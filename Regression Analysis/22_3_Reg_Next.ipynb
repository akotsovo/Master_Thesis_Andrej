# %% [markdown]
# # 22_3 Regression - Nextbike

# %% [markdown]
# Focus on Trips starting at stations

# %%
# import libraries
import pandas as pd
import numpy as np
import sklearn
from datetime import datetime
import os
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
import shapely
import hashlib
import holidays
from shapely import Point, wkt
import scipy.stats
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import shapiro, anderson, norm, expon, gamma
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Load and prepare data

# %%
data_month_double = '07'

# %%
# read final data
data = pd.read_csv("../../../20_Final_Data.csv")
# Out:
# /tmp/ipykernel_1576496/974816303.py:2: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("../../../20_Final_Data_NEW_TEST.csv")

# %%
tier = pd.read_parquet("../Data/12_tier_part2.parquet")
next = pd.read_parquet("../Data/15_nextbike_part2.parquet")

# %%
tier['trip_duration_seconds'] = tier['trip_duration'].dt.total_seconds()
next['trip_duration_seconds'] = next['trip_duration'].dt.total_seconds()

# %%
# transform geometry
data['station_point'] = data['station_point'].apply(wkt.loads)

# %%
data['buffer_zone'] = shapely.wkt.loads(data['buffer_zone'])

# %%
data = gpd.GeoDataFrame(data, geometry='station_point')

# %%
data = data.loc[:, ~data.columns.str.contains('Unnamed')]

# %%
#data.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.2'], inplace=True)

# %%
data['actual_arrival_time'] = pd.to_datetime(data['actual_arrival_time'])
data['actual_departure_time'] = pd.to_datetime(data['actual_departure_time'])
data['scheduled_arrival_time'] = pd.to_datetime(data['scheduled_arrival_time'])
data['scheduled_departure_time'] = pd.to_datetime(data['scheduled_departure_time'])

# %%
data = gpd.GeoDataFrame(data, geometry='buffer_zone')

# %%
data.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2564861 entries, 0 to 2564860
# Data columns (total 56 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   route_id                             int64
#  1   agency_id                            int64
#  2   route_short_name                     object
#  3   route_type                           int64
#  4   route_type_name                      object
#  5   agency_name                          object
#  6   service_id                           int64
#  7   trip_id                              object
#  8   trip_headsign                        object
#  9   direction_id                         int64
#  10  shape_id                             int64
#  11  stop_id                              int64
#  12  actual_arrival_time                  datetime64[ns]
#  13  actual_departure_time                datetime64[ns]
#  14  vrs_timestamp                        int64
#  15  stop_sequence                        int64
#  16  stop_headsign                        object
#  17  stop_name                            object
#  18  scheduled_arrival_time               datetime64[ns]
#  19  scheduled_departure_time             datetime64[ns]
#  20  arrival_delay                        object
#  21  departure_delay                      object
#  22  service                              int64
#  23  date                                 object
#  24  weekday                              object
#  25  transfer_stop                        bool
#  26  tier_trips_count                     int64
#  27  tier_trips_id                        object
#  28  tier_trips_end_at_station_count      int64
#  29  tier_trips_end_at_station_id         object
#  30  station_point                        geometry
#  31  buffer_zone                          geometry
#  32  nextbike_trips_count                 int64
#  33  nextbike_trips_id                    object
#  34  nextbike_trips_end_at_station_count  int64
#  35  nextbike_trips_end_at_station_id     object
#  36  current_time                         object
#  37  current_temp                         float64
#  38  current_feels_like                   float64
#  39  current_cloudiness                   int64
#  40  current_visibility                   int64
#  41  current_wind_speed                   float64
#  42  current_description                  object
#  43  current_precipitation_volume         float64
#  44  arrival_delay_float                  float64
#  45  departure_delay_float                float64
#  46  actual_arrival_time_float            int64
#  47  actual_departure_time_float          int64
#  48  delay_span                           object
#  49  arrival_delay_span                   int64
#  50  weather_int                          int64
#  51  time_span_arrival                    object
#  52  time_span_int_arrival                int64
#  53  weekend                              int64
#  54  time_span                            object
#  55  time_span_int                        int64
# dtypes: bool(1), datetime64[ns](4), float64(6), geometry(2), int64(23), object(20)
# memory usage: 1.1+ GB

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
data['arrival_delay'] = pd.to_timedelta(data['arrival_delay'])
data['departure_delay'] = pd.to_timedelta(data['departure_delay'])

# %%
#NEW FEATURES
data['delay_category'] = data['arrival_delay'].apply(lambda x: 1 if x > pd.Timedelta(0) else 0 if x == pd.Timedelta(0) else -1)
data['cancelled_trip'] = np.where((data['scheduled_arrival_time'].notna() & data['actual_arrival_time'].isna() & data['scheduled_departure_time'].notna() & data['actual_departure_time'].isna()), 1, 0)

# %%
data['arrival_delay_float'] = data['arrival_delay'].astype(str)
data['arrival_delay_float'] = data['arrival_delay_float'].str.split(' ', n=2).str[-1]
data['arrival_delay_float'] = data['arrival_delay_float'].astype(str)
data['arrival_delay_float'] = pd.to_timedelta(data['arrival_delay_float'])
data['arrival_delay_float'] = pd.to_timedelta(data['arrival_delay_float']).dt.total_seconds() / 60

# %%
data['departure_delay_float'] = data['departure_delay'].astype(str)
data['departure_delay_float'] = data['departure_delay_float'].str.split(' ', n=2).str[-1]
data['departure_delay_float'] = data['departure_delay_float'].astype(str)
data['departure_delay_float'] = pd.to_timedelta(data['departure_delay_float'])
data['departure_delay_float'] = pd.to_timedelta(data['departure_delay_float']).dt.total_seconds() / 60

# %%
data['delay'] = data['departure_delay'].apply(lambda x: 1 if x > pd.Timedelta(0) else 0)
data['no_delay'] = data['departure_delay'].apply(lambda x: 1 if x == pd.Timedelta(0) else 0)
data['nan_delay'] = data['departure_delay'].apply(lambda x: 1 if pd.isna(x) else 0)

# %%
data['delay_span_int'] = 0

for index in data.index:
    if data['delay_span'][index] == '0':
        data['delay_span_int'][index] = 0
    if data['delay_span'][index] == '0-5':
        data['delay_span_int'][index] = 1
    if data['delay_span'][index] == '5-10':
        data['delay_span_int'][index] = 2
    if data['delay_span'][index] == '10-15':
        data['delay_span_int'][index] = 3
    if data['delay_span'][index] == '15-20':
        data['delay_span_int'][index] = 4
    if data['delay_span'][index] == '20-30':
        data['delay_span_int'][index] = 5
    if data['delay_span'][index] == '30-45':
        data['delay_span_int'][index] = 6
    if data['delay_span'][index] == '45-60':
        data['delay_span_int'][index] = 7
# Out:
# /tmp/ipykernel_1576496/1846020972.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['delay_span_int'][index] = 0
# /tmp/ipykernel_1576496/1846020972.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['delay_span_int'][index] = 0
# /tmp/ipykernel_1576496/1846020972.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['delay_span_int'][index] = 1
# /tmp/ipykernel_1576496/1846020972.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['delay_span_int'][index] = 1
# /tmp/ipykernel_1576496/1846020972.py:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['delay_span_int'][index] = 7
# /tmp/ipykernel_1576496/1846020972.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['delay_span_int'][index] = 7
# /tmp/ipykernel_1576496/1846020972.py:17: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['delay_span_int'][index] = 6
# /tmp/ipykernel_1576496/1846020972.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['delay_span_int'][index] = 6
# /tmp/ipykernel_1576496/1846020972.py:15: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['delay_span_int'][index] = 5
# /tmp/ipykernel_1576496/1846020972.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['delay_span_int'][index] = 5
# /tmp/ipykernel_1576496/1846020972.py:13: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['delay_span_int'][index] = 4
# /tmp/ipykernel_1576496/1846020972.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['delay_span_int'][index] = 4
# /tmp/ipykernel_1576496/1846020972.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['delay_span_int'][index] = 3
# /tmp/ipykernel_1576496/1846020972.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['delay_span_int'][index] = 3
# /tmp/ipykernel_1576496/1846020972.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['delay_span_int'][index] = 2
# /tmp/ipykernel_1576496/1846020972.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['delay_span_int'][index] = 2

# %%
# new colum that sets trips that not happend to -1
data['arrival_delay_new'] = data['arrival_delay'].fillna(-1)
data['arrival_delay_float_new'] = data['arrival_delay_float'].fillna(-1)
# new colum that sets trips that not happend to -1
data['departure_delay_new'] = data['departure_delay'].fillna(-1)
data['departure_delay_float_new'] = data['departure_delay_float'].fillna(-1)

# %%
data['current_precipitation_volume'].fillna(0, inplace=True)
# Out:
# /tmp/ipykernel_1576496/969628070.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['current_precipitation_volume'].fillna(0, inplace=True)

# %%
delay = data[data['departure_delay'] > pd.Timedelta(0)]

# %%
no_delay = data[data['departure_delay'] == pd.Timedelta(0)]

# %%
nan_delay = data[data['scheduled_arrival_time'].notna() & data['actual_arrival_time'].isna() & data['scheduled_departure_time'].notna() & data['actual_departure_time'].isna()]
#nan_delay = data[data['arrival_delay'].isna()]
nan_delay
# Out:
#          route_id  agency_id route_short_name  route_type route_type_name  \
# 41            551          8              551           3             Bus
# 42            551          8              551           3             Bus
# 43            551          8              551           3             Bus
# 44            551          8              551           3             Bus
# 45            551          8              551           3             Bus
# ...           ...        ...              ...         ...             ...
# 2564854       689          6               N9           3             Bus
# 2564856       689          6               N9           3             Bus
# 2564857       689          6               N9           3             Bus
# 2564858       689          6               N9           3             Bus
# 2564860       689          6               N9           3             Bus
#
#                                       agency_name  service_id  \
# 41       RSVG Rhein-Sieg-Verkehrsgesellschaft mbH         125
# 42       RSVG Rhein-Sieg-Verkehrsgesellschaft mbH         125
# 43       RSVG Rhein-Sieg-Verkehrsgesellschaft mbH         125
# 44       RSVG Rhein-Sieg-Verkehrsgesellschaft mbH         125
# 45       RSVG Rhein-Sieg-Verkehrsgesellschaft mbH         125
# ...                                           ...         ...
# 2564854         SWB Stadtwerke Bonn Verkehrs GmbH          43
# 2564856         SWB Stadtwerke Bonn Verkehrs GmbH          43
# 2564857         SWB Stadtwerke Bonn Verkehrs GmbH          43
# 2564858         SWB Stadtwerke Bonn Verkehrs GmbH          43
# 2564860         SWB Stadtwerke Bonn Verkehrs GmbH          43
#
#                                                    trip_id trip_headsign  \
# 41       255-551-008-2071.2.22:033200-34-157_C0741D60-B...      Bonn Hbf
# 42       159-551-008-687.2.36:044000-33-157_FAA787CB-18...  Troisdorf Bf
# 43       159-551-008-687.2.36:044000-33-157_FAA787CB-18...  Troisdorf Bf
# 44       159-551-008-687.2.36:044000-33-157_FAA787CB-18...  Troisdorf Bf
# 45       159-551-008-687.2.36:044000-33-157_FAA787CB-18...  Troisdorf Bf
# ...                                                    ...           ...
# 2564854  6890005-689-006-687.2.34:263500-53-1_2AFE8F0F-...      Bonn Hbf
# 2564856  6890005-689-006-687.2.34:263500-53-1_2AFE8F0F-...      Bonn Hbf
# 2564857  6890005-689-006-687.2.34:263500-53-1_2AFE8F0F-...      Bonn Hbf
# 2564858  6890005-689-006-687.2.34:263500-53-1_2AFE8F0F-...      Bonn Hbf
# 2564860  6890005-689-006-687.2.34:263500-53-1_2AFE8F0F-...      Bonn Hbf
#
#          direction_id  ...  delay_category  cancelled_trip delay no_delay  \
# 41                  1  ...              -1               1     0        0
# 42                  0  ...              -1               1     0        0
# 43                  0  ...              -1               1     0        0
# 44                  0  ...              -1               1     0        0
# 45                  0  ...              -1               1     0        0
# ...               ...  ...             ...             ...   ...      ...
# 2564854             0  ...              -1               1     0        0
# 2564856             0  ...              -1               1     0        0
# 2564857             0  ...              -1               1     0        0
# 2564858             0  ...              -1               1     0        0
# 2564860             0  ...              -1               1     0        0
#
#          nan_delay  delay_span_int arrival_delay_new arrival_delay_float_new  \
# 41               1               0                -1                    -1.0
# 42               1               0                -1                    -1.0
# 43               1               0                -1                    -1.0
# 44               1               0                -1                    -1.0
# 45               1               0                -1                    -1.0
# ...            ...             ...               ...                     ...
# 2564854          1               0                -1                    -1.0
# 2564856          1               0                -1                    -1.0
# 2564857          1               0                -1                    -1.0
# 2564858          1               0                -1                    -1.0
# 2564860          1               0                -1                    -1.0
#
#         departure_delay_new departure_delay_float_new
# 41                       -1                      -1.0
# 42                       -1                      -1.0
# 43                       -1                      -1.0
# 44                       -1                      -1.0
# 45                       -1                      -1.0
# ...                     ...                       ...
# 2564854                  -1                      -1.0
# 2564856                  -1                      -1.0
# 2564857                  -1                      -1.0
# 2564858                  -1                      -1.0
# 2564860                  -1                      -1.0
#
# [1005613 rows x 66 columns]

# %% [markdown]
# ### Definition of functions

# %%
def calc_stats(data, column_name):

    #generated by Copilot

    sum = data[column_name].sum()

#Central Tendency

    rows = len(data.index)
    # Calculate mean (average)
    mean = data[column_name].mean()
    # Calculate median (middle value)
    median = data[column_name].median()
    # Calculate mode (most frequent value)
    mode = data[column_name].mode()
    #calc maximum
    max = data[column_name].max()
    #calc minimum
    min = data[column_name].min()

    # Calculate range
    data_range = data[column_name].max() - data[column_name].min()
    # Calculate coefficient of variation of range
    cvr = data_range / mean
    # Calculate coefficient of variation of mean
    cvm = mean / mean
    # Calculate coefficient of variation of median
    cvmed = median / mean
    # Calculate coefficient of variation of mode
    cvmode = mode / mean
    # Calculate coefficient of variation of standard deviation
   

# Variability
# Measure of how spread out the values in a data set are
    
    # Calculate standard deviation (average amount of variability in a dataset; tells how far each score lies from the mean; the larger the standard deviation, the more variable the data)
    std_dev = data[column_name].std()
    # Calculate variance (average squared deviation from the mean; square of standard deviation; units of varriance are much larger than those of a typical value in the dataset)
    variance = data[column_name].var()
    # Calculate coefficient of variation
    cv = std_dev / mean # standard deviation divided by the mean; measures the relative variability of a dataset; allows comparison of variability of datasets with different units of measurement
    # Calculate 25th percentile
    percentile_25 = data[column_name].quantile(0.25)
    # Calculate 75th percentile
    percentile_75 = data[column_name].quantile(0.75)
    # Calculate interquartile range
    iqr = percentile_75 - percentile_25 # difference between the 75th and 25th percentiles; measures the spread of the middle 50% of values in a dataset
    # Calculate coefficient of quartile deviation
    qd = iqr / (percentile_75 + percentile_25)
    # Calculate coefficient of variation of coefficient of variation
    cvcv = std_dev / mean
    # Calculate coefficient of variation of coefficient of quartile deviation
    cvqd = iqr / (percentile_75 + percentile_25)
    # Calculate coefficient of variation of range

#Measure of Shape

    # Calculate skewness - measure of how much the probability distribution of a random variable deviates from the normal distribution
    skewness = data[column_name].skew()
    
    # Calculate kurtosis
    kurtosis = data[column_name].kurtosis()

    # Calculate coefficient of skewness
    cs = skewness / std_dev
    # Calculate coefficient of kurtosis
    ck = kurtosis / std_dev
    # Calculate coefficient of variation of skewness
    cvs = skewness / std_dev
    # Calculate coefficient of variation of kurtosis
    cvk = kurtosis / std_dev
    # Calculate coefficient of variation of coefficient of skewness
    cvcs = skewness / std_dev
    # Calculate coefficient of variation of coefficient of kurtosis
    cvck = kurtosis / std_dev
    
    
    
    #return "column: " + str(column_name), "mean: " + str(mean), "median: " + str(median), "mode: " + str(mode), "std_dev: " + str(std_dev), "variance: " + str(variance), "skewness: "+ str(skewness), "kurtosis: " + str(kurtosis), "percentile_25: "+ str(percentile_25), "percentile_75: "+ str(percentile_75), "iqr: " + str(iqr), "range: "+ str(data_range), "cv"+ str(cv), "qd: "+str(qd), "cs: "+ str(cs), "ck: " + str(ck), "csv: "+ str(cvs), "cvk: "+ str(cvk), "cvcs: "+ str(cvcs), "cvck: " +str(cvck), "cvcv: "+ str(cvcv), "cvqd: "+ str (cvqd), "cvr: "+ str(cvr), "cvm: " + str(cvm), "cvmed: " + str(cvmed), "cvmode: "+ str(cvmode)

    return pd.DataFrame({'column': [column_name],
                         'number of rows': [rows],                       
                         'sum': [sum],
                         'mean': [mean],
                         'median': [median],
                         'mode': [mode],
                         'max': [max],
                         'min': [min],
                         'std_dev': [std_dev],
                         'variance': [variance],
                         'skewness': [skewness],
                         'kurtosis': [kurtosis],
                         'percentile_25': [percentile_25],
                         'percentile_75': [percentile_75],
                         'iqr': [iqr],
                         'range': [data_range],
                         'cv': [cv],
                         'qd': [qd],
                         'cs': [cs],
                         'ck': [ck],
                         'cvs': [cvs],
                         'cvk': [cvk],
                         'cvcs': [cvcs],
                         'cvck': [cvck],
                         'cvcv': [cvcv],
                         'cvqd': [cvqd],
                         'cvr': [cvr],
                         'cvm': [cvm],
                         'cvmed': [cvmed],
                         'cvmode': [cvmode]}).T

# %%
# create a shorter dataframe with most interesting columns - for better overview
def show_short_df(dataframe):
    delay_short = dataframe[['route_id', 'trip_id', 'stop_id', 'stop_name', 'scheduled_arrival_time', 'actual_arrival_time', 'scheduled_departure_time', 'actual_departure_time', 'arrival_delay', 'departure_delay', 'tier_trips_count', 'tier_trips_end_at_station_count', 'nextbike_trips_count', 'nextbike_trips_end_at_station_count', 'buffer_zone', 'arrival_delay_float', 'departure_delay_float']]
    return delay_short

# %%
# transform geometry
point_start = gpd.GeoDataFrame(geometry=gpd.GeoSeries.from_wkb(tier["start_location"], crs=4326))
point_end = gpd.GeoDataFrame(geometry=gpd.GeoSeries.from_wkb(tier["end_location"], crs=4326))
# drop geometry columns in wrong format
tier = tier.drop(columns=["start_location", "end_location"])
# replace geometry columns with correct format
tier['start_location'] = point_start
tier['end_location'] = point_end

# %%
# get the data from the tier / nextbike dataset
def check_micromobility_datasets(type, data):
    
    if type == 'tier':

        return_data = tier.copy()
        return_data = return_data.iloc[0:0] # empty dataframe

        for item in data['tier_trips_id'].str.split(' ').explode().dropna():   # iterate over all tier ids in the dataframe
            
            id = tier[tier['tier_trips_id'] == int(float(item))]   # get the rows with the specific id
            return_data = pd.concat([return_data, id])  # add the rows to the return dataframe

            return_data.drop_duplicates(inplace=True)
            
    if type == 'next':

        return_data = next.copy()
        return_data = return_data.iloc[0:0] # empty dataframe

        for item in data['nextbike_trips_id'].str.split(' ').explode().dropna():   # iterate over all nextbike ids in the dataframe
            
            id = next[next['nextbike_trips_id'] == int(float(item))]  # get the rows with the specific id
            return_data = pd.concat([return_data, id]) # add the rows to the return dataframe

            return_data.drop_duplicates(inplace=True)

    return return_data

# %%
def get_station_to_station(data, mode):
    
    if mode == 'tier':

        data = data[data['tier_trips_start_at_station_id'].notna() & data['tier_trips_end_at_station_id'].notna()]
        data = data[data['tier_trips_start_at_station_id'] != data['tier_trips_end_at_station_id']]
        data = data[data['tier_trips_start_at_station_id'] != 0]
        data = data[data['tier_trips_end_at_station_id'] != 0]
    t = check_micromobility_datasets('tier', data)
    n = check_micromobility_datasets('next', data)

    t = t[t['end_stop_id'].notna() & t['start_stop_id'].notna()]
    n = n[n['end_stop_id'].notna() & n['start_stop_id'].notna()]
    
    return t, n

# %%
# map the start and end locations of the trips on a map and connect them with a line

def map_buffer_zones(dataset):
    
    micromobility_data = check_micromobility_datasets('tier', dataset)
    
    # Create a folium map object
    m = folium.Map(location=[50.73743, 7.09821], zoom_start=12)

    # Iterate over each row in the micromobility data
    for index, row in micromobility_data.iterrows():
        # Get the start and end locations
        start_location = row['start_location']
        end_location = row['end_location']
        
        # Get the start and end stop names
        start_stop_name = row['start_stop_name']
        end_stop_name = row['end_stop_name']
        # Add markers for the start and end locations
        folium.Marker(location=[start_location.y, start_location.x], popup=start_stop_name).add_to(m)
        folium.Marker(location=[end_location.y, end_location.x], popup=end_stop_name).add_to(m)
        # Create a line connecting the start and end locations
        folium.PolyLine(locations=[[start_location.y, start_location.x], [end_location.y, end_location.x]], color='blue').add_to(m)
        
    # Display the map
    return m

# %%
def get_stats(data, var):

    if var == 'all':
        var = data.columns

    df = pd.DataFrame()

    for i in var:
        df = pd.concat([df, calc_stats(data, i)], axis=1)

    df.columns = df.iloc[0]
    df = df[1:]
    
    return df

# %%
def get_micro_stats(data, operator):
    
    if operator == 'tier':
        dataframe = get_stats(check_micromobility_datasets(operator, data), ['trip_duration_seconds', 'trip_distance_kilometers'])
    elif operator == 'next':
        dataframe = get_stats(check_micromobility_datasets(operator, data), ['trip_duration_seconds', 'trip_distance_kilometers'])
    
    return dataframe

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'center')
                 #Bbox = dict(facecolor = 'red', alpha =.8))

# %% [markdown]
# route_id', 'agency_id',
#        'route_short_name', 'route_type', 'route_type_name', 'agency_name',
#        'service_id', 'trip_id', 'trip_headsign', 'direction_id', 'shape_id',
#        'stop_id', 'actual_arrival_time', 'actual_departure_time',
#        'vrs_timestamp', 'stop_sequence', 'stop_headsign', 'stop_name',
#        'station_point', 'buffer_zone', 'scheduled_arrival_time',
#        'scheduled_departure_time', 'arrival_delay', 'departure_delay',
#        'service', 'date', 'weekday', 'transfer_stop', 'tier_trips_count',
#        'tier_trips_id', 'nextbike_trips_count', 'nextbike_trips_id',
#        'current_time', 'current_temp', 'current_feels_like',
#        'current_cloudiness', 'current_visibility', 'current_wind_speed',
#        'current_description', 'current_precipitation_volume', 'holiday',
#        'holiday_NRW', 'holiday_name', 'holiday_name_NRW'

# %%
data.columns
# Out:
# Index(['route_id', 'agency_id', 'route_short_name', 'route_type',
#        'route_type_name', 'agency_name', 'service_id', 'trip_id',
#        'trip_headsign', 'direction_id', 'shape_id', 'stop_id',
#        'actual_arrival_time', 'actual_departure_time', 'vrs_timestamp',
#        'stop_sequence', 'stop_headsign', 'stop_name', 'scheduled_arrival_time',
#        'scheduled_departure_time', 'arrival_delay', 'departure_delay',
#        'service', 'date', 'weekday', 'transfer_stop', 'tier_trips_count',
#        'tier_trips_id', 'tier_trips_end_at_station_count',
#        'tier_trips_end_at_station_id', 'station_point', 'buffer_zone',
#        'nextbike_trips_count', 'nextbike_trips_id',
#        'nextbike_trips_end_at_station_count',
#        'nextbike_trips_end_at_station_id', 'current_time', 'current_temp',
#        'current_feels_like', 'current_cloudiness', 'current_visibility',
#        'current_wind_speed', 'current_description',
#        'current_precipitation_volume', 'arrival_delay_float',
#        'departure_delay_float', 'actual_arrival_time_float',
#        'actual_departure_time_float', 'delay_span', 'arrival_delay_span',
#        'weather_int', 'time_span_arrival', 'time_span_int_arrival', 'weekend',
#        'time_span', 'time_span_int', 'delay_category', 'cancelled_trip',
#        'delay', 'no_delay', 'nan_delay', 'delay_span_int', 'arrival_delay_new',
#        'arrival_delay_float_new', 'departure_delay_new',
#        'departure_delay_float_new'],
#       dtype='object')

# %% [markdown]
# ## Def Features

# %%
y_string = 'nextbike_trips_count'

# %%
# create dummy variables for categories
delay_span_dummy = data[['delay_span']]
delay_span_dummy = pd.get_dummies(delay_span_dummy, columns=['delay_span'], drop_first=True)


weekday_dummy = data[['weekday']]
weekday_dummy = pd.get_dummies(weekday_dummy, columns=['weekday'], drop_first=True)


time_span_dummy = data[['time_span']]
time_span_dummy = pd.get_dummies(time_span_dummy, columns=['time_span'], drop_first=True)

data_slim = data.drop(columns=['route_id', 'agency_id', 'route_short_name',
       'route_type_name', 'agency_name', 'service_id', 'trip_id',
       'trip_headsign', 'direction_id', 'shape_id',
       'actual_arrival_time', 'actual_departure_time', 'vrs_timestamp',
       'stop_sequence', 'stop_headsign', 'stop_name', 'scheduled_arrival_time',
       'scheduled_departure_time', 'arrival_delay', 'date', 'tier_trips_id', 'tier_trips_end_at_station_count',
       'tier_trips_end_at_station_id', 'station_point', 'buffer_zone',
       'tier_trips_count', 'nextbike_trips_id',
       'nextbike_trips_end_at_station_count', 'departure_delay', 'actual_arrival_time_float', 'time_span_int', 'delay_category', 'departure_delay_new',
       'nextbike_trips_end_at_station_id', 'current_time', 'current_feels_like', 'current_cloudiness', 'current_visibility',
       'current_wind_speed', 'current_description', 'arrival_delay_float',  'actual_departure_time_float',  'time_span_arrival', 'time_span_int_arrival', 'delay_span_int', 'arrival_delay_new', 'arrival_delay_float_new', 'arrival_delay_span'])

data_dummy = pd.get_dummies(data_slim, columns=['time_span', 'weekday', 'delay_span'], drop_first=True)

# %%
data_slim.columns
# Out:
# Index(['route_type', 'stop_id', 'service', 'weekday', 'transfer_stop',
#        'nextbike_trips_count', 'current_temp', 'current_precipitation_volume',
#        'departure_delay_float', 'delay_span', 'weather_int', 'weekend',
#        'time_span', 'cancelled_trip', 'delay', 'no_delay', 'nan_delay',
#        'departure_delay_float_new'],
#       dtype='object')

# %%
data_dummy.columns
# Out:
# Index(['route_type', 'stop_id', 'service', 'transfer_stop',
#        'nextbike_trips_count', 'current_temp', 'current_precipitation_volume',
#        'departure_delay_float', 'weather_int', 'weekend', 'cancelled_trip',
#        'delay', 'no_delay', 'nan_delay', 'departure_delay_float_new',
#        'time_span_afternoon', 'time_span_early morning', 'time_span_evening',
#        'time_span_evening rush', 'time_span_lunch', 'time_span_morning rush',
#        'time_span_until midday', 'weekday_Monday', 'weekday_Saturday',
#        'weekday_Sunday', 'weekday_Thursday', 'weekday_Tuesday',
#        'weekday_Wednesday', 'delay_span_0-5', 'delay_span_10-15',
#        'delay_span_15-20', 'delay_span_20-30', 'delay_span_30-45',
#        'delay_span_45-60', 'delay_span_5-10'],
#       dtype='object')

# %% [markdown]
# # Test for Model

# %%
# Varianz und Mittelwert der abhängigen Variable
# Var > Mean -> Poisson nicht gut (bei großer Abweichung)
mean = data[y_string].mean()
print(mean)
variance = data[y_string].var()
print(variance)
dispersion_ratio = variance / mean
print(dispersion_ratio)
# Out:
# 0.04864669079532965
# 0.0734255495825432
# 1.5093637076253594

# %%
corr_matrix = data_dummy.corr()
corr_matrix
# Out:
#                               route_type   stop_id   service  transfer_stop  \
# route_type                      1.000000  0.060355  0.016856      -0.065857
# stop_id                         0.060355  1.000000 -0.001685      -0.015772
# service                         0.016856 -0.001685  1.000000      -0.007632
# transfer_stop                  -0.065857 -0.015772 -0.007632       1.000000
# nextbike_trips_count           -0.017866 -0.059338  0.008975       0.036869
# current_temp                    0.027113  0.006173  0.050747      -0.005364
# current_precipitation_volume   -0.001331 -0.000459  0.001262      -0.000140
# departure_delay_float           0.026825 -0.000539 -0.020214      -0.001756
# weather_int                    -0.003618 -0.001419 -0.000763       0.000614
# weekend                        -0.008933 -0.001467 -0.095210       0.006757
# cancelled_trip                 -0.011872 -0.003145  0.016968      -0.007308
# delay                           0.059852  0.019042  0.004679      -0.041360
# no_delay                       -0.048696 -0.019936 -0.022378       0.061103
# nan_delay                      -0.017569 -0.001823  0.014370      -0.011132
# departure_delay_float_new       0.024613  0.000149 -0.020435       0.002036
# time_span_afternoon             0.013519  0.001933  0.017986      -0.000065
# time_span_early morning        -0.043058 -0.006701 -0.016943       0.007556
# time_span_evening              -0.001487 -0.000992  0.015684       0.004776
# time_span_evening rush          0.019866  0.002445  0.022991       0.001473
# time_span_lunch                 0.006009 -0.000887  0.022747      -0.000779
# time_span_morning rush          0.012555  0.002188  0.023777       0.001853
# time_span_until midday          0.006961  0.001069  0.017306      -0.000781
# weekday_Monday                 -0.003203 -0.001722  0.020264      -0.001553
# weekday_Saturday               -0.008863 -0.001648  0.000591       0.003781
# weekday_Sunday                 -0.004846 -0.000890 -0.109276       0.005604
# weekday_Thursday                0.004911  0.001104  0.027363      -0.001854
# weekday_Tuesday                 0.002984  0.000740  0.027405      -0.001280
# weekday_Wednesday               0.004350  0.001130  0.027388      -0.001870
# delay_span_0-5                  0.059182  0.019224  0.012627      -0.043125
# delay_span_10-15                0.005625  0.030173 -0.001942      -0.005749
# delay_span_15-20                0.008414 -0.004215 -0.002099       0.002988
# delay_span_20-30                0.008273  0.014147 -0.007796       0.011454
# delay_span_30-45                0.007988 -0.006972 -0.034543       0.014965
# delay_span_45-60                0.005451 -0.009670 -0.026784      -0.004798
# delay_span_5-10                 0.008172 -0.006247 -0.000539      -0.002561
#
#                               nextbike_trips_count  current_temp  \
# route_type                               -0.017866      0.027113
# stop_id                                  -0.059338      0.006173
# service                                   0.008975      0.050747
# transfer_stop                             0.036869     -0.005364
# nextbike_trips_count                      1.000000      0.037952
# current_temp                              0.037952      1.000000
# current_precipitation_volume             -0.009247     -0.049263
# departure_delay_float                    -0.009838     -0.016466
# weather_int                              -0.018254     -0.142011
# weekend                                  -0.019111      0.135245
# cancelled_trip                           -0.002127     -0.028525
# delay                                    -0.037967      0.022719
# no_delay                                  0.042030      0.006047
# nan_delay                                 0.001701     -0.027466
# departure_delay_float_new                -0.007663     -0.004259
# time_span_afternoon                       0.030705      0.201086
# time_span_early morning                  -0.008749     -0.176066
# time_span_evening                        -0.010248     -0.008180
# time_span_evening rush                    0.005905      0.193866
# time_span_lunch                           0.011297      0.181632
# time_span_morning rush                   -0.011955     -0.277739
# time_span_until midday                    0.001885      0.013122
# weekday_Monday                           -0.002198     -0.058290
# weekday_Saturday                         -0.008449      0.121484
# weekday_Sunday                           -0.019043      0.025841
# weekday_Thursday                          0.003624     -0.126978
# weekday_Tuesday                           0.006656      0.078613
# weekday_Wednesday                         0.008540     -0.106187
# delay_span_0-5                           -0.031373      0.025606
# delay_span_10-15                         -0.003003     -0.002046
# delay_span_15-20                         -0.003589      0.000572
# delay_span_20-30                         -0.003144     -0.001695
# delay_span_30-45                         -0.003580     -0.021065
# delay_span_45-60                          0.004147     -0.014491
# delay_span_5-10                          -0.002867      0.008926
#
#                               current_precipitation_volume  \
# route_type                                       -0.001331
# stop_id                                          -0.000459
# service                                           0.001262
# transfer_stop                                    -0.000140
# nextbike_trips_count                             -0.009247
# current_temp                                     -0.049263
# current_precipitation_volume                      1.000000
# departure_delay_float                            -0.003632
# weather_int                                       0.685637
# weekend                                           0.087984
# cancelled_trip                                    0.010671
# delay                                            -0.006414
# no_delay                                         -0.004407
# nan_delay                                         0.010043
# departure_delay_float_new                        -0.005613
# time_span_afternoon                               0.019596
# time_span_early morning                          -0.013165
# time_span_evening                                -0.013672
# time_span_evening rush                            0.008869
# time_span_lunch                                  -0.000472
# time_span_morning rush                            0.001600
# time_span_until midday                           -0.012142
# weekday_Monday                                   -0.024392
# weekday_Saturday                                  0.083818
# weekday_Sunday                                    0.035412
# weekday_Thursday                                  0.027576
# weekday_Tuesday                                  -0.066925
# weekday_Wednesday                                -0.042474
# delay_span_0-5                                   -0.006357
# delay_span_10-15                                 -0.000857
# delay_span_15-20                                 -0.000513
# delay_span_20-30                                 -0.000959
# delay_span_30-45                                 -0.002646
# delay_span_45-60                                 -0.002144
# delay_span_5-10                                  -0.000870
#
#                               departure_delay_float  weather_int   weekend  \
# route_type                                 0.026825    -0.003618 -0.008933
# stop_id                                   -0.000539    -0.001419 -0.001467
# service                                   -0.020214    -0.000763 -0.095210
# transfer_stop                             -0.001756     0.000614  0.006757
# nextbike_trips_count                      -0.009838    -0.018254 -0.019111
# current_temp                              -0.016466    -0.142011  0.135245
# current_precipitation_volume              -0.003632     0.685637  0.087984
# departure_delay_float                      1.000000    -0.005550  0.006572
# weather_int                               -0.005550     1.000000  0.067783
# weekend                                    0.006572     0.067783  1.000000
# cancelled_trip                                  NaN     0.011450 -0.026659
# delay                                      0.121881    -0.008034  0.012568
# no_delay                                  -0.121881    -0.003418  0.016543
# nan_delay                                       NaN     0.010797 -0.026382
# departure_delay_float_new                  1.000000    -0.007280  0.012866
# time_span_afternoon                       -0.001427    -0.005517  0.010623
# time_span_early morning                    0.019381     0.002651 -0.008085
# time_span_evening                         -0.007612     0.013428  0.021791
# time_span_evening rush                    -0.009038    -0.009699  0.006860
# time_span_lunch                           -0.001162    -0.003645  0.015652
# time_span_morning rush                    -0.012461     0.014116 -0.032128
# time_span_until midday                    -0.006186    -0.023511 -0.002325
# weekday_Monday                            -0.004048     0.002228 -0.329412
# weekday_Saturday                           0.000684     0.074638  0.567856
# weekday_Sunday                             0.004326     0.043457  0.670184
# weekday_Thursday                          -0.002835     0.068347 -0.288432
# weekday_Tuesday                           -0.001682    -0.056565 -0.288875
# weekday_Wednesday                         -0.002564    -0.062573 -0.288693
# delay_span_0-5                             0.044318    -0.007977  0.011333
# delay_span_10-15                           0.091897    -0.000623  0.006153
# delay_span_15-20                           0.200583    -0.000165  0.003714
# delay_span_20-30                           0.245863    -0.001100 -0.000079
# delay_span_30-45                           0.384454    -0.004030  0.011069
# delay_span_45-60                           0.191557    -0.002951  0.006178
# delay_span_5-10                            0.058298    -0.002118 -0.007732
#
#                               ...  weekday_Thursday  weekday_Tuesday  \
# route_type                    ...          0.004911         0.002984
# stop_id                       ...          0.001104         0.000740
# service                       ...          0.027363         0.027405
# transfer_stop                 ...         -0.001854        -0.001280
# nextbike_trips_count          ...          0.003624         0.006656
# current_temp                  ...         -0.126978         0.078613
# current_precipitation_volume  ...          0.027576        -0.066925
# departure_delay_float         ...         -0.002835        -0.001682
# weather_int                   ...          0.068347        -0.056565
# weekend                       ...         -0.288432        -0.288875
# cancelled_trip                ...          0.021300        -0.059127
# delay                         ...         -0.012335         0.039693
# no_delay                      ...         -0.009915         0.020073
# nan_delay                     ...          0.020534        -0.056046
# departure_delay_float_new     ...         -0.008205         0.015513
# time_span_afternoon           ...         -0.010274         0.017689
# time_span_early morning       ...         -0.002943         0.000326
# time_span_evening             ...         -0.007742         0.012835
# time_span_evening rush        ...         -0.009786         0.029647
# time_span_lunch               ...         -0.005334         0.015782
# time_span_morning rush        ...          0.008096         0.010290
# time_span_until midday        ...         -0.000955         0.007486
# weekday_Monday                ...         -0.193566        -0.193863
# weekday_Saturday              ...         -0.180141        -0.180418
# weekday_Sunday                ...         -0.120119        -0.120304
# weekday_Thursday              ...          1.000000        -0.169746
# weekday_Tuesday               ...         -0.169746         1.000000
# weekday_Wednesday             ...         -0.169639        -0.169900
# delay_span_0-5                ...         -0.011939         0.040312
# delay_span_10-15              ...         -0.001795        -0.000653
# delay_span_15-20              ...         -0.001256         0.001132
# delay_span_20-30              ...          0.001206         0.001745
# delay_span_30-45              ...         -0.003376        -0.000685
# delay_span_45-60              ...         -0.001466         0.000013
# delay_span_5-10               ...          0.000962         0.004687
#
#                               weekday_Wednesday  delay_span_0-5  \
# route_type                             0.004350        0.059182
# stop_id                                0.001130        0.019224
# service                                0.027388        0.012627
# transfer_stop                         -0.001870       -0.043125
# nextbike_trips_count                   0.008540       -0.031373
# current_temp                          -0.106187        0.025606
# current_precipitation_volume          -0.042474       -0.006357
# departure_delay_float                 -0.002564        0.044318
# weather_int                           -0.062573       -0.007977
# weekend                               -0.288693        0.011333
# cancelled_trip                         0.025727       -0.614673
# delay                                 -0.014333        0.989110
# no_delay                              -0.012602       -0.402726
# nan_delay                              0.024777       -0.631162
# departure_delay_float_new             -0.009274        0.221978
# time_span_afternoon                   -0.003991        0.147060
# time_span_early morning                0.000558        0.062012
# time_span_evening                     -0.011388        0.118687
# time_span_evening rush                -0.005213        0.188450
# time_span_lunch                       -0.016138        0.179477
# time_span_morning rush                 0.002962        0.190787
# time_span_until midday                -0.002055        0.138284
# weekday_Monday                        -0.193741       -0.011366
# weekday_Saturday                      -0.180304       -0.015185
# weekday_Sunday                        -0.120228        0.032863
# weekday_Thursday                      -0.169639       -0.011939
# weekday_Tuesday                       -0.169900        0.040312
# weekday_Wednesday                      1.000000       -0.013836
# delay_span_0-5                        -0.013836        1.000000
# delay_span_10-15                      -0.002126       -0.013160
# delay_span_15-20                      -0.002374       -0.020000
# delay_span_20-30                      -0.001174       -0.022267
# delay_span_30-45                      -0.001564       -0.018116
# delay_span_45-60                      -0.001611       -0.012464
# delay_span_5-10                        0.001669       -0.018742
#
#                               delay_span_10-15  delay_span_15-20  \
# route_type                            0.005625          0.008414
# stop_id                               0.030173         -0.004215
# service                              -0.001942         -0.002099
# transfer_stop                        -0.005749          0.002988
# nextbike_trips_count                 -0.003003         -0.003589
# current_temp                         -0.002046          0.000572
# current_precipitation_volume         -0.000857         -0.000513
# departure_delay_float                 0.091897          0.200583
# weather_int                          -0.000623         -0.000165
# weekend                               0.006153          0.003714
# cancelled_trip                       -0.013808         -0.020984
# delay                                 0.022365          0.033751
# no_delay                             -0.009216         -0.014005
# nan_delay                            -0.014178         -0.021314
# departure_delay_float_new             0.091854          0.197153
# time_span_afternoon                  -0.000245          0.001989
# time_span_early morning               0.008421          0.006550
# time_span_evening                     0.005786          0.007194
# time_span_evening rush                0.001101          0.004929
# time_span_lunch                       0.001742          0.005143
# time_span_morning rush                0.001631          0.002808
# time_span_until midday                0.001849          0.004096
# weekday_Monday                       -0.000838         -0.000653
# weekday_Saturday                      0.003038         -0.000009
# weekday_Sunday                        0.005781          0.004815
# weekday_Thursday                     -0.001795         -0.001256
# weekday_Tuesday                      -0.000653          0.001132
# weekday_Wednesday                    -0.002126         -0.002374
# delay_span_0-5                       -0.013160         -0.020000
# delay_span_10-15                      1.000000         -0.000449
# delay_span_15-20                     -0.000449          1.000000
# delay_span_20-30                     -0.000500         -0.000760
# delay_span_30-45                     -0.000407         -0.000618
# delay_span_45-60                     -0.000280         -0.000426
# delay_span_5-10                      -0.000421         -0.000640
#
#                               delay_span_20-30  delay_span_30-45  \
# route_type                            0.008273          0.007988
# stop_id                               0.014147         -0.006972
# service                              -0.007796         -0.034543
# transfer_stop                         0.011454          0.014965
# nextbike_trips_count                 -0.003144         -0.003580
# current_temp                         -0.001695         -0.021065
# current_precipitation_volume         -0.000959         -0.002646
# departure_delay_float                 0.245863          0.384454
# weather_int                          -0.001100         -0.004030
# weekend                              -0.000079          0.011069
# cancelled_trip                       -0.023364         -0.019007
# delay                                 0.018314          0.030305
# no_delay                             -0.015593         -0.012686
# nan_delay                            -0.004788         -0.019044
# departure_delay_float_new             0.194058          0.370359
# time_span_afternoon                  -0.002340         -0.006405
# time_span_early morning               0.010414          0.042033
# time_span_evening                    -0.000084         -0.005585
# time_span_evening rush               -0.001294         -0.008187
# time_span_lunch                      -0.000806         -0.007992
# time_span_morning rush               -0.003730         -0.008675
# time_span_until midday                0.000676         -0.006163
# weekday_Monday                       -0.001208         -0.003466
# weekday_Saturday                     -0.002832          0.003242
# weekday_Sunday                        0.002087          0.012219
# weekday_Thursday                      0.001206         -0.003376
# weekday_Tuesday                       0.001745         -0.000685
# weekday_Wednesday                    -0.001174         -0.001564
# delay_span_0-5                       -0.022267         -0.018116
# delay_span_10-15                     -0.000500         -0.000407
# delay_span_15-20                     -0.000760         -0.000618
# delay_span_20-30                      1.000000         -0.000689
# delay_span_30-45                     -0.000689          1.000000
# delay_span_45-60                     -0.000474         -0.000385
# delay_span_5-10                      -0.000712         -0.000580
#
#                               delay_span_45-60  delay_span_5-10
# route_type                            0.005451         0.008172
# stop_id                              -0.009670        -0.006247
# service                              -0.026784        -0.000539
# transfer_stop                        -0.004798        -0.002561
# nextbike_trips_count                  0.004147        -0.002867
# current_temp                         -0.014491         0.008926
# current_precipitation_volume         -0.002144        -0.000870
# departure_delay_float                 0.191557         0.058298
# weather_int                          -0.002951        -0.002118
# weekend                               0.006178        -0.007732
# cancelled_trip                       -0.013078        -0.019665
# delay                                -0.001931         0.031721
# no_delay                             -0.008728        -0.012972
# nan_delay                             0.009298        -0.020194
# departure_delay_float_new             0.099496         0.061623
# time_span_afternoon                  -0.004407         0.017195
# time_span_early morning               0.003180         0.000335
# time_span_evening                    -0.003843        -0.001216
# time_span_evening rush               -0.005633         0.007774
# time_span_lunch                      -0.005573         0.013514
# time_span_morning rush               -0.005968        -0.002614
# time_span_until midday               -0.004240         0.001073
# weekday_Monday                       -0.001686         0.001768
# weekday_Saturday                      0.001091        -0.006420
# weekday_Sunday                        0.007540        -0.003945
# weekday_Thursday                     -0.001466         0.000962
# weekday_Tuesday                       0.000013         0.004687
# weekday_Wednesday                    -0.001611         0.001669
# delay_span_0-5                       -0.012464        -0.018742
# delay_span_10-15                     -0.000280        -0.000421
# delay_span_15-20                     -0.000426        -0.000640
# delay_span_20-30                     -0.000474        -0.000712
# delay_span_30-45                     -0.000385        -0.000580
# delay_span_45-60                      1.000000        -0.000399
# delay_span_5-10                      -0.000399         1.000000
#
# [35 rows x 35 columns]

# %%
# Calculate the correlation matrix
corr_matrix = data_dummy.corr()

# Select the target variable (dependent variable)
target_variable = y_string

# Sort the correlation matrix by the absolute values of the correlation with the target variable
sorted_corr = corr_matrix[target_variable].abs().sort_values(ascending=False)

# Select the top k features with the highest correlation with the target variable
k = 10
selected_features = sorted_corr[1:k+1].index.tolist()

# Print the selected features
print("Selected features:")
print(selected_features)
# Out:
# Selected features:
# ['stop_id', 'no_delay', 'delay', 'current_temp', 'transfer_stop', 'delay_span_0-5', 'time_span_afternoon', 'weekend', 'weekday_Sunday', 'weather_int']

# %%
selected_features = data_dummy[selected_features]

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ### Best Model

# %%
X = selected_features
y = data[y_string]

standizer = StandardScaler()
X = standizer.fit_transform(X)

exog = sm.add_constant(X)
poission_model = sm.GLM(y, exog)
result = poission_model.fit()
print(result.summary())
# Out:
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564850
# Model Family:                  Gaussian   Df Model:                           10
# Link Function:                 Identity   Scale:                        0.072593
# Method:                            IRLS   Log-Likelihood:            -2.7571e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   1.8619e+05
# Time:                          18:19:10   Pearson chi2:                 1.86e+05
# No. Iterations:                       3   Pseudo R-squ. (CS):            0.01140
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0486      0.000    289.159      0.000       0.048       0.049
# x1            -0.0158      0.000    -93.674      0.000      -0.016      -0.015
# x2             0.0062      0.000     33.215      0.000       0.006       0.007
# x3            -0.0826      0.001    -71.892      0.000      -0.085      -0.080
# x4             0.0092      0.000     52.095      0.000       0.009       0.010
# x5             0.0093      0.000     55.063      0.000       0.009       0.010
# x6             0.0753      0.001     65.780      0.000       0.073       0.077
# x7             0.0071      0.000     40.087      0.000       0.007       0.007
# x8            -0.0050      0.000    -21.697      0.000      -0.005      -0.005
# x9            -0.0019      0.000     -8.377      0.000      -0.002      -0.001
# x10           -0.0033      0.000    -19.042      0.000      -0.004      -0.003
# ==============================================================================

# %%
X = data_dummy.drop(columns=["nextbike_trips_count", "departure_delay_float"])
y = data[y_string]

standizer = StandardScaler()
X = standizer.fit_transform(X)

exog = sm.add_constant(X)
poission_model = sm.GLM(y, exog)
result = poission_model.fit()
print(result.summary())
# Out:
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564829
# Model Family:                  Gaussian   Df Model:                           31
# Link Function:                 Identity   Scale:                        0.072431
# Method:                            IRLS   Log-Likelihood:            -2.7283e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   1.8577e+05
# Time:                          18:19:04   Pearson chi2:                 1.86e+05
# No. Iterations:                     100   Pseudo R-squ. (CS):            0.01365
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0485      0.000    208.259      0.000       0.048       0.049
# x1            -0.0032      0.000    -18.756      0.000      -0.004      -0.003
# x2            -0.0157      0.000    -92.878      0.000      -0.016      -0.015
# x3         -7.454e-05      0.000     -0.432      0.665      -0.000       0.000
# x4             0.0092      0.000     54.412      0.000       0.009       0.010
# x5             0.0074      0.000     37.101      0.000       0.007       0.008
# x6             0.0006      0.000      2.746      0.006       0.000       0.001
# x7            -0.0037      0.000    -15.860      0.000      -0.004      -0.003
# x8          2.867e+10   4.69e+10      0.611      0.541   -6.33e+10    1.21e+11
# x9            -0.0110      0.001    -15.544      0.000      -0.012      -0.010
# x10         -2.04e+09   3.34e+09     -0.611      0.541   -8.58e+09     4.5e+09
# x11        -1.759e+09   2.88e+09     -0.611      0.541    -7.4e+09    3.88e+09
# x12        -2.075e+09    3.4e+09     -0.611      0.541   -8.73e+09    4.58e+09
# x13            0.0029      0.000     13.960      0.000       0.002       0.003
# x14            0.0129      0.000     51.536      0.000       0.012       0.013
# x15            0.0024      0.000     12.548      0.000       0.002       0.003
# x16            0.0031      0.000     13.668      0.000       0.003       0.004
# x17            0.0081      0.000     29.080      0.000       0.008       0.009
# x18            0.0093      0.000     33.753      0.000       0.009       0.010
# x19            0.0070      0.000     25.263      0.000       0.006       0.008
# x20            0.0065      0.000     27.220      0.000       0.006       0.007
# x21         1.103e+10   1.81e+10      0.611      0.541   -2.43e+10    4.64e+10
# x22        -1.052e+10   1.72e+10     -0.611      0.541   -4.43e+10    2.32e+10
# x23         -1.54e+10   2.52e+10     -0.611      0.541   -6.48e+10     3.4e+10
# x24         1.008e+10   1.65e+10      0.611      0.541   -2.23e+10    4.24e+10
# x25         1.009e+10   1.65e+10      0.611      0.541   -2.23e+10    4.25e+10
# x26         1.009e+10   1.65e+10      0.611      0.541   -2.23e+10    4.25e+10
# x27            0.1397      0.002     84.935      0.000       0.136       0.143
# x28            0.0048      0.000     26.964      0.000       0.004       0.005
# x29            0.0063      0.000     33.072      0.000       0.006       0.007
# x30            0.0045      0.000     24.722      0.000       0.004       0.005
# x31            0.0055      0.000     27.967      0.000       0.005       0.006
# x32            0.0023      0.000     13.370      0.000       0.002       0.003
# x33            0.0061      0.000     32.564      0.000       0.006       0.006
# ==============================================================================

# %% [markdown]
# ### Other

# %%
short_data = data[['departure_delay', y_string]].copy()
short_data['departure_delay'] = pd.to_numeric(short_data['departure_delay'])

# %%
model = smf.ols(formula='nextbike_trips_count ~ departure_delay', data=short_data).fit()
print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   R-squared:                      -0.019
# Model:                              OLS   Adj. R-squared:                 -0.019
# Method:                   Least Squares   F-statistic:                       nan
# Date:                  Fri, 13 Sep 2024   Prob (F-statistic):                nan
# Time:                          18:08:43   Log-Likelihood:            -3.1426e+05
# No. Observations:               2564861   AIC:                         6.285e+05
# Df Residuals:                   2564860   BIC:                         6.285e+05
# Df Model:                             0
# Covariance Type:              nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept        5.784e-40   3.15e-42    183.653      0.000    5.72e-40    5.85e-40
# departure_delay -5.335e-21    2.9e-23   -183.653      0.000   -5.39e-21   -5.28e-21
# ==============================================================================
# Omnibus:                  3534310.709   Durbin-Watson:                   1.941
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1139923981.965
# Skew:                           8.024   Prob(JB):                         0.00
# Kurtosis:                     105.024   Cond. No.                     7.63e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.63e+18. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
model = smf.ols(formula='nextbike_trips_count ~ departure_delay_float', data=data).fit()
print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   R-squared:                       0.000
# Model:                              OLS   Adj. R-squared:                  0.000
# Method:                   Least Squares   F-statistic:                     147.4
# Date:                  Fri, 13 Sep 2024   Prob (F-statistic):           6.49e-34
# Time:                          18:08:43   Log-Likelihood:            -1.5568e+05
# No. Observations:               1522668   AIC:                         3.114e+05
# Df Residuals:                   1522666   BIC:                         3.114e+05
# Df Model:                             1
# Covariance Type:              nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.0487      0.000    221.406      0.000       0.048       0.049
# departure_delay_float    -0.0009    7.3e-05    -12.140      0.000      -0.001      -0.001
# ==============================================================================
# Omnibus:                  2094870.266   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        646213130.270
# Skew:                           8.020   Prob(JB):                         0.00
# Kurtosis:                     102.640   Cond. No.                         3.06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model = smf.ols(formula='nextbike_trips_count ~ departure_delay_new', data=data).fit()
print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   R-squared:                       0.004
# Model:                              OLS   Adj. R-squared:                  0.004
# Method:                   Least Squares   F-statistic:                     53.54
# Date:                  Fri, 13 Sep 2024   Prob (F-statistic):               0.00
# Time:                          18:10:04   Log-Likelihood:            -2.8555e+05
# No. Observations:               2564861   AIC:                         5.715e+05
# Df Residuals:                   2564681   BIC:                         5.738e+05
# Df Model:                           179
# Covariance Type:              nonrobust
# =======================================================================================================================
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# Intercept                                               0.0492      0.000    185.714      0.000       0.049       0.050
# departure_delay_new[T.Timedelta('0 days 00:00:00')]     0.0207      0.000     46.499      0.000       0.020       0.022
# departure_delay_new[T.Timedelta('0 days 00:00:10')]    -0.0264      0.002    -14.413      0.000      -0.030      -0.023
# departure_delay_new[T.Timedelta('0 days 00:00:15')]    -0.0110      0.001    -18.188      0.000      -0.012      -0.010
# departure_delay_new[T.Timedelta('0 days 00:00:20')]    -0.0132      0.002     -6.695      0.000      -0.017      -0.009
# departure_delay_new[T.Timedelta('0 days 00:00:30')]    -0.0176      0.001    -31.174      0.000      -0.019      -0.016
# departure_delay_new[T.Timedelta('0 days 00:00:40')]    -0.0035      0.002     -1.619      0.105      -0.008       0.001
# departure_delay_new[T.Timedelta('0 days 00:00:45')]    -0.0152      0.001    -27.177      0.000      -0.016      -0.014
# departure_delay_new[T.Timedelta('0 days 00:00:50')]    -0.0257      0.003     -9.601      0.000      -0.031      -0.020
# departure_delay_new[T.Timedelta('0 days 00:00:59')]    -0.0492      0.029     -1.677      0.094      -0.107       0.008
# departure_delay_new[T.Timedelta('0 days 00:01:00')]     0.0147      0.004      4.141      0.000       0.008       0.022
# departure_delay_new[T.Timedelta('0 days 00:01:15')]     0.0476      0.006      7.991      0.000       0.036       0.059
# departure_delay_new[T.Timedelta('0 days 00:01:30')]    -0.0190      0.011     -1.812      0.070      -0.040       0.002
# departure_delay_new[T.Timedelta('0 days 00:01:45')]    -0.0159      0.009     -1.765      0.078      -0.034       0.002
# departure_delay_new[T.Timedelta('0 days 00:02:00')]     0.0418      0.004     11.247      0.000       0.035       0.049
# departure_delay_new[T.Timedelta('0 days 00:02:15')]    -0.0091      0.010     -0.904      0.366      -0.029       0.011
# departure_delay_new[T.Timedelta('0 days 00:02:30')]    -0.0048      0.007     -0.701      0.483      -0.018       0.009
# departure_delay_new[T.Timedelta('0 days 00:02:45')]    -0.0132      0.014     -0.963      0.335      -0.040       0.014
# departure_delay_new[T.Timedelta('0 days 00:03:00')]    -0.0167      0.004     -4.354      0.000      -0.024      -0.009
# departure_delay_new[T.Timedelta('0 days 00:03:15')]     0.3749      0.007     52.748      0.000       0.361       0.389
# departure_delay_new[T.Timedelta('0 days 00:03:30')]    -0.0459      0.016     -2.948      0.003      -0.076      -0.015
# departure_delay_new[T.Timedelta('0 days 00:03:45')]    -0.0492      0.020     -2.501      0.012      -0.088      -0.011
# departure_delay_new[T.Timedelta('0 days 00:04:00')]    -0.0053      0.007     -0.751      0.453      -0.019       0.009
# departure_delay_new[T.Timedelta('0 days 00:04:15')]    -0.0445      0.013     -3.396      0.001      -0.070      -0.019
# departure_delay_new[T.Timedelta('0 days 00:04:30')]    -0.0057      0.056     -0.102      0.919      -0.116       0.105
# departure_delay_new[T.Timedelta('0 days 00:04:45')]    -0.0386      0.009     -4.161      0.000      -0.057      -0.020
# departure_delay_new[T.Timedelta('0 days 00:05:00')]    -0.0176      0.007     -2.666      0.008      -0.031      -0.005
# departure_delay_new[T.Timedelta('0 days 00:05:15')]     0.0014      0.030      0.047      0.963      -0.058       0.061
# departure_delay_new[T.Timedelta('0 days 00:05:30')]     0.0528      0.039      1.367      0.171      -0.023       0.129
# departure_delay_new[T.Timedelta('0 days 00:05:45')]    -0.0269      0.007     -4.096      0.000      -0.040      -0.014
# departure_delay_new[T.Timedelta('0 days 00:06:00')]    -0.0407      0.012     -3.276      0.001      -0.065      -0.016
# departure_delay_new[T.Timedelta('0 days 00:06:30')]    -0.0492      0.037     -1.337      0.181      -0.121       0.023
# departure_delay_new[T.Timedelta('0 days 00:06:45')]    -0.0492      0.052     -0.945      0.345      -0.151       0.053
# departure_delay_new[T.Timedelta('0 days 00:07:00')]    -0.0075      0.055     -0.137      0.891      -0.116       0.101
# departure_delay_new[T.Timedelta('0 days 00:07:20')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 00:08:00')]    -0.0492      0.066     -0.750      0.453      -0.178       0.079
# departure_delay_new[T.Timedelta('0 days 00:09:00')]    -0.0492      0.121     -0.407      0.684      -0.286       0.188
# departure_delay_new[T.Timedelta('0 days 00:09:15')]    -0.0492      0.064     -0.772      0.440      -0.174       0.076
# departure_delay_new[T.Timedelta('0 days 00:09:20')]    -0.0492      0.191     -0.257      0.797      -0.424       0.326
# departure_delay_new[T.Timedelta('0 days 00:10:00')]    -0.0492      0.156     -0.315      0.753      -0.355       0.257
# departure_delay_new[T.Timedelta('0 days 00:10:30')]    -0.0492      0.037     -1.337      0.181      -0.121       0.023
# departure_delay_new[T.Timedelta('0 days 00:10:40')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 00:11:00')]    -0.0492      0.048     -1.029      0.303      -0.143       0.045
# departure_delay_new[T.Timedelta('0 days 00:11:40')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 00:12:00')]    -0.0492      0.046     -1.076      0.282      -0.139       0.040
# departure_delay_new[T.Timedelta('0 days 00:12:15')]    -0.0466      0.014     -3.371      0.001      -0.074      -0.019
# departure_delay_new[T.Timedelta('0 days 00:12:40')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 00:13:40')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 00:13:45')]    -0.0492      0.036     -1.349      0.177      -0.121       0.022
# departure_delay_new[T.Timedelta('0 days 00:14:00')]    -0.0492      0.040     -1.220      0.222      -0.128       0.030
# departure_delay_new[T.Timedelta('0 days 00:14:15')]    -0.0492      0.052     -0.945      0.345      -0.151       0.053
# departure_delay_new[T.Timedelta('0 days 00:14:30')]    -0.0492      0.024     -2.050      0.040      -0.096      -0.002
# departure_delay_new[T.Timedelta('0 days 00:15:40')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 00:15:45')]    -0.0492      0.016     -3.065      0.002      -0.081      -0.018
# departure_delay_new[T.Timedelta('0 days 00:16:00')]    -0.0492      0.048     -1.029      0.303      -0.143       0.045
# departure_delay_new[T.Timedelta('0 days 00:16:15')]    -0.0398      0.026     -1.514      0.130      -0.091       0.012
# departure_delay_new[T.Timedelta('0 days 00:16:40')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 00:16:45')]    -0.0492      0.037     -1.337      0.181      -0.121       0.023
# departure_delay_new[T.Timedelta('0 days 00:17:15')]    -0.0135      0.051     -0.264      0.792      -0.114       0.087
# departure_delay_new[T.Timedelta('0 days 00:17:45')]    -0.0414      0.017     -2.455      0.014      -0.074      -0.008
# departure_delay_new[T.Timedelta('0 days 00:18:00')]    -0.0492      0.052     -0.945      0.345      -0.151       0.053
# departure_delay_new[T.Timedelta('0 days 00:18:15')]    -0.0492      0.028     -1.764      0.078      -0.104       0.005
# departure_delay_new[T.Timedelta('0 days 00:18:30')]    -0.0492      0.024     -2.082      0.037      -0.096      -0.003
# departure_delay_new[T.Timedelta('0 days 00:18:45')]    -0.0062      0.017     -0.369      0.712      -0.039       0.027
# departure_delay_new[T.Timedelta('0 days 00:19:00')]     0.0417      0.082      0.511      0.609      -0.118       0.202
# departure_delay_new[T.Timedelta('0 days 00:19:30')]     0.1730      0.090      1.919      0.055      -0.004       0.350
# departure_delay_new[T.Timedelta('0 days 00:19:45')]    -0.0492      0.041     -1.207      0.228      -0.129       0.031
# departure_delay_new[T.Timedelta('0 days 00:20:00')]    -0.0492      0.020     -2.474      0.013      -0.088      -0.010
# departure_delay_new[T.Timedelta('0 days 00:20:15')]    -0.0492      0.018     -2.788      0.005      -0.084      -0.015
# departure_delay_new[T.Timedelta('0 days 00:20:30')]    -0.0492      0.060     -0.814      0.416      -0.168       0.069
# departure_delay_new[T.Timedelta('0 days 00:21:00')]     0.0619      0.090      0.687      0.492      -0.115       0.239
# departure_delay_new[T.Timedelta('0 days 00:21:30')]    -0.0492      0.135     -0.364      0.716      -0.314       0.216
# departure_delay_new[T.Timedelta('0 days 00:21:45')]    -0.0492      0.041     -1.207      0.228      -0.129       0.031
# departure_delay_new[T.Timedelta('0 days 00:22:00')]    -0.0492      0.012     -4.115      0.000      -0.073      -0.026
# departure_delay_new[T.Timedelta('0 days 00:22:15')]     0.0239      0.017      1.423      0.155      -0.009       0.057
# departure_delay_new[T.Timedelta('0 days 00:24:00')]    -0.0492      0.017     -2.887      0.004      -0.083      -0.016
# departure_delay_new[T.Timedelta('0 days 00:24:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 00:25:00')]    -0.0492      0.090     -0.546      0.585      -0.226       0.128
# departure_delay_new[T.Timedelta('0 days 00:25:15')]    -0.0492      0.110     -0.446      0.656      -0.266       0.167
# departure_delay_new[T.Timedelta('0 days 00:25:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 00:26:00')]    -0.0492      0.090     -0.546      0.585      -0.226       0.128
# departure_delay_new[T.Timedelta('0 days 00:27:00')]    -0.0492      0.110     -0.446      0.656      -0.266       0.167
# departure_delay_new[T.Timedelta('0 days 00:27:15')]    -0.0492      0.096     -0.515      0.607      -0.237       0.138
# departure_delay_new[T.Timedelta('0 days 00:27:30')]    -0.0492      0.110     -0.446      0.656      -0.266       0.167
# departure_delay_new[T.Timedelta('0 days 00:28:00')]    -0.0492      0.090     -0.546      0.585      -0.226       0.128
# departure_delay_new[T.Timedelta('0 days 00:29:15')]    -0.0492      0.030     -1.617      0.106      -0.109       0.010
# departure_delay_new[T.Timedelta('0 days 00:29:45')]    -0.0492      0.031     -1.565      0.118      -0.111       0.012
# departure_delay_new[T.Timedelta('0 days 00:30:00')]    -0.0492      0.036     -1.385      0.166      -0.119       0.020
# departure_delay_new[T.Timedelta('0 days 00:30:15')]    -0.0492      0.030     -1.647      0.100      -0.108       0.009
# departure_delay_new[T.Timedelta('0 days 00:31:00')]    -0.0492      0.121     -0.407      0.684      -0.286       0.188
# departure_delay_new[T.Timedelta('0 days 00:31:15')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 00:31:30')]    -0.0492      0.031     -1.575      0.115      -0.110       0.012
# departure_delay_new[T.Timedelta('0 days 00:31:45')]    -0.0492      0.051     -0.963      0.336      -0.149       0.051
# departure_delay_new[T.Timedelta('0 days 00:32:15')]    -0.0492      0.135     -0.364      0.716      -0.314       0.216
# departure_delay_new[T.Timedelta('0 days 00:32:30')]    -0.0492      0.191     -0.257      0.797      -0.424       0.326
# departure_delay_new[T.Timedelta('0 days 00:32:45')]    -0.0492      0.102     -0.481      0.630      -0.250       0.151
# departure_delay_new[T.Timedelta('0 days 00:33:30')]    -0.0492      0.121     -0.407      0.684      -0.286       0.188
# departure_delay_new[T.Timedelta('0 days 00:33:45')]    -0.0492      0.023     -2.137      0.033      -0.094      -0.004
# departure_delay_new[T.Timedelta('0 days 00:34:00')]    -0.0492      0.135     -0.364      0.716      -0.314       0.216
# departure_delay_new[T.Timedelta('0 days 00:34:15')]    -0.0492      0.030     -1.637      0.102      -0.108       0.010
# departure_delay_new[T.Timedelta('0 days 00:34:45')]    -0.0492      0.135     -0.364      0.716      -0.314       0.216
# departure_delay_new[T.Timedelta('0 days 00:35:30')]    -0.0492      0.191     -0.257      0.797      -0.424       0.326
# departure_delay_new[T.Timedelta('0 days 00:35:45')]    -0.0420      0.023     -1.831      0.067      -0.087       0.003
# departure_delay_new[T.Timedelta('0 days 00:36:00')]    -0.0290      0.027     -1.067      0.286      -0.082       0.024
# departure_delay_new[T.Timedelta('0 days 00:36:30')]    -0.0369      0.030     -1.226      0.220      -0.096       0.022
# departure_delay_new[T.Timedelta('0 days 00:36:45')]    -0.0492      0.090     -0.546      0.585      -0.226       0.128
# departure_delay_new[T.Timedelta('0 days 00:37:45')]    -0.0492      0.027     -1.855      0.064      -0.101       0.003
# departure_delay_new[T.Timedelta('0 days 00:38:00')]    -0.0492      0.051     -0.963      0.336      -0.149       0.051
# departure_delay_new[T.Timedelta('0 days 00:38:15')]    -0.0492      0.121     -0.407      0.684      -0.286       0.188
# departure_delay_new[T.Timedelta('0 days 00:38:45')]    -0.0492      0.135     -0.364      0.716      -0.314       0.216
# departure_delay_new[T.Timedelta('0 days 00:39:30')]    -0.0492      0.040     -1.220      0.222      -0.128       0.030
# departure_delay_new[T.Timedelta('0 days 00:39:45')]    -0.0492      0.035     -1.409      0.159      -0.118       0.019
# departure_delay_new[T.Timedelta('0 days 00:40:15')]    -0.0254      0.030     -0.860      0.390      -0.083       0.032
# departure_delay_new[T.Timedelta('0 days 00:40:30')]    -0.0492      0.121     -0.407      0.684      -0.286       0.188
# departure_delay_new[T.Timedelta('0 days 00:41:00')]    -0.0492      0.156     -0.315      0.753      -0.355       0.257
# departure_delay_new[T.Timedelta('0 days 00:41:15')]    -0.0492      0.040     -1.220      0.222      -0.128       0.030
# departure_delay_new[T.Timedelta('0 days 00:41:30')]    -0.0492      0.049     -1.013      0.311      -0.144       0.046
# departure_delay_new[T.Timedelta('0 days 00:41:50')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 00:42:00')]    -0.0267      0.029     -0.932      0.351      -0.083       0.029
# departure_delay_new[T.Timedelta('0 days 00:42:30')]    -0.0492      0.121     -0.407      0.684      -0.286       0.188
# departure_delay_new[T.Timedelta('0 days 00:43:00')]    -0.0492      0.022     -2.250      0.024      -0.092      -0.006
# departure_delay_new[T.Timedelta('0 days 00:44:30')]    -0.0492      0.044     -1.121      0.262      -0.135       0.037
# departure_delay_new[T.Timedelta('0 days 00:45:00')]     0.0079      0.046      0.174      0.862      -0.082       0.098
# departure_delay_new[T.Timedelta('0 days 00:45:30')]    -0.0159      0.049     -0.321      0.748      -0.113       0.081
# departure_delay_new[T.Timedelta('0 days 00:45:45')]    -0.0492      0.156     -0.315      0.753      -0.355       0.257
# departure_delay_new[T.Timedelta('0 days 00:46:30')]    -0.0492      0.191     -0.257      0.797      -0.424       0.326
# departure_delay_new[T.Timedelta('0 days 00:46:45')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 00:47:15')]    -0.0492      0.036     -1.349      0.177      -0.121       0.022
# departure_delay_new[T.Timedelta('0 days 00:47:30')]    -0.0492      0.191     -0.257      0.797      -0.424       0.326
# departure_delay_new[T.Timedelta('0 days 00:48:30')]    -0.0492      0.191     -0.257      0.797      -0.424       0.326
# departure_delay_new[T.Timedelta('0 days 00:49:00')]    -0.0310      0.036     -0.851      0.395      -0.103       0.040
# departure_delay_new[T.Timedelta('0 days 00:50:30')]     0.4508      0.191      2.357      0.018       0.076       0.826
# departure_delay_new[T.Timedelta('0 days 00:50:45')]    -0.0492      0.110     -0.446      0.656      -0.266       0.167
# departure_delay_new[T.Timedelta('0 days 00:51:30')]    -0.0310      0.036     -0.851      0.395      -0.103       0.040
# departure_delay_new[T.Timedelta('0 days 01:03:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:04:30')]    -0.0492      0.191     -0.257      0.797      -0.424       0.326
# departure_delay_new[T.Timedelta('0 days 01:06:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:07:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:08:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:09:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:10:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:11:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:12:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:13:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:14:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:15:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:16:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:17:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:18:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:19:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:20:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:22:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:23:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:26:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:27:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:28:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:29:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:30:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:32:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:33:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:35:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:37:30')]    -0.0492      0.191     -0.257      0.797      -0.424       0.326
# departure_delay_new[T.Timedelta('0 days 01:38:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:39:30')]    -0.0492      0.270     -0.182      0.856      -0.579       0.481
# departure_delay_new[T.Timedelta('0 days 01:41:30')]    -0.0492      0.135     -0.364      0.716      -0.314       0.216
# departure_delay_new[T.Timedelta('0 days 01:42:30')]    -0.0492      0.191     -0.257      0.797      -0.424       0.326
# departure_delay_new[T.Timedelta('0 days 01:44:30')]    -0.0492      0.191     -0.257      0.797      -0.424       0.326
# departure_delay_new[T.Timedelta('0 days 01:45:30')]    -0.0492      0.191     -0.257      0.797      -0.424       0.326
# departure_delay_new[T.Timedelta('0 days 01:46:30')]    -0.0492      0.191     -0.257      0.797      -0.424       0.326
# departure_delay_new[T.Timedelta('0 days 01:47:30')]    -0.0492      0.191     -0.257      0.797      -0.424       0.326
# departure_delay_new[T.Timedelta('0 days 01:48:30')]    -0.0492      0.191     -0.257      0.797      -0.424       0.326
# departure_delay_new[T.Timedelta('0 days 01:49:30')]    -0.0492      0.191     -0.257      0.797      -0.424       0.326
# departure_delay_new[T.Timedelta('0 days 01:50:30')]    -0.0492      0.135     -0.364      0.716      -0.314       0.216
# departure_delay_new[T.Timedelta('0 days 01:51:30')]    -0.0492      0.156     -0.315      0.753      -0.355       0.257
# departure_delay_new[T.Timedelta('0 days 01:52:30')]    -0.0492      0.191     -0.257      0.797      -0.424       0.326
# departure_delay_new[T.Timedelta('0 days 08:30:00')]    -0.0492      0.102     -0.481      0.630      -0.250       0.151
# departure_delay_new[T.Timedelta('0 days 08:30:15')]    -0.0492      0.110     -0.446      0.656      -0.266       0.167
# departure_delay_new[T.Timedelta('0 days 08:30:30')]    -0.0492      0.086     -0.575      0.565      -0.217       0.118
# departure_delay_new[T.Timedelta('0 days 08:30:45')]    -0.0492      0.086     -0.575      0.565      -0.217       0.118
# departure_delay_new[T.Timedelta('1 days 00:00:00')]    -0.0315      0.010     -3.037      0.002      -0.052      -0.011
# ==============================================================================
# Omnibus:                  3552865.141   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1175171722.401
# Skew:                           8.098   Prob(JB):                         0.00
# Kurtosis:                     106.605   Cond. No.                     1.68e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.68e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
model = smf.ols(formula='nextbike_trips_count ~ departure_delay_float_new', data=data).fit()
print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   R-squared:                       0.000
# Model:                              OLS   Adj. R-squared:                  0.000
# Method:                   Least Squares   F-statistic:                     150.6
# Date:                  Fri, 13 Sep 2024   Prob (F-statistic):           1.27e-34
# Time:                          18:10:06   Log-Likelihood:            -2.9026e+05
# No. Observations:               2564861   AIC:                         5.805e+05
# Df Residuals:                   2564859   BIC:                         5.805e+05
# Df Model:                             1
# Covariance Type:              nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     0.0485      0.000    286.455      0.000       0.048       0.049
# departure_delay_float_new    -0.0009   7.04e-05    -12.273      0.000      -0.001      -0.001
# ==============================================================================
# Omnibus:                  3558423.163   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1178302443.002
# Skew:                           8.123   Prob(JB):                         0.00
# Kurtosis:                     106.739   Cond. No.                         2.41
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model = smf.ols(formula='tier_trips_count ~ delay_span', data=data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       tier_trips_count   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     338.6
# Date:                Fri, 13 Sep 2024   Prob (F-statistic):               0.00
# Time:                        18:10:19   Log-Likelihood:             1.1174e+06
# No. Observations:             2564861   AIC:                        -2.235e+06
# Df Residuals:                 2564853   BIC:                        -2.235e+06
# Df Model:                           7
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.0228      0.000    184.720      0.000       0.023       0.023
# delay_span[T.0-5]      -0.0083      0.000    -41.163      0.000      -0.009      -0.008
# delay_span[T.10-15]    -0.0188      0.006     -3.312      0.001      -0.030      -0.008
# delay_span[T.15-20]    -0.0056      0.004     -1.509      0.131      -0.013       0.002
# delay_span[T.20-30]    -0.0085      0.003     -2.528      0.011      -0.015      -0.002
# delay_span[T.30-45]     0.0002      0.004      0.045      0.964      -0.008       0.008
# delay_span[T.45-60]     0.1507      0.006     25.108      0.000       0.139       0.163
# delay_span[T.5-10]     -0.0143      0.004     -3.589      0.000      -0.022      -0.007
# ==============================================================================
# Omnibus:                  3944343.030   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1930458076.818
# Skew:                           9.846   Prob(JB):                         0.00
# Kurtosis:                     135.951   Cond. No.                         66.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model = smf.ols(formula='nextbike_trips_count ~ cancelled_trip', data=data).fit()
print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   R-squared:                       0.000
# Model:                              OLS   Adj. R-squared:                  0.000
# Method:                   Least Squares   F-statistic:                     11.60
# Date:                  Fri, 13 Sep 2024   Prob (F-statistic):           0.000658
# Time:                          18:10:21   Log-Likelihood:            -2.9033e+05
# No. Observations:               2564861   AIC:                         5.807e+05
# Df Residuals:                   2564859   BIC:                         5.807e+05
# Df Model:                             1
# Covariance Type:              nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          0.0491      0.000    226.309      0.000       0.049       0.050
# cancelled_trip    -0.0012      0.000     -3.407      0.001      -0.002      -0.001
# ==============================================================================
# Omnibus:                  3558565.355   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1178513557.264
# Skew:                           8.124   Prob(JB):                         0.00
# Kurtosis:                     106.748   Cond. No.                         2.44
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model = smf.ols(formula='nextbike_trips_count ~ delay', data=data).fit()
print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   R-squared:                       0.001
# Model:                              OLS   Adj. R-squared:                  0.001
# Method:                   Least Squares   F-statistic:                     3703.
# Date:                  Fri, 13 Sep 2024   Prob (F-statistic):               0.00
# Time:                          18:10:23   Log-Likelihood:            -2.8848e+05
# No. Observations:               2564861   AIC:                         5.770e+05
# Df Residuals:                   2564859   BIC:                         5.770e+05
# Df Model:                             1
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0565      0.000    265.321      0.000       0.056       0.057
# delay         -0.0213      0.000    -60.848      0.000      -0.022      -0.021
# ==============================================================================
# Omnibus:                  3554774.969   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1173590233.153
# Skew:                           8.108   Prob(JB):                         0.00
# Kurtosis:                     106.531   Cond. No.                         2.43
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model = smf.ols(formula='nextbike_trips_count ~ no_delay', data=data).fit()
print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   R-squared:                       0.002
# Model:                              OLS   Adj. R-squared:                  0.002
# Method:                   Least Squares   F-statistic:                     4539.
# Date:                  Fri, 13 Sep 2024   Prob (F-statistic):               0.00
# Time:                          18:10:24   Log-Likelihood:            -2.8807e+05
# No. Observations:               2564861   AIC:                         5.761e+05
# Df Residuals:                   2564859   BIC:                         5.762e+05
# Df Model:                             1
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0425      0.000    221.808      0.000       0.042       0.043
# no_delay       0.0274      0.000     67.371      0.000       0.027       0.028
# ==============================================================================
# Omnibus:                  3554498.330   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1173886345.898
# Skew:                           8.106   Prob(JB):                         0.00
# Kurtosis:                     106.545   Cond. No.                         2.54
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model = smf.ols(formula='nextbike_trips_count ~ nan_delay', data=data).fit()
print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   R-squared:                       0.000
# Model:                              OLS   Adj. R-squared:                  0.000
# Method:                   Least Squares   F-statistic:                     7.424
# Date:                  Fri, 13 Sep 2024   Prob (F-statistic):            0.00643
# Time:                          18:10:25   Log-Likelihood:            -2.9033e+05
# No. Observations:               2564861   AIC:                         5.807e+05
# Df Residuals:                   2564859   BIC:                         5.807e+05
# Df Model:                             1
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0483      0.000    219.793      0.000       0.048       0.049
# nan_delay      0.0009      0.000      2.725      0.006       0.000       0.002
# ==============================================================================
# Omnibus:                  3558534.269   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1178430330.717
# Skew:                           8.124   Prob(JB):                         0.00
# Kurtosis:                     106.744   Cond. No.                         2.46
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model = smf.ols(formula='nextbike_trips_count ~ nan_delay', data=data).fit()
print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   R-squared:                       0.000
# Model:                              OLS   Adj. R-squared:                  0.000
# Method:                   Least Squares   F-statistic:                     7.424
# Date:                  Fri, 13 Sep 2024   Prob (F-statistic):            0.00643
# Time:                          18:10:27   Log-Likelihood:            -2.9033e+05
# No. Observations:               2564861   AIC:                         5.807e+05
# Df Residuals:                   2564859   BIC:                         5.807e+05
# Df Model:                             1
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0483      0.000    219.793      0.000       0.048       0.049
# nan_delay      0.0009      0.000      2.725      0.006       0.000       0.002
# ==============================================================================
# Omnibus:                  3558534.269   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1178430330.717
# Skew:                           8.124   Prob(JB):                         0.00
# Kurtosis:                     106.744   Cond. No.                         2.46
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X = data[['departure_delay_float_new', 'current_temp', 'current_precipitation_volume', 'service', 'delay_span_int', 'time_span_int', 'weekend', 'delay_category', 'cancelled_trip', 'delay', 'no_delay', 'nan_delay']]
y = data[y_string]

standizer = StandardScaler()
X = standizer.fit_transform(X)

exog = sm.add_constant(X)
poission_model = sm.OLS(y, exog)
result = poission_model.fit()
print(result.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   R-squared:                       0.005
# Model:                              OLS   Adj. R-squared:                  0.005
# Method:                   Least Squares   F-statistic:                     1136.
# Date:                  Fri, 13 Sep 2024   Prob (F-statistic):               0.00
# Time:                          18:10:32   Log-Likelihood:            -2.8410e+05
# No. Observations:               2564861   AIC:                         5.682e+05
# Df Residuals:                   2564849   BIC:                         5.684e+05
# Df Model:                            11
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0486      0.000    288.215      0.000       0.048       0.049
# x1            -0.0017      0.000     -8.605      0.000      -0.002      -0.001
# x2             0.0106      0.000     60.636      0.000       0.010       0.011
# x3            -0.0014      0.000     -8.326      0.000      -0.002      -0.001
# x4             0.0014      0.000      8.355      0.000       0.001       0.002
# x5             0.0076      0.000     16.982      0.000       0.007       0.008
# x6             0.0031      0.000     13.045      0.000       0.003       0.004
# x7            -0.0064      0.000    -37.460      0.000      -0.007      -0.006
# x8             0.0015      0.000      4.204      0.000       0.001       0.002
# x9            -0.0151      0.001    -20.325      0.000      -0.017      -0.014
# x10           -0.0181      0.000    -50.239      0.000      -0.019      -0.017
# x11            0.0054      0.000     17.584      0.000       0.005       0.006
# x12            0.0132      0.000     28.722      0.000       0.012       0.014
# ==============================================================================
# Omnibus:                  3548324.703   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1168118003.994
# Skew:                           8.079   Prob(JB):                         0.00
# Kurtosis:                     106.292   Cond. No.                     1.31e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.82e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
data_dummy.isna().any()
# Out:
# route_type                      False
# stop_id                         False
# service                         False
# transfer_stop                   False
# nextbike_trips_count            False
# current_temp                    False
# current_precipitation_volume    False
# departure_delay_float            True
# weather_int                     False
# weekend                         False
# cancelled_trip                  False
# delay                           False
# no_delay                        False
# nan_delay                       False
# departure_delay_float_new       False
# time_span_afternoon             False
# time_span_early morning         False
# time_span_evening               False
# time_span_evening rush          False
# time_span_lunch                 False
# time_span_morning rush          False
# time_span_until midday          False
# weekday_Monday                  False
# weekday_Saturday                False
# weekday_Sunday                  False
# weekday_Thursday                False
# weekday_Tuesday                 False
# weekday_Wednesday               False
# delay_span_0-5                  False
# delay_span_10-15                False
# delay_span_15-20                False
# delay_span_20-30                False
# delay_span_30-45                False
# delay_span_45-60                False
# delay_span_5-10                 False
# dtype: bool

# %% [markdown]
# # Poisson Regression

# %% [markdown]
# ### Best Model

# %%
agg_station_date_10min = data.groupby(['stop_id', 'stop_name', pd.Grouper(key='scheduled_arrival_time', freq='10Min')]).sum(numeric_only=True)

# %%
agg_station_date_10min.isna().any()
# Out:
# route_id                               False
# agency_id                              False
# route_type                             False
# service_id                             False
# direction_id                           False
# shape_id                               False
# vrs_timestamp                          False
# stop_sequence                          False
# service                                False
# transfer_stop                          False
# tier_trips_count                       False
# tier_trips_end_at_station_count        False
# nextbike_trips_count                   False
# nextbike_trips_end_at_station_count    False
# current_temp                           False
# current_feels_like                     False
# current_cloudiness                     False
# current_visibility                     False
# current_wind_speed                     False
# current_precipitation_volume           False
# arrival_delay_float                    False
# departure_delay_float                  False
# actual_arrival_time_float              False
# actual_departure_time_float            False
# arrival_delay_span                     False
# weather_int                            False
# time_span_int_arrival                  False
# weekend                                False
# time_span_int                          False
# delay_category                         False
# cancelled_trip                         False
# delay                                  False
# no_delay                               False
# nan_delay                              False
# delay_span_int                         False
# arrival_delay_float_new                False
# departure_delay_float_new              False
# dtype: bool

# %%
poisson_model = smf.poisson('nextbike_trips_count ~ departure_delay_float_new', data=agg_station_date_10min).fit()
print(poisson_model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.343798
#          Iterations 18
#                            Poisson Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              1290080
# Model:                          Poisson   Df Residuals:                  1290078
# Method:                             MLE   Df Model:                            1
# Date:                  Fri, 13 Sep 2024   Pseudo R-squ.:                  0.2082
# Time:                          18:08:29   Log-Likelihood:            -4.4353e+05
# converged:                         True   LL-Null:                   -5.6016e+05
# Covariance Type:              nonrobust   LLR p-value:                     0.000
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -2.8631      0.003   -843.252      0.000      -2.870      -2.856
# departure_delay_float_new    -0.4721      0.001   -779.924      0.000      -0.473      -0.471
# =============================================================================================

# %%
X = selected_features
y = data[y_string]

standizer = StandardScaler()
X = standizer.fit_transform(X)

exog = sm.add_constant(X)
poission_model = sm.GLM(y, exog, family=sm.families.Poisson())
result = poission_model.fit(method="lbfgs")
print(result.summary())
# Out:
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564850
# Model Family:                   Poisson   Df Model:                           10
# Link Function:                      Log   Scale:                          1.0000
# Method:                           lbfgs   Log-Likelihood:            -4.9854e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   7.8253e+05
# Time:                          18:20:35   Pearson chi2:                 4.12e+06
# No. Iterations:                      14   Pseudo R-squ. (CS):            0.01837
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.2603      0.004   -871.855      0.000      -3.268      -3.253
# x1            -0.6634      0.007   -101.745      0.000      -0.676      -0.651
# x2             0.0833      0.003     28.666      0.000       0.078       0.089
# x3            -1.0816      0.011    -96.906      0.000      -1.103      -1.060
# x4             0.1783      0.003     63.208      0.000       0.173       0.184
# x5             0.1613      0.002     65.646      0.000       0.156       0.166
# x6             0.8927      0.011     83.800      0.000       0.872       0.914
# x7             0.1136      0.002     46.393      0.000       0.109       0.118
# x8            -0.1044      0.004    -26.453      0.000      -0.112      -0.097
# x9            -0.0620      0.004    -14.103      0.000      -0.071      -0.053
# x10           -0.0800      0.003    -23.983      0.000      -0.087      -0.073
# ==============================================================================

# %%
X = data_dummy.drop(columns=[y_string, 'departure_delay_float'])
y = data[y_string]

standizer = StandardScaler()
X = standizer.fit_transform(X)

exog = sm.add_constant(X)
poission_model = sm.GLM(y, exog, family=sm.families.Poisson())
result = poission_model.fit(method="lbfgs")
print(result.summary())
# Out:
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/base/model.py:595: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564829
# Model Family:                   Poisson   Df Model:                           31
# Link Function:                      Log   Scale:                          1.0000
# Method:                           lbfgs   Log-Likelihood:            -4.9620e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   7.7786e+05
# Time:                          18:20:09   Pearson chi2:                 4.11e+06
# No. Iterations:                      20   Pseudo R-squ. (CS):            0.02016
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.2846      0.004   -858.697      0.000      -3.292      -3.277
# x1            -0.0361      0.003    -13.914      0.000      -0.041      -0.031
# x2            -0.6557      0.006   -101.115      0.000      -0.668      -0.643
# x3             0.0421      0.006      7.323      0.000       0.031       0.053
# x4             0.1605      0.002     64.886      0.000       0.156       0.165
# x5             0.1377      0.003     42.796      0.000       0.131       0.144
# x6             0.0211      0.004      5.172      0.000       0.013       0.029
# x7            -0.0980      0.004    -21.883      0.000      -0.107      -0.089
# x8            -0.0533    7.3e+04   -7.3e-07      1.000   -1.43e+05    1.43e+05
# x9            -0.2393      0.009    -25.686      0.000      -0.258      -0.221
# x10           -0.9451        nan        nan        nan         nan         nan
# x11            0.1942        nan        nan        nan         nan         nan
# x12            0.7647        nan        nan        nan         nan         nan
# x13            0.0138      0.002      5.712      0.000       0.009       0.019
# x14            0.3293      0.006     59.670      0.000       0.318       0.340
# x15            0.0834      0.004     18.984      0.000       0.075       0.092
# x16            0.1430      0.005     26.379      0.000       0.132       0.154
# x17            0.2879      0.007     43.014      0.000       0.275       0.301
# x18            0.3074      0.007     46.536      0.000       0.294       0.320
# x19            0.2608      0.007     37.381      0.000       0.247       0.275
# x20            0.2272      0.006     41.220      0.000       0.216       0.238
# x21           -0.0447   2.81e+04  -1.59e-06      1.000   -5.51e+04    5.51e+04
# x22           -0.0602   2.68e+04  -2.25e-06      1.000   -5.25e+04    5.25e+04
# x23           -0.1042   3.92e+04  -2.66e-06      1.000   -7.69e+04    7.69e+04
# x24           -0.0020   2.57e+04  -7.67e-08      1.000   -5.03e+04    5.03e+04
# x25           -0.0295   2.57e+04  -1.15e-06      1.000   -5.04e+04    5.04e+04
# x26            0.0099   2.57e+04   3.85e-07      1.000   -5.04e+04    5.04e+04
# x27            0.8845      0.011     82.494      0.000       0.864       0.906
# x28           -0.0046      0.017     -0.273      0.785      -0.037       0.028
# x29            0.0125      0.006      2.141      0.032       0.001       0.024
# x30           -0.0016      0.005     -0.359      0.719      -0.010       0.007
# x31            0.0140      0.007      1.972      0.049    8.72e-05       0.028
# x32            0.0130      0.002      7.023      0.000       0.009       0.017
# x33            0.0192      0.005      3.960      0.000       0.010       0.029
# ==============================================================================

# %% [markdown]
# ### Other

# %%
X = data[['departure_delay']]
y = data[y_string]

standizer = StandardScaler()
X = standizer.fit_transform(X)

exog = sm.add_constant(X)
poission_model = sm.GLM(y, exog, family=sm.families.Poisson())
result = poission_model.fit()
print(result.summary())
# Out:
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564859
# Model Family:                   Poisson   Df Model:                            1
# Link Function:                      Log   Scale:                          1.0000
# Method:                            IRLS   Log-Likelihood:            -5.2231e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   8.3008e+05
# Time:                          18:19:13   Pearson chi2:                 3.87e+06
# No. Iterations:                       7   Pseudo R-squ. (CS):          4.364e-06
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.0232      0.003  -1067.845      0.000      -3.029      -3.018
# x1            -0.0095      0.003     -3.347      0.001      -0.015      -0.004
# ==============================================================================

# %%
X = data[['departure_delay_float_new']]
y = data[y_string]

standizer = StandardScaler()
X = standizer.fit_transform(X)

exog = sm.add_constant(X)
poission_model = sm.GLM(y, exog, family=sm.families.Poisson())
result = poission_model.fit()
print(result.summary())
# Out:
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564859
# Model Family:                   Poisson   Df Model:                            1
# Link Function:                      Log   Scale:                          1.0000
# Method:                            IRLS   Log-Likelihood:            -5.2193e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   8.2932e+05
# Time:                          18:19:16   Pearson chi2:                 3.87e+06
# No. Iterations:                       7   Pseudo R-squ. (CS):          0.0002992
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.0283      0.003  -1061.938      0.000      -3.034      -3.023
# x1            -0.1922      0.008    -23.941      0.000      -0.208      -0.176
# ==============================================================================

# %%
from sklearn.preprocessing import StandardScaler


X = delay_span_dummy
y = data[y_string]

standizer = StandardScaler()
X = standizer.fit_transform(X)

exog = sm.add_constant(X)
poission_model = sm.GLM(y, exog, family=sm.families.Poisson())
result = poission_model.fit()
print(result.summary())
# Out:
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564853
# Model Family:                   Poisson   Df Model:                            7
# Link Function:                      Log   Scale:                          1.0000
# Method:                            IRLS   Log-Likelihood:            -5.2013e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   8.2571e+05
# Time:                          18:19:21   Pearson chi2:                 3.81e+06
# No. Iterations:                       7   Pseudo R-squ. (CS):           0.001705
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.0425      0.003  -1047.983      0.000      -3.048      -3.037
# x1            -0.1872      0.003    -61.832      0.000      -0.193      -0.181
# x2            -0.0642      0.017     -3.736      0.000      -0.098      -0.031
# x3            -0.0412      0.006     -7.052      0.000      -0.053      -0.030
# x4            -0.0305      0.004     -6.802      0.000      -0.039      -0.022
# x5            -0.0468      0.007     -6.557      0.000      -0.061      -0.033
# x6             0.0123      0.002      6.745      0.000       0.009       0.016
# x7            -0.0290      0.005     -6.041      0.000      -0.038      -0.020
# ==============================================================================

# %%
from sklearn.preprocessing import StandardScaler

X = data[['delay_category']]
y = data['tier_trips_count']

standizer = StandardScaler()
X = standizer.fit_transform(X)

exog = sm.add_constant(X)
poission_model = sm.GLM(y, exog, family=sm.families.Poisson())
result = poission_model.fit()
print(result.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:       tier_trips_count   No. Observations:              2564861
# Model:                            GLM   Df Residuals:                  2564859
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -2.5316e+05
# Date:                Fri, 13 Sep 2024   Deviance:                   4.1279e+05
# Time:                        18:19:24   Pearson chi2:                 3.19e+06
# No. Iterations:                     7   Pseudo R-squ. (CS):          0.0001907
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.9308      0.004   -879.756      0.000      -3.940      -3.922
# x1            -0.0998      0.005    -21.931      0.000      -0.109      -0.091
# ==============================================================================

# %%
from sklearn.preprocessing import StandardScaler


X = time_span_dummy
y = data[y_string]

standizer = StandardScaler()
X = standizer.fit_transform(X)

exog = sm.add_constant(X)
poission_model = sm.GLM(y, exog, family=sm.families.Poisson())
result = poission_model.fit()
print(result.summary())
# Out:
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564853
# Model Family:                   Poisson   Df Model:                            7
# Link Function:                      Log   Scale:                          1.0000
# Method:                            IRLS   Log-Likelihood:            -5.1982e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   8.2510e+05
# Time:                          18:19:29   Pearson chi2:                 3.84e+06
# No. Iterations:                       7   Pseudo R-squ. (CS):           0.001944
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.0419      0.003  -1055.749      0.000      -3.048      -3.036
# x1             0.1427      0.002     59.489      0.000       0.138       0.147
# x2            -0.0485      0.004    -13.740      0.000      -0.055      -0.042
# x3            -0.0449      0.003    -13.569      0.000      -0.051      -0.038
# x4             0.0516      0.003     17.900      0.000       0.046       0.057
# x5             0.0750      0.003     26.868      0.000       0.070       0.081
# x6            -0.0402      0.003    -12.360      0.000      -0.047      -0.034
# x7             0.0282      0.003      9.781      0.000       0.023       0.034
# ==============================================================================

# %%
from sklearn.preprocessing import StandardScaler


X = weekday_dummy
y = data[y_string]

standizer = StandardScaler()
X = standizer.fit_transform(X)

exog = sm.add_constant(X)
poission_model = sm.GLM(y, exog, family=sm.families.Poisson())
result = poission_model.fit()
print(result.summary())
# Out:
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564854
# Model Family:                   Poisson   Df Model:                            6
# Link Function:                      Log   Scale:                          1.0000
# Method:                            IRLS   Log-Likelihood:            -5.2116e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   8.2777e+05
# Time:                          18:19:34   Pearson chi2:                 3.85e+06
# No. Iterations:                       7   Pseudo R-squ. (CS):          0.0009026
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.0334      0.003  -1059.468      0.000      -3.039      -3.028
# x1            -0.0448      0.004    -11.864      0.000      -0.052      -0.037
# x2            -0.0748      0.004    -19.734      0.000      -0.082      -0.067
# x3            -0.1457      0.004    -37.280      0.000      -0.153      -0.138
# x4            -0.0148      0.004     -4.138      0.000      -0.022      -0.008
# x5            -0.0014      0.004     -0.384      0.701      -0.008       0.006
# x6             0.0068      0.004      1.927      0.054      -0.000       0.014
# ==============================================================================

# %%
from sklearn.preprocessing import StandardScaler

X = data[['cancelled_trip']]
y = data[y_string]

standizer = StandardScaler()
X = standizer.fit_transform(X)

exog = sm.add_constant(X)
poission_model = sm.GLM(y, exog, family=sm.families.Poisson())
result = poission_model.fit()
print(result.summary())
# Out:
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564859
# Model Family:                   Poisson   Df Model:                            1
# Link Function:                      Log   Scale:                          1.0000
# Method:                            IRLS   Log-Likelihood:            -5.2230e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   8.3007e+05
# Time:                          18:19:37   Pearson chi2:                 3.87e+06
# No. Iterations:                       7   Pseudo R-squ. (CS):          6.841e-06
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.0232      0.003  -1067.827      0.000      -3.029      -3.018
# x1            -0.0119      0.003     -4.185      0.000      -0.017      -0.006
# ==============================================================================

# %%
X = data[['nan_delay']]
y = data[y_string]

standizer = StandardScaler()
X = standizer.fit_transform(X)

exog = sm.add_constant(X)
poission_model = sm.GLM(y, exog, family=sm.families.Poisson())
result = poission_model.fit()
print(result.summary())
# Out:
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564859
# Model Family:                   Poisson   Df Model:                            1
# Link Function:                      Log   Scale:                          1.0000
# Method:                            IRLS   Log-Likelihood:            -5.2231e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   8.3008e+05
# Time:                          18:19:39   Pearson chi2:                 3.87e+06
# No. Iterations:                       7   Pseudo R-squ. (CS):          4.364e-06
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.0232      0.003  -1067.845      0.000      -3.029      -3.018
# x1             0.0095      0.003      3.347      0.001       0.004       0.015
# ==============================================================================

# %%
X = data[['no_delay']]
y = data[y_string]

standizer = StandardScaler()
X = standizer.fit_transform(X)

exog = sm.add_constant(X)
poission_model = sm.GLM(y, exog, family=sm.families.Poisson())
result = poission_model.fit()
print(result.summary())
# Out:
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564859
# Model Family:                   Poisson   Df Model:                            1
# Link Function:                      Log   Scale:                          1.0000
# Method:                            IRLS   Log-Likelihood:            -5.1918e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   8.2382e+05
# Time:                          18:19:42   Pearson chi2:                 3.81e+06
# No. Iterations:                       7   Pseudo R-squ. (CS):           0.002441
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.0465      0.003  -1053.371      0.000      -3.052      -3.041
# x1             0.2067      0.003     81.853      0.000       0.202       0.212
# ==============================================================================

# %%
X = data[['delay']]
y = data[y_string]

standizer = StandardScaler()
X = standizer.fit_transform(X)

exog = sm.add_constant(X)
poission_model = sm.GLM(y, exog, family=sm.families.Poisson())
result = poission_model.fit()
print(result.summary())
# Out:
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564859
# Model Family:                   Poisson   Df Model:                            1
# Link Function:                      Log   Scale:                          1.0000
# Method:                            IRLS   Log-Likelihood:            -5.1939e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   8.2423e+05
# Time:                          18:19:45   Pearson chi2:                 3.78e+06
# No. Iterations:                       7   Pseudo R-squ. (CS):           0.002279
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.0480      0.003  -1049.143      0.000      -3.054      -3.042
# x1            -0.2284      0.003    -74.011      0.000      -0.234      -0.222
# ==============================================================================

# %% [markdown]
# #### Multi

# %%
X = data_dummy.drop(columns=[y_string, 'departure_delay_float'])
X
# Out:
#          route_type  stop_id  service  transfer_stop  current_temp  \
# 0                 3      687        1          False         18.47
# 1                 3     1106        1           True         18.47
# 2                 3     1102        1          False         18.47
# 3                 3     1115        1           True         18.47
# 4                 3     1500        1           True         18.47
# ...             ...      ...      ...            ...           ...
# 2564856           3     1204        1          False         17.30
# 2564857           3     1140        1          False         17.30
# 2564858           3     1141        1          False         17.30
# 2564859           3      687        1          False         17.30
# 2564860           3      687        1          False         17.30
#
#          current_precipitation_volume  weather_int  weekend  cancelled_trip  \
# 0                                0.00            0        1               0
# 1                                0.00            0        1               0
# 2                                0.00            0        1               0
# 3                                0.00            0        1               0
# 4                                0.00            0        1               0
# ...                               ...          ...      ...             ...
# 2564856                          1.34            1        0               1
# 2564857                          1.34            1        0               1
# 2564858                          1.34            1        0               1
# 2564859                          1.34            1        0               0
# 2564860                          1.34            1        0               1
#
#          delay  ...  weekday_Thursday  weekday_Tuesday  weekday_Wednesday  \
# 0            1  ...             False            False              False
# 1            1  ...             False            False              False
# 2            1  ...             False            False              False
# 3            1  ...             False            False              False
# 4            1  ...             False            False              False
# ...        ...  ...               ...              ...                ...
# 2564856      0  ...             False             True              False
# 2564857      0  ...             False             True              False
# 2564858      0  ...             False             True              False
# 2564859      0  ...             False             True              False
# 2564860      0  ...             False             True              False
#
#          delay_span_0-5  delay_span_10-15  delay_span_15-20  delay_span_20-30  \
# 0                 False             False             False             False
# 1                 False             False             False             False
# 2                 False             False             False             False
# 3                 False             False             False             False
# 4                 False             False             False             False
# ...                 ...               ...               ...               ...
# 2564856           False             False             False             False
# 2564857           False             False             False             False
# 2564858           False             False             False             False
# 2564859           False             False             False             False
# 2564860           False             False             False             False
#
#          delay_span_30-45  delay_span_45-60  delay_span_5-10
# 0                   False             False            False
# 1                   False             False            False
# 2                   False             False            False
# 3                   False             False            False
# 4                   False             False            False
# ...                   ...               ...              ...
# 2564856             False             False            False
# 2564857             False             False            False
# 2564858             False             False            False
# 2564859             False             False            False
# 2564860             False             False            False
#
# [2564861 rows x 33 columns]

# %%
X = time_span_dummy
y = data[y_string]

standizer = StandardScaler()
X = standizer.fit_transform(X)

exog = sm.add_constant(X)
poission_model = sm.GLM(y, exog, family=sm.families.Poisson())
result = poission_model.fit(method="lbfgs")
print(result.summary())
# Out:
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564853
# Model Family:                   Poisson   Df Model:                            7
# Link Function:                      Log   Scale:                          1.0000
# Method:                           lbfgs   Log-Likelihood:            -5.1982e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   8.2510e+05
# Time:                          18:20:14   Pearson chi2:                 3.84e+06
# No. Iterations:                       4   Pseudo R-squ. (CS):           0.001944
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.0418      0.003  -1055.768      0.000      -3.047      -3.036
# x1             0.1428      0.002     59.520      0.000       0.138       0.147
# x2            -0.0482      0.004    -13.684      0.000      -0.055      -0.041
# x3            -0.0448      0.003    -13.539      0.000      -0.051      -0.038
# x4             0.0516      0.003     17.893      0.000       0.046       0.057
# x5             0.0751      0.003     26.877      0.000       0.070       0.081
# x6            -0.0402      0.003    -12.367      0.000      -0.047      -0.034
# x7             0.0282      0.003      9.762      0.000       0.023       0.034
# ==============================================================================

# %%
X = delay_span_dummy
y = data[y_string]

standizer = StandardScaler()
X = standizer.fit_transform(X)

exog = sm.add_constant(X)
poission_model = sm.GLM(y, exog, family=sm.families.Poisson())
result = poission_model.fit(method="lbfgs")
print(result.summary())
# Out:
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564853
# Model Family:                   Poisson   Df Model:                            7
# Link Function:                      Log   Scale:                          1.0000
# Method:                           lbfgs   Log-Likelihood:            -5.2013e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   8.2571e+05
# Time:                          18:20:20   Pearson chi2:                 3.81e+06
# No. Iterations:                       8   Pseudo R-squ. (CS):           0.001705
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.0427      0.003  -1048.360      0.000      -3.048      -3.037
# x1            -0.1874      0.003    -61.887      0.000      -0.193      -0.181
# x2            -0.0627      0.016     -3.813      0.000      -0.095      -0.030
# x3            -0.0412      0.006     -7.054      0.000      -0.053      -0.030
# x4            -0.0305      0.004     -6.799      0.000      -0.039      -0.022
# x5            -0.0470      0.007     -6.557      0.000      -0.061      -0.033
# x6             0.0123      0.002      6.757      0.000       0.009       0.016
# x7            -0.0290      0.005     -6.040      0.000      -0.038      -0.020
# ==============================================================================

# %%
X = weekday_dummy
y = data[y_string]

standizer = StandardScaler()
X = standizer.fit_transform(X)

exog = sm.add_constant(X)
poission_model = sm.GLM(y, exog, family=sm.families.Poisson())
result = poission_model.fit(method="lbfgs")
print(result.summary())
# Out:
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564854
# Model Family:                   Poisson   Df Model:                            6
# Link Function:                      Log   Scale:                          1.0000
# Method:                           lbfgs   Log-Likelihood:            -5.2116e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   8.2777e+05
# Time:                          18:20:25   Pearson chi2:                 3.85e+06
# No. Iterations:                       6   Pseudo R-squ. (CS):          0.0009026
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.0333      0.003  -1059.476      0.000      -3.039      -3.028
# x1            -0.0447      0.004    -11.826      0.000      -0.052      -0.037
# x2            -0.0745      0.004    -19.647      0.000      -0.082      -0.067
# x3            -0.1456      0.004    -37.261      0.000      -0.153      -0.138
# x4            -0.0148      0.004     -4.141      0.000      -0.022      -0.008
# x5            -0.0013      0.004     -0.363      0.716      -0.008       0.006
# x6             0.0072      0.004      2.040      0.041       0.000       0.014
# ==============================================================================

# %% [markdown]
# # Zero Inflated Poisson Regression

# %%
import statsmodels.api as sm

# Create the Poisson regression model
model = sm.ZeroInflatedPoisson(data[y_string], data[['departure_delay_float_new']])

# Fit the model
results = model.fit()

# Print the summary of the model
print(results.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.195094
#          Iterations: 14
#          Function evaluations: 17
#          Gradient evaluations: 17
#                      ZeroInflatedPoisson Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:              ZeroInflatedPoisson   Df Residuals:                  2564860
# Method:                             MLE   Df Model:                            0
# Date:                  Fri, 13 Sep 2024   Pseudo R-squ.:                -0.02464
# Time:                          18:21:14   Log-Likelihood:            -5.0039e+05
# converged:                         True   LL-Null:                   -4.8835e+05
# Covariance Type:              nonrobust   LLR p-value:                       nan
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# inflate_const                 2.7123      0.003    824.449      0.000       2.706       2.719
# departure_delay_float_new    -0.0009      0.002     -0.405      0.685      -0.006       0.004
# =============================================================================================

# %%
# Create the Poisson regression model
model = sm.ZeroInflatedPoisson(data[y_string], data[['delay_span_int']])

# Fit the model
results = model.fit()

# Print the summary of the model
print(results.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.192885
#          Iterations: 15
#          Function evaluations: 17
#          Gradient evaluations: 17
#                      ZeroInflatedPoisson Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:              ZeroInflatedPoisson   Df Residuals:                  2564860
# Method:                             MLE   Df Model:                            0
# Date:                  Fri, 13 Sep 2024   Pseudo R-squ.:                -0.01304
# Time:                          18:21:58   Log-Likelihood:            -4.9472e+05
# converged:                         True   LL-Null:                   -4.8835e+05
# Covariance Type:              nonrobust   LLR p-value:                       nan
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# inflate_const      2.5515      0.003    767.923      0.000       2.545       2.558
# delay_span_int    -0.6796      0.006   -111.317      0.000      -0.692      -0.668
# ==================================================================================

# %%
# Create the Poisson regression model
model = sm.ZeroInflatedPoisson(data[y_string], data[['delay_category']])

# Fit the model
results = model.fit()

# Print the summary of the model
print(results.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.195057
#          Iterations: 13
#          Function evaluations: 15
#          Gradient evaluations: 15
#                      ZeroInflatedPoisson Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:              ZeroInflatedPoisson   Df Residuals:                  2564860
# Method:                             MLE   Df Model:                            0
# Date:                  Fri, 13 Sep 2024   Pseudo R-squ.:                -0.02445
# Time:                          18:22:40   Log-Likelihood:            -5.0029e+05
# converged:                         True   LL-Null:                   -4.8835e+05
# Covariance Type:              nonrobust   LLR p-value:                       nan
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# inflate_const      2.7055      0.003    821.980      0.000       2.699       2.712
# delay_category     0.0539      0.004     13.924      0.000       0.046       0.062
# ==================================================================================

# %%
data_dummy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2564861 entries, 0 to 2564860
# Data columns (total 35 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   route_type                    int64
#  1   stop_id                       int64
#  2   service                       int64
#  3   transfer_stop                 bool
#  4   nextbike_trips_count          int64
#  5   current_temp                  float64
#  6   current_precipitation_volume  float64
#  7   departure_delay_float         float64
#  8   weather_int                   int64
#  9   weekend                       int64
#  10  cancelled_trip                int64
#  11  delay                         int64
#  12  no_delay                      int64
#  13  nan_delay                     int64
#  14  departure_delay_float_new     float64
#  15  time_span_afternoon           bool
#  16  time_span_early morning       bool
#  17  time_span_evening             bool
#  18  time_span_evening rush        bool
#  19  time_span_lunch               bool
#  20  time_span_morning rush        bool
#  21  time_span_until midday        bool
#  22  weekday_Monday                bool
#  23  weekday_Saturday              bool
#  24  weekday_Sunday                bool
#  25  weekday_Thursday              bool
#  26  weekday_Tuesday               bool
#  27  weekday_Wednesday             bool
#  28  delay_span_0-5                bool
#  29  delay_span_10-15              bool
#  30  delay_span_15-20              bool
#  31  delay_span_20-30              bool
#  32  delay_span_30-45              bool
#  33  delay_span_45-60              bool
#  34  delay_span_5-10               bool
# dtypes: bool(21), float64(4), int64(10)
# memory usage: 325.3 MB

# %%
X = data_dummy.drop(columns=[y_string, "departure_delay_float"])
y = data[y_string]

# Create the Poisson regression model
model = sm.ZeroInflatedPoisson(y,X.astype(float))

# Fit the model
results = model.fit()

# Print the summary of the model
print(results.summary())
# Out:
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/scipy/optimize/_optimize.py:1292: OptimizeWarning: Maximum number of iterations has been exceeded.
#   res = _minimize_bfgs(f, x0, args, fprime, callback=callback, **opts)
#          Current function value: 0.184902
#          Iterations: 35
#          Function evaluations: 41
#          Gradient evaluations: 41
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                      ZeroInflatedPoisson Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:              ZeroInflatedPoisson   Df Residuals:                  2564828
# Method:                             MLE   Df Model:                           32
# Date:                  Fri, 13 Sep 2024   Pseudo R-squ.:                 0.02888
# Time:                          18:25:08   Log-Likelihood:            -4.7425e+05
# converged:                        False   LL-Null:                   -4.8835e+05
# Covariance Type:              nonrobust   LLR p-value:                     0.000
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# inflate_const                    1.6943      0.004    466.828      0.000       1.687       1.701
# route_type                      -0.0480      0.003    -15.161      0.000      -0.054      -0.042
# stop_id                         -0.0002   2.41e-06    -95.148      0.000      -0.000      -0.000
# service                         -0.6936      0.058    -11.929      0.000      -0.808      -0.580
# transfer_stop                    0.3866      0.008     50.024      0.000       0.371       0.402
# current_temp                     0.0313      0.001     37.346      0.000       0.030       0.033
# current_precipitation_volume    -0.0012      0.015     -0.082      0.935      -0.031       0.028
# weather_int                     -0.2869      0.012    -24.534      0.000      -0.310      -0.264
# weekend                         -0.2021    2.8e+05  -7.21e-07      1.000   -5.49e+05    5.49e+05
# cancelled_trip                  -0.2747      0.024    -11.534      0.000      -0.321      -0.228
# delay                           -0.4429    2.8e+05  -1.58e-06      1.000   -5.49e+05    5.49e+05
# no_delay                        -0.1457    2.8e+05   -5.2e-07      1.000   -5.49e+05    5.49e+05
# nan_delay                       -0.1680    2.8e+05     -6e-07      1.000   -5.49e+05    5.49e+05
# departure_delay_float_new       -0.0536      0.008     -6.517      0.000      -0.070      -0.037
# time_span_afternoon              0.4295      0.019     22.038      0.000       0.391       0.468
# time_span_early morning         -0.1531      0.032     -4.828      0.000      -0.215      -0.091
# time_span_evening               -0.1783      0.022     -7.961      0.000      -0.222      -0.134
# time_span_evening rush           0.0767      0.019      4.027      0.000       0.039       0.114
# time_span_lunch                  0.1465      0.019      7.731      0.000       0.109       0.184
# time_span_morning rush          -0.2631      0.019    -13.640      0.000      -0.301      -0.225
# time_span_until midday          -0.0054      0.021     -0.262      0.793      -0.046       0.035
# weekday_Monday                  -0.2882    2.8e+05  -1.03e-06      1.000   -5.49e+05    5.49e+05
# weekday_Saturday                 0.0213    2.8e+05   7.62e-08      1.000   -5.49e+05    5.49e+05
# weekday_Sunday                  -0.1219    5.6e+05  -2.18e-07      1.000    -1.1e+06     1.1e+06
# weekday_Thursday                -0.1719    2.8e+05  -6.14e-07      1.000   -5.49e+05    5.49e+05
# weekday_Tuesday                 -0.1829    2.8e+05  -6.53e-07      1.000   -5.49e+05    5.49e+05
# weekday_Wednesday               -0.1341    2.8e+05  -4.79e-07      1.000   -5.49e+05    5.49e+05
# delay_span_0-5                  -0.2030      0.037     -5.474      0.000      -0.276      -0.130
# delay_span_10-15                -0.0009      0.432     -0.002      0.998      -0.848       0.846
# delay_span_15-20                -0.0032      0.232     -0.014      0.989      -0.459       0.452
# delay_span_20-30                -0.0011      0.191     -0.006      0.995      -0.375       0.372
# delay_span_30-45                -0.0025      0.430     -0.006      0.995      -0.844       0.839
# delay_span_45-60                 0.0046      0.163      0.028      0.978      -0.315       0.324
# delay_span_5-10                 -0.0047      0.161     -0.029      0.977      -0.319       0.310
# ================================================================================================

# %%
X = delay_span_dummy
y = data[y_string]

# Create the Poisson regression model
model = sm.ZeroInflatedPoisson(y,X)

# Fit the model
results = model.fit()

# Print the summary of the model
print(results.summary())
# Out:
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/scipy/optimize/_optimize.py:1292: OptimizeWarning: Maximum number of iterations has been exceeded.
#   res = _minimize_bfgs(f, x0, args, fprime, callback=callback, **opts)
#          Current function value: 0.192751
#          Iterations: 35
#          Function evaluations: 37
#          Gradient evaluations: 37
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                      ZeroInflatedPoisson Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:              ZeroInflatedPoisson   Df Residuals:                  2564854
# Method:                             MLE   Df Model:                            6
# Date:                  Fri, 13 Sep 2024   Pseudo R-squ.:                -0.01234
# Time:                          18:26:17   Log-Likelihood:            -4.9438e+05
# converged:                        False   LL-Null:                   -4.8835e+05
# Covariance Type:              nonrobust   LLR p-value:                     1.000
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# inflate_const        2.5443      0.003    765.310      0.000       2.538       2.551
# delay_span_0-5      -0.7178      0.006   -115.627      0.000      -0.730      -0.706
# delay_span_10-15    -0.8064      0.320     -2.517      0.012      -1.434      -0.178
# delay_span_15-20    -1.7693      0.233     -7.605      0.000      -2.225      -1.313
# delay_span_20-30    -2.0047      0.219     -9.154      0.000      -2.434      -1.576
# delay_span_30-45    -1.4799      0.240     -6.154      0.000      -1.951      -1.009
# delay_span_45-60    -0.1213      0.128     -0.947      0.344      -0.373       0.130
# delay_span_5-10     -1.6099      0.223     -7.203      0.000      -2.048      -1.172
# ====================================================================================

# %%
X = time_span_dummy
y = data[y_string]

# Create the Poisson regression model
model = sm.ZeroInflatedPoisson(y,X)

# Fit the model
results = model.fit()

# Print the summary of the model
print(results.summary())
# Out:
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/scipy/optimize/_optimize.py:1292: OptimizeWarning: Maximum number of iterations has been exceeded.
#   res = _minimize_bfgs(f, x0, args, fprime, callback=callback, **opts)
#          Current function value: 0.193352
#          Iterations: 35
#          Function evaluations: 37
#          Gradient evaluations: 37
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                      ZeroInflatedPoisson Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:              ZeroInflatedPoisson   Df Residuals:                  2564854
# Method:                             MLE   Df Model:                            6
# Date:                  Fri, 13 Sep 2024   Pseudo R-squ.:                -0.01549
# Time:                          18:27:28   Log-Likelihood:            -4.9592e+05
# converged:                        False   LL-Null:                   -4.8835e+05
# Covariance Type:              nonrobust   LLR p-value:                     1.000
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# inflate_const               2.5534      0.003    768.491      0.000       2.547       2.560
# time_span_afternoon        -0.1272      0.010    -12.689      0.000      -0.147      -0.108
# time_span_early morning    -0.4190      0.028    -15.111      0.000      -0.473      -0.365
# time_span_evening          -0.7225      0.017    -43.420      0.000      -0.755      -0.690
# time_span_evening rush     -0.4218      0.010    -42.947      0.000      -0.441      -0.403
# time_span_lunch            -0.3553      0.010    -37.075      0.000      -0.374      -0.337
# time_span_morning rush     -0.6744      0.011    -62.606      0.000      -0.695      -0.653
# time_span_until midday     -0.5003      0.013    -37.986      0.000      -0.526      -0.475
# ===========================================================================================

# %%
X = weekday_dummy
y = data[y_string]

# Create the Poisson regression model
model = sm.ZeroInflatedPoisson(y,X)

# Fit the model
results = model.fit()

# Print the summary of the model
print(results.summary())
# Out:
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/scipy/optimize/_optimize.py:1292: OptimizeWarning: Maximum number of iterations has been exceeded.
#   res = _minimize_bfgs(f, x0, args, fprime, callback=callback, **opts)
#          Current function value: 0.191300
#          Iterations: 35
#          Function evaluations: 36
#          Gradient evaluations: 36
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                      ZeroInflatedPoisson Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:              ZeroInflatedPoisson   Df Residuals:                  2564855
# Method:                             MLE   Df Model:                            5
# Date:                  Fri, 13 Sep 2024   Pseudo R-squ.:               -0.004715
# Time:                          18:28:35   Log-Likelihood:            -4.9066e+05
# converged:                        False   LL-Null:                   -4.8835e+05
# Covariance Type:              nonrobust   LLR p-value:                     1.000
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# inflate_const         2.3025      0.003    679.366      0.000       2.296       2.309
# weekday_Monday       -0.6759      0.008    -84.735      0.000      -0.692      -0.660
# weekday_Saturday     -0.7753      0.009    -88.386      0.000      -0.793      -0.758
# weekday_Sunday       -1.0401      0.014    -72.830      0.000      -1.068      -1.012
# weekday_Thursday     -0.6161      0.009    -71.618      0.000      -0.633      -0.599
# weekday_Tuesday      -0.5741      0.008    -67.805      0.000      -0.591      -0.557
# weekday_Wednesday    -0.5530      0.008    -65.926      0.000      -0.569      -0.537
# =====================================================================================

# %%
X = selected_features
y = data[y_string]

# Create the Poisson regression model
model = sm.ZeroInflatedPoisson(y,X.astype(float))

# Fit the model
results = model.fit()

# Print the summary of the model
print(results.summary())
# Out:
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:1331: RuntimeWarning: overflow encountered in exp
#   return -np.exp(XB) +  endog*XB - gammaln(endog+1)
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:1508: RuntimeWarning: overflow encountered in exp
#   L = np.exp(np.dot(X,params) + offset + exposure)
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:1509: RuntimeWarning: overflow encountered in multiply
#   return (self.endog - L)[:,None] * X
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:1509: RuntimeWarning: invalid value encountered in multiply
#   return (self.endog - L)[:,None] * X
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:1074: RuntimeWarning: overflow encountered in exp
#   return np.exp(linpred)
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/count_model.py:269: RuntimeWarning: invalid value encountered in multiply
#   dldp[zero_idx,:] = (score_main[zero_idx].T *
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:1331: RuntimeWarning: overflow encountered in exp
#   return -np.exp(XB) +  endog*XB - gammaln(endog+1)
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/scipy/optimize/_optimize.py:1292: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(f, x0, args, fprime, callback=callback, **opts)
#          Current function value: 0.220646
#          Iterations: 0
#          Function evaluations: 13
#          Gradient evaluations: 2
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                      ZeroInflatedPoisson Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:              ZeroInflatedPoisson   Df Residuals:                  2564851
# Method:                             MLE   Df Model:                            9
# Date:                  Fri, 13 Sep 2024   Pseudo R-squ.:                 -0.1588
# Time:                          18:29:19   Log-Likelihood:            -5.6593e+05
# converged:                        False   LL-Null:                   -4.8835e+05
# Covariance Type:              nonrobust   LLR p-value:                     1.000
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# inflate_const           0.1000      0.006     16.773      0.000       0.088       0.112
# stop_id                -0.0021    9.2e-06   -230.979      0.000      -0.002      -0.002
# no_delay                0.0005      0.009      0.055      0.956      -0.018       0.019
# delay                6.041e-05      0.040      0.002      0.999      -0.078       0.078
# current_temp         6.048e-05      0.001      0.110      0.912      -0.001       0.001
# transfer_stop           0.0002      0.010      0.025      0.980      -0.019       0.019
# delay_span_0-5          0.0002      0.039      0.005      0.996      -0.077       0.077
# time_span_afternoon     0.0005      0.015      0.035      0.972      -0.029       0.030
# weekend              6.876e-05      0.005      0.013      0.989      -0.010       0.010
# weekday_Sunday          0.0003      0.019      0.017      0.986      -0.037       0.038
# weather_int             0.0002      0.009      0.020      0.984      -0.016       0.017
# =======================================================================================

# %%
# Create the Poisson regression model
model = sm.ZeroInflatedPoisson(data[y_string], data[['delay_category']])

# Fit the model
results = model.fit()

# Print the summary of the model
print(results.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.195057
#          Iterations: 13
#          Function evaluations: 15
#          Gradient evaluations: 15
#                      ZeroInflatedPoisson Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:              ZeroInflatedPoisson   Df Residuals:                  2564860
# Method:                             MLE   Df Model:                            0
# Date:                  Fri, 13 Sep 2024   Pseudo R-squ.:                -0.02445
# Time:                          18:30:04   Log-Likelihood:            -5.0029e+05
# converged:                         True   LL-Null:                   -4.8835e+05
# Covariance Type:              nonrobust   LLR p-value:                       nan
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# inflate_const      2.7055      0.003    821.980      0.000       2.699       2.712
# delay_category     0.0539      0.004     13.924      0.000       0.046       0.062
# ==================================================================================

# %%
# Create the Poisson regression model
model = sm.ZeroInflatedPoisson(data[y_string], data[['cancelled_trip']])

# Fit the model
results = model.fit()

# Print the summary of the model
print(results.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.193944
#          Iterations: 14
#          Function evaluations: 16
#          Gradient evaluations: 16
#                      ZeroInflatedPoisson Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:              ZeroInflatedPoisson   Df Residuals:                  2564860
# Method:                             MLE   Df Model:                            0
# Date:                  Fri, 13 Sep 2024   Pseudo R-squ.:                -0.01860
# Time:                          18:30:50   Log-Likelihood:            -4.9744e+05
# converged:                         True   LL-Null:                   -4.8835e+05
# Covariance Type:              nonrobust   LLR p-value:                       nan
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# inflate_const      2.6025      0.003    785.562      0.000       2.596       2.609
# cancelled_trip    -0.4439      0.005    -81.648      0.000      -0.455      -0.433
# ==================================================================================

# %%
# Create the Poisson regression model
model = sm.ZeroInflatedPoisson(data['tier_trips_count'],data[['delay']])

# Fit the model
results = model.fit()

# Print the summary of the model
print(results.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.098202
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
#                      ZeroInflatedPoisson Regression Results
# ===============================================================================
# Dep. Variable:        tier_trips_count   No. Observations:              2564861
# Model:             ZeroInflatedPoisson   Df Residuals:                  2564860
# Method:                            MLE   Df Model:                            0
# Date:                 Fri, 13 Sep 2024   Pseudo R-squ.:                -0.02853
# Time:                         18:31:41   Log-Likelihood:            -2.5188e+05
# converged:                        True   LL-Null:                   -2.4489e+05
# Covariance Type:             nonrobust   LLR p-value:                       nan
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# inflate_const     3.3313      0.005    690.915      0.000       3.322       3.341
# delay            -1.0100      0.010    -98.578      0.000      -1.030      -0.990
# =================================================================================

# %%
# Create the Poisson regression model
model = sm.ZeroInflatedPoisson(data[y_string],data[['no_delay']])

# Fit the model
results = model.fit()

# Print the summary of the model
print(results.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.195011
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
#                      ZeroInflatedPoisson Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:              ZeroInflatedPoisson   Df Residuals:                  2564860
# Method:                             MLE   Df Model:                            0
# Date:                  Fri, 13 Sep 2024   Pseudo R-squ.:                -0.02421
# Time:                          18:32:28   Log-Likelihood:            -5.0018e+05
# converged:                         True   LL-Null:                   -4.8835e+05
# Covariance Type:              nonrobust   LLR p-value:                       nan
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# inflate_const     2.6953      0.003    818.379      0.000       2.689       2.702
# no_delay         -0.1244      0.006    -21.123      0.000      -0.136      -0.113
# =================================================================================

# %%
# Create the Poisson regression model
model = sm.ZeroInflatedPoisson(data[y_string],data[['nan_delay']])

# Fit the model
results = model.fit()

# Print the summary of the model
print(results.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.194015
#          Iterations: 14
#          Function evaluations: 16
#          Gradient evaluations: 16
#                      ZeroInflatedPoisson Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:              ZeroInflatedPoisson   Df Residuals:                  2564860
# Method:                             MLE   Df Model:                            0
# Date:                  Fri, 13 Sep 2024   Pseudo R-squ.:                -0.01898
# Time:                          18:33:15   Log-Likelihood:            -4.9762e+05
# converged:                         True   LL-Null:                   -4.8835e+05
# Covariance Type:              nonrobust   LLR p-value:                       nan
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# inflate_const     2.6044      0.003    786.334      0.000       2.598       2.611
# nan_delay        -0.4189      0.005    -79.370      0.000      -0.429      -0.409
# =================================================================================

# %%
# Create the Poisson regression model
model = sm.ZeroInflatedPoisson(data[y_string],data[['nan_delay']])

# Fit the model
results = model.fit()

# Print the summary of the model
print(results.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.194015
#          Iterations: 14
#          Function evaluations: 16
#          Gradient evaluations: 16
#                      ZeroInflatedPoisson Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:              ZeroInflatedPoisson   Df Residuals:                  2564860
# Method:                             MLE   Df Model:                            0
# Date:                  Fri, 13 Sep 2024   Pseudo R-squ.:                -0.01898
# Time:                          18:34:01   Log-Likelihood:            -4.9762e+05
# converged:                         True   LL-Null:                   -4.8835e+05
# Covariance Type:              nonrobust   LLR p-value:                       nan
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# inflate_const     2.6044      0.003    786.334      0.000       2.598       2.611
# nan_delay        -0.4189      0.005    -79.370      0.000      -0.429      -0.409
# =================================================================================

# %% [markdown]
# # Negative Binomial Regression

# %% [markdown]
# #### Best Models

# %%
X = selected_features
y = data[y_string]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Create the negative binomial regression model
model = sm.GLM(y, X.astype(float), family=sm.families.NegativeBinomial())
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564850
# Model Family:          NegativeBinomial   Df Model:                           10
# Link Function:                      Log   Scale:                          1.0000
# Method:                            IRLS   Log-Likelihood:            -4.8284e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   6.6397e+05
# Time:                          19:00:37   Pearson chi2:                 3.86e+06
# No. Iterations:                       7   Pseudo R-squ. (CS):            0.01711
# Covariance Type:              nonrobust
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -3.3963      0.016   -215.722      0.000      -3.427      -3.365
# stop_id                -0.0003   2.68e-06    -99.469      0.000      -0.000      -0.000
# no_delay                0.2017      0.007     27.898      0.000       0.188       0.216
# delay                  -2.2180      0.028    -78.855      0.000      -2.273      -2.163
# current_temp            0.0410      0.001     61.267      0.000       0.040       0.042
# transfer_stop           0.4530      0.007     65.004      0.000       0.439       0.467
# delay_span_0-5          1.8301      0.027     67.172      0.000       1.777       1.883
# time_span_afternoon     0.4467      0.010     43.736      0.000       0.427       0.467
# weekend                -0.1043      0.004    -25.597      0.000      -0.112      -0.096
# weekday_Sunday         -0.2333      0.017    -13.878      0.000      -0.266      -0.200
# weather_int            -0.1791      0.008    -23.251      0.000      -0.194      -0.164
# =======================================================================================

# %%
X = data_dummy.drop(columns=[y_string, 'departure_delay_float'])
y = data[y_string]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Create the negative binomial regression model
model = sm.GLM(y, X.astype(float), family=sm.families.NegativeBinomial())
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564829
# Model Family:          NegativeBinomial   Df Model:                           31
# Link Function:                      Log   Scale:                          1.0000
# Method:                            IRLS   Log-Likelihood:            -4.8060e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   6.5950e+05
# Time:                          19:00:14   Pearson chi2:                 3.84e+06
# No. Iterations:                     100   Pseudo R-squ. (CS):            0.01882
# Covariance Type:              nonrobust
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                           -3.2529      0.062    -52.208      0.000      -3.375      -3.131
# route_type                      -0.0418      0.003    -14.357      0.000      -0.048      -0.036
# stop_id                         -0.0003   2.66e-06    -98.715      0.000      -0.000      -0.000
# service                          0.6300      0.087      7.210      0.000       0.459       0.801
# transfer_stop                    0.4523      0.007     64.422      0.000       0.439       0.466
# current_temp                     0.0316      0.001     41.473      0.000       0.030       0.033
# current_precipitation_volume     0.0657      0.013      5.238      0.000       0.041       0.090
# weather_int                     -0.2209      0.010    -21.308      0.000      -0.241      -0.201
# weekend                         -0.4500      0.007    -65.735      0.000      -0.463      -0.437
# cancelled_trip                  -0.5113      0.020    -25.575      0.000      -0.551      -0.472
# delay                           -3.0564      0.030   -101.633      0.000      -3.115      -2.997
# no_delay                        -0.6498      0.024    -27.205      0.000      -0.697      -0.603
# nan_delay                        0.4533      0.029     15.894      0.000       0.397       0.509
# departure_delay_float_new        0.0059      0.001      5.786      0.000       0.004       0.008
# time_span_afternoon              1.2933      0.022     58.020      0.000       1.250       1.337
# time_span_early morning          0.6050      0.033     18.440      0.000       0.541       0.669
# time_span_evening                0.6319      0.025     25.628      0.000       0.584       0.680
# time_span_evening rush           0.9246      0.022     42.044      0.000       0.881       0.968
# time_span_lunch                  0.9961      0.022     45.501      0.000       0.953       1.039
# time_span_morning rush           0.7994      0.022     36.519      0.000       0.756       0.842
# time_span_until midday           0.9260      0.023     40.306      0.000       0.881       0.971
# weekday_Monday                  -0.5117      0.011    -45.986      0.000      -0.533      -0.490
# weekday_Saturday                 0.2351      0.013     18.238      0.000       0.210       0.260
# weekday_Sunday                   0.4041      0.018     21.953      0.000       0.368       0.440
# weekday_Thursday                -0.4019      0.011    -35.025      0.000      -0.424      -0.379
# weekday_Tuesday                 -0.4779      0.012    -41.530      0.000      -0.501      -0.455
# weekday_Wednesday               -0.3681      0.011    -32.516      0.000      -0.390      -0.346
# delay_span_0-5                   1.8176      0.027     66.139      0.000       1.764       1.871
# delay_span_10-15                -0.3596      1.001     -0.359      0.719      -2.321       1.602
# delay_span_15-20                 0.4598      0.229      2.003      0.045       0.010       0.910
# delay_span_20-30                -0.0495      0.157     -0.316      0.752      -0.357       0.258
# delay_span_30-45                 0.5651      0.307      1.840      0.066      -0.037       1.167
# delay_span_45-60                 0.8193      0.122      6.739      0.000       0.581       1.058
# delay_span_5-10                  0.7817      0.200      3.909      0.000       0.390       1.174
# ================================================================================================

# %% [markdown]
# ### Other

# %%
X = data[['departure_delay_float_new']]
y = data[y_string]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Create the negative binomial regression model
model = sm.GLM(y, X, family=sm.families.NegativeBinomial())
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564859
# Model Family:          NegativeBinomial   Df Model:                            1
# Link Function:                      Log   Scale:                          1.0000
# Method:                            IRLS   Log-Likelihood:            -5.0460e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   7.0749e+05
# Time:                          18:34:03   Pearson chi2:                 3.69e+06
# No. Iterations:                       6   Pseudo R-squ. (CS):          0.0002866
# Covariance Type:              nonrobust
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                        -3.0386      0.003  -1012.131      0.000      -3.044      -3.033
# departure_delay_float_new    -0.0797      0.003    -23.451      0.000      -0.086      -0.073
# =============================================================================================

# %%
# Define the independent variables (X) and the dependent variable (y)
X = data[['cancelled_trip']]
y = data[y_string]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Create the negative binomial regression model
model = sm.GLM(y, X, family=sm.families.NegativeBinomial())
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564859
# Model Family:          NegativeBinomial   Df Model:                            1
# Link Function:                      Log   Scale:                          1.0000
# Method:                            IRLS   Log-Likelihood:            -5.0496e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   7.0821e+05
# Time:                          18:34:06   Pearson chi2:                 3.69e+06
# No. Iterations:                       6   Pseudo R-squ. (CS):          6.524e-06
# Covariance Type:              nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -3.0137      0.004   -814.199      0.000      -3.021      -3.006
# cancelled_trip    -0.0243      0.006     -4.087      0.000      -0.036      -0.013
# ==================================================================================

# %%
# Define the independent variables (X) and the dependent variable (y)
X = data[['delay_span_int']]
y = data[y_string]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Create the negative binomial regression model
model = sm.GLM(y, X, family=sm.families.NegativeBinomial())
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564859
# Model Family:          NegativeBinomial   Df Model:                            1
# Link Function:                      Log   Scale:                          1.0000
# Method:                            IRLS   Log-Likelihood:            -5.0309e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   7.0447e+05
# Time:                          18:34:08   Pearson chi2:                 3.65e+06
# No. Iterations:                       6   Pseudo R-squ. (CS):           0.001463
# Covariance Type:              nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -2.9006      0.003   -844.431      0.000      -2.907      -2.894
# delay_span_int    -0.3648      0.006    -58.790      0.000      -0.377      -0.353
# ==================================================================================

# %%
# Define the independent variables (X) and the dependent variable (y)
X = data[['delay_category']]
y = data[y_string]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Create the negative binomial regression model
model = sm.GLM(y, X, family=sm.families.NegativeBinomial())
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564859
# Model Family:          NegativeBinomial   Df Model:                            1
# Link Function:                      Log   Scale:                          1.0000
# Method:                            IRLS   Log-Likelihood:            -5.0447e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   7.0724e+05
# Time:                          18:34:10   Pearson chi2:                 3.67e+06
# No. Iterations:                       6   Pseudo R-squ. (CS):          0.0003848
# Covariance Type:              nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -3.0511      0.003   -993.282      0.000      -3.057      -3.045
# delay_category    -0.1136      0.004    -31.262      0.000      -0.121      -0.106
# ==================================================================================

# %%
# Define the independent variables (X) and the dependent variable (y)
X = data[['delay']]
y = data[y_string]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Create the negative binomial regression model
model = sm.GLM(y, X, family=sm.families.NegativeBinomial())
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564859
# Model Family:          NegativeBinomial   Df Model:                            1
# Link Function:                      Log   Scale:                          1.0000
# Method:                            IRLS   Log-Likelihood:            -5.0217e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   7.0263e+05
# Time:                          18:34:13   Pearson chi2:                 3.60e+06
# No. Iterations:                       6   Pseudo R-squ. (CS):           0.002179
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.8728      0.003   -844.447      0.000      -2.879      -2.866
# delay         -0.4729      0.007    -72.540      0.000      -0.486      -0.460
# ==============================================================================

# %%
# Define the independent variables (X) and the dependent variable (y)
X = data[['no_delay']]
y = data[y_string]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Create the negative binomial regression model
model = sm.GLM(y, X, family=sm.families.NegativeBinomial())
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564859
# Model Family:          NegativeBinomial   Df Model:                            1
# Link Function:                      Log   Scale:                          1.0000
# Method:                            IRLS   Log-Likelihood:            -5.0199e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   7.0227e+05
# Time:                          18:34:15   Pearson chi2:                 3.63e+06
# No. Iterations:                       6   Pseudo R-squ. (CS):           0.002318
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.1573      0.004   -900.261      0.000      -3.164      -3.150
# no_delay       0.4965      0.006     79.460      0.000       0.484       0.509
# ==============================================================================

# %%
# Define the independent variables (X) and the dependent variable (y)
X = data[['nan_delay']]
y = data[y_string]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Create the negative binomial regression model
model = sm.GLM(y, X, family=sm.families.NegativeBinomial())
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564859
# Model Family:          NegativeBinomial   Df Model:                            1
# Link Function:                      Log   Scale:                          1.0000
# Method:                            IRLS   Log-Likelihood:            -5.0496e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   7.0822e+05
# Time:                          18:34:17   Pearson chi2:                 3.69e+06
# No. Iterations:                       6   Pseudo R-squ. (CS):          4.161e-06
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.0310      0.004   -802.558      0.000      -3.038      -3.024
# nan_delay      0.0193      0.006      3.269      0.001       0.008       0.031
# ==============================================================================

# %%
X = delay_span_dummy
y = data[y_string]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Create the negative binomial regression model
model = sm.GLM(y, X.astype(float), family=sm.families.NegativeBinomial())
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564853
# Model Family:          NegativeBinomial   Df Model:                            7
# Link Function:                      Log   Scale:                          1.0000
# Method:                            IRLS   Log-Likelihood:            -5.0287e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   7.0404e+05
# Time:                          19:00:20   Pearson chi2:                 3.63e+06
# No. Iterations:                       7   Pseudo R-squ. (CS):           0.001630
# Covariance Type:              nonrobust
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -2.8945      0.003   -840.679      0.000      -2.901      -2.888
# delay_span_0-5      -0.3879      0.006    -60.556      0.000      -0.400      -0.375
# delay_span_10-15    -3.7362      1.001     -3.734      0.000      -5.697      -1.775
# delay_span_15-20    -1.5771      0.225     -7.012      0.000      -2.018      -1.136
# delay_span_20-30    -1.0499      0.156     -6.737      0.000      -1.355      -0.744
# delay_span_30-45    -1.9772      0.303     -6.532      0.000      -2.570      -1.384
# delay_span_45-60     0.7544      0.118      6.380      0.000       0.523       0.986
# delay_span_5-10     -1.1850      0.198     -5.991      0.000      -1.573      -0.797
# ====================================================================================

# %%
X = time_span_dummy
y = data[y_string]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Create the negative binomial regression model
model = sm.GLM(y, X.astype(float), family=sm.families.NegativeBinomial())
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564853
# Model Family:          NegativeBinomial   Df Model:                            7
# Link Function:                      Log   Scale:                          1.0000
# Method:                            IRLS   Log-Likelihood:            -5.0260e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   7.0349e+05
# Time:                          19:00:24   Pearson chi2:                 3.66e+06
# No. Iterations:                       6   Pseudo R-squ. (CS):           0.001846
# Covariance Type:              nonrobust
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -3.0993      0.004   -704.070      0.000      -3.108      -3.091
# time_span_afternoon         0.5660      0.010     57.447      0.000       0.547       0.585
# time_span_early morning    -0.3555      0.026    -13.526      0.000      -0.407      -0.304
# time_span_evening          -0.2008      0.015    -13.321      0.000      -0.230      -0.171
# time_span_evening rush      0.1670      0.010     17.456      0.000       0.148       0.186
# time_span_lunch             0.2449      0.009     26.161      0.000       0.227       0.263
# time_span_morning rush     -0.1244      0.010    -12.115      0.000      -0.144      -0.104
# time_span_until midday      0.1157      0.012      9.546      0.000       0.092       0.139
# ===========================================================================================

# %%
X = weekday_dummy
y = data[y_string]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Create the negative binomial regression model
model = sm.GLM(y, X.astype(float), family=sm.families.NegativeBinomial())
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   No. Observations:              2564861
# Model:                              GLM   Df Residuals:                  2564854
# Model Family:          NegativeBinomial   Df Model:                            6
# Link Function:                      Log   Scale:                          1.0000
# Method:                            IRLS   Log-Likelihood:            -5.0386e+05
# Date:                  Fri, 13 Sep 2024   Deviance:                   7.0601e+05
# Time:                          19:00:28   Pearson chi2:                 3.67e+06
# No. Iterations:                       6   Pseudo R-squ. (CS):          0.0008640
# Covariance Type:              nonrobust
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -2.9332      0.007   -401.332      0.000      -2.948      -2.919
# weekday_Monday       -0.1163      0.010    -11.576      0.000      -0.136      -0.097
# weekday_Saturday     -0.2038      0.011    -19.276      0.000      -0.224      -0.183
# weekday_Sunday       -0.5418      0.015    -36.621      0.000      -0.571      -0.513
# weekday_Thursday     -0.0421      0.010     -4.035      0.000      -0.063      -0.022
# weekday_Tuesday      -0.0039      0.010     -0.374      0.709      -0.024       0.016
# weekday_Wednesday     0.0193      0.010      1.877      0.060      -0.001       0.039
# =====================================================================================

# %% [markdown]
# # Zero Inflated Negative Binomial

# %%
# Define the independent variables (X) and the dependent variable (y)
X = data[['departure_delay_float_new']]
y = data[y_string]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Create the zero-inflated negative binomial regression model
model = sm.ZeroInflatedNegativeBinomialP(y, X)

# Fit the model
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/scipy/optimize/_optimize.py:1292: OptimizeWarning: Maximum number of iterations has been exceeded.
#   res = _minimize_bfgs(f, x0, args, fprime, callback=callback, **opts)
#          Current function value: 0.189299
#          Iterations: 35
#          Function evaluations: 38
#          Gradient evaluations: 38
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                      ZeroInflatedNegativeBinomialP Regression Results
# =========================================================================================
# Dep. Variable:              nextbike_trips_count   No. Observations:              2564861
# Model:             ZeroInflatedNegativeBinomialP   Df Residuals:                  2564859
# Method:                                      MLE   Df Model:                            1
# Date:                           Fri, 13 Sep 2024   Pseudo R-squ.:               0.0003048
# Time:                                   19:09:06   Log-Likelihood:            -4.8553e+05
# converged:                                 False   LL-Null:                   -4.8567e+05
# Covariance Type:                       nonrobust   LLR p-value:                 2.327e-66
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# inflate_const                -0.0393      0.074     -0.529      0.597      -0.185       0.106
# const                        -2.3719      0.037    -64.830      0.000      -2.444      -2.300
# departure_delay_float_new    -0.1020      0.004    -24.955      0.000      -0.110      -0.094
# alpha                         4.0967      0.187     21.910      0.000       3.730       4.463
# =============================================================================================

# %%
# Define the independent variables (X) and the dependent variable (y)
X = data[['delay_span_int']]
y = data[y_string]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Create the zero-inflated negative binomial regression model
model = sm.ZeroInflatedNegativeBinomialP(y, X)

# Fit the model
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.188831
#          Iterations: 30
#          Function evaluations: 33
#          Gradient evaluations: 33
#                      ZeroInflatedNegativeBinomialP Regression Results
# =========================================================================================
# Dep. Variable:              nextbike_trips_count   No. Observations:              2564861
# Model:             ZeroInflatedNegativeBinomialP   Df Residuals:                  2564859
# Method:                                      MLE   Df Model:                            1
# Date:                           Fri, 13 Sep 2024   Pseudo R-squ.:                0.002778
# Time:                                   19:18:37   Log-Likelihood:            -4.8432e+05
# converged:                                  True   LL-Null:                   -4.8567e+05
# Covariance Type:                       nonrobust   LLR p-value:                     0.000
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# inflate_const     -2.7497      0.594     -4.626      0.000      -3.915      -1.585
# const             -2.8409      0.036    -78.974      0.000      -2.911      -2.770
# delay_span_int    -0.3584      0.007    -50.523      0.000      -0.372      -0.344
# alpha              8.4352      0.346     24.391      0.000       7.757       9.113
# ==================================================================================

# %%
# Define the independent variables (X) and the dependent variable (y)
X = data[['delay_category']]
y = data[y_string]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Create the zero-inflated negative binomial regression model
model = sm.ZeroInflatedNegativeBinomialP(y, X)

# Fit the model
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.189216
#          Iterations: 30
#          Function evaluations: 32
#          Gradient evaluations: 32
#                      ZeroInflatedNegativeBinomialP Regression Results
# =========================================================================================
# Dep. Variable:              nextbike_trips_count   No. Observations:              2564861
# Model:             ZeroInflatedNegativeBinomialP   Df Residuals:                  2564859
# Method:                                      MLE   Df Model:                            1
# Date:                           Fri, 13 Sep 2024   Pseudo R-squ.:               0.0007438
# Time:                                   19:25:02   Log-Likelihood:            -4.8531e+05
# converged:                                  True   LL-Null:                   -4.8567e+05
# Covariance Type:                       nonrobust   LLR p-value:                3.922e-159
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# inflate_const     -2.7902      0.608     -4.589      0.000      -3.982      -1.598
# const             -2.9922      0.035    -84.622      0.000      -3.062      -2.923
# delay_category    -0.1169      0.004    -27.088      0.000      -0.125      -0.108
# alpha              8.6446      0.348     24.823      0.000       7.962       9.327
# ==================================================================================

# %%
# Define the independent variables (X) and the dependent variable (y)
X = data[['cancelled_trip']]
y = data[y_string]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Create the zero-inflated negative binomial regression model
model = sm.ZeroInflatedNegativeBinomialP(y, X)

# Fit the model
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.189357
#          Iterations: 31
#          Function evaluations: 34
#          Gradient evaluations: 34
#                      ZeroInflatedNegativeBinomialP Regression Results
# =========================================================================================
# Dep. Variable:              nextbike_trips_count   No. Observations:              2564861
# Model:             ZeroInflatedNegativeBinomialP   Df Residuals:                  2564859
# Method:                                      MLE   Df Model:                            1
# Date:                           Fri, 13 Sep 2024   Pseudo R-squ.:              -1.394e-07
# Time:                                   19:32:22   Log-Likelihood:            -4.8567e+05
# converged:                                  True   LL-Null:                   -4.8567e+05
# Covariance Type:                       nonrobust   LLR p-value:                     1.000
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# inflate_const     -2.7940      0.665     -4.199      0.000      -4.098      -1.490
# const             -2.9543      0.039    -76.529      0.000      -3.030      -2.879
# cancelled_trip    -0.0245      0.007     -3.494      0.000      -0.038      -0.011
# alpha              8.6973      0.380     22.879      0.000       7.952       9.442
# ==================================================================================

# %%
# Define the independent variables (X) and the dependent variable (y)
X = data[['delay']]
y = data[y_string]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Create the zero-inflated negative binomial regression model
model = sm.ZeroInflatedNegativeBinomialP(y, X)

# Fit the model
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.188557
#          Iterations: 30
#          Function evaluations: 33
#          Gradient evaluations: 33
#                      ZeroInflatedNegativeBinomialP Regression Results
# =========================================================================================
# Dep. Variable:              nextbike_trips_count   No. Observations:              2564861
# Model:             ZeroInflatedNegativeBinomialP   Df Residuals:                  2564859
# Method:                                      MLE   Df Model:                            1
# Date:                           Fri, 13 Sep 2024   Pseudo R-squ.:                0.004222
# Time:                                   19:37:24   Log-Likelihood:            -4.8362e+05
# converged:                                  True   LL-Null:                   -4.8567e+05
# Covariance Type:                       nonrobust   LLR p-value:                     0.000
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# inflate_const    -2.7345      0.665     -4.114      0.000      -4.037      -1.432
# const            -2.8098      0.041    -68.963      0.000      -2.890      -2.730
# delay            -0.4733      0.007    -63.392      0.000      -0.488      -0.459
# alpha             8.3245      0.386     21.561      0.000       7.568       9.081
# =================================================================================

# %%
# Define the independent variables (X) and the dependent variable (y)
X = data[['no_delay']]
y = data[y_string]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Create the zero-inflated negative binomial regression model
model = sm.ZeroInflatedNegativeBinomialP(y, X)

# Fit the model
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.188535
#          Iterations: 30
#          Function evaluations: 33
#          Gradient evaluations: 33
#                      ZeroInflatedNegativeBinomialP Regression Results
# =========================================================================================
# Dep. Variable:              nextbike_trips_count   No. Observations:              2564861
# Model:             ZeroInflatedNegativeBinomialP   Df Residuals:                  2564859
# Method:                                      MLE   Df Model:                            1
# Date:                           Fri, 13 Sep 2024   Pseudo R-squ.:                0.004339
# Time:                                   19:45:48   Log-Likelihood:            -4.8357e+05
# converged:                                  True   LL-Null:                   -4.8567e+05
# Covariance Type:                       nonrobust   LLR p-value:                     0.000
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# inflate_const    -2.7496      0.575     -4.785      0.000      -3.876      -1.623
# const            -3.0956      0.035    -88.998      0.000      -3.164      -3.027
# no_delay          0.4969      0.008     65.963      0.000       0.482       0.512
# alpha             8.2814      0.329     25.152      0.000       7.636       8.927
# =================================================================================

# %%
# Define the independent variables (X) and the dependent variable (y)
X = data[['nan_delay']]
y = data[y_string]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Create the zero-inflated negative binomial regression model
model = sm.ZeroInflatedNegativeBinomialP(y, X)

# Fit the model
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.189358
#          Iterations: 29
#          Function evaluations: 33
#          Gradient evaluations: 33
#                      ZeroInflatedNegativeBinomialP Regression Results
# =========================================================================================
# Dep. Variable:              nextbike_trips_count   No. Observations:              2564861
# Model:             ZeroInflatedNegativeBinomialP   Df Residuals:                  2564859
# Method:                                      MLE   Df Model:                            1
# Date:                           Fri, 13 Sep 2024   Pseudo R-squ.:              -4.627e-06
# Time:                                   19:52:23   Log-Likelihood:            -4.8568e+05
# converged:                                  True   LL-Null:                   -4.8567e+05
# Covariance Type:                       nonrobust   LLR p-value:                     1.000
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# inflate_const    -2.7798      0.521     -5.332      0.000      -3.802      -1.758
# const            -2.9707      0.031    -96.535      0.000      -3.031      -2.910
# nan_delay         0.0187      0.007      2.696      0.007       0.005       0.032
# alpha             8.7006      0.305     28.497      0.000       8.102       9.299
# =================================================================================

# %%
# Define the independent variables (X) and the dependent variable (y)
X = data_dummy.drop(columns=[y_string, 'departure_delay_float'])
y = data[y_string]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Create the zero-inflated negative binomial regression model
model = sm.ZeroInflatedNegativeBinomialP(y, X.astype(float))

# Fit the model
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/base/model.py:595: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:4329: RuntimeWarning: overflow encountered in exp
#   return np.exp(linpred)
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3937: RuntimeWarning: invalid value encountered in multiply
#   a1 * np.log(a1) + y * np.log(mu) -
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3936: RuntimeWarning: invalid value encountered in subtract
#   llf = (gammaln(y + a1) - gammaln(y + 1) - gammaln(a1) +
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3974: RuntimeWarning: divide by zero encountered in log
#   dgterm = dgpart + np.log(a1 / a2) + 1 - a3 / a2
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3977: RuntimeWarning: invalid value encountered in multiply
#   dparams = (a4 * dgterm -
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3980: RuntimeWarning: overflow encountered in multiply
#   dparams = (self.exog.T * mu * dparams).T
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3980: RuntimeWarning: invalid value encountered in multiply
#   dparams = (self.exog.T * mu * dparams).T
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3937: RuntimeWarning: invalid value encountered in log
#   a1 * np.log(a1) + y * np.log(mu) -
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:4329: RuntimeWarning: overflow encountered in exp
#   return np.exp(linpred)
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3937: RuntimeWarning: invalid value encountered in multiply
#   a1 * np.log(a1) + y * np.log(mu) -
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3936: RuntimeWarning: invalid value encountered in subtract
#   llf = (gammaln(y + a1) - gammaln(y + 1) - gammaln(a1) +
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3974: RuntimeWarning: divide by zero encountered in log
#   dgterm = dgpart + np.log(a1 / a2) + 1 - a3 / a2
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3977: RuntimeWarning: invalid value encountered in multiply
#   dparams = (a4 * dgterm -
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3980: RuntimeWarning: overflow encountered in multiply
#   dparams = (self.exog.T * mu * dparams).T
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3980: RuntimeWarning: invalid value encountered in multiply
#   dparams = (self.exog.T * mu * dparams).T
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:4329: RuntimeWarning: overflow encountered in exp
#   return np.exp(linpred)
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3974: RuntimeWarning: divide by zero encountered in log
#   dgterm = dgpart + np.log(a1 / a2) + 1 - a3 / a2
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3977: RuntimeWarning: invalid value encountered in multiply
#   dparams = (a4 * dgterm -
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3980: RuntimeWarning: invalid value encountered in multiply
#   dparams = (self.exog.T * mu * dparams).T
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3937: RuntimeWarning: invalid value encountered in multiply
#   a1 * np.log(a1) + y * np.log(mu) -
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3936: RuntimeWarning: invalid value encountered in subtract
#   llf = (gammaln(y + a1) - gammaln(y + 1) - gammaln(a1) +
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/scipy/optimize/_optimize.py:1292: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(f, x0, args, fprime, callback=callback, **opts)
#          Current function value: nan
#          Iterations: 1
#          Function evaluations: 112
#          Gradient evaluations: 112
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/base/model.py:595: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                      ZeroInflatedNegativeBinomialP Regression Results
# =========================================================================================
# Dep. Variable:              nextbike_trips_count   No. Observations:              2564861
# Model:             ZeroInflatedNegativeBinomialP   Df Residuals:                  2564827
# Method:                                      MLE   Df Model:                           33
# Date:                           Fri, 13 Sep 2024   Pseudo R-squ.:                     nan
# Time:                                   20:24:57   Log-Likelihood:                    nan
# converged:                                 False   LL-Null:                   -4.8567e+05
# Covariance Type:                       nonrobust   LLR p-value:                       nan
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# inflate_const                   -1.0774        nan        nan        nan         nan         nan
# const                           -3.8465        nan        nan        nan         nan         nan
# route_type                       0.8389        nan        nan        nan         nan         nan
# stop_id                       1034.2142        nan        nan        nan         nan         nan
# service                          0.9640        nan        nan        nan         nan         nan
# transfer_stop                    0.5168        nan        nan        nan         nan         nan
# current_temp                     7.1382        nan        nan        nan         nan         nan
# current_precipitation_volume     0.0915        nan        nan        nan         nan         nan
# weather_int                     -0.1683        nan        nan        nan         nan         nan
# weekend                         -0.0154        nan        nan        nan         nan         nan
# cancelled_trip                  -0.3667        nan        nan        nan         nan         nan
# delay                           -2.2424        nan        nan        nan         nan         nan
# no_delay                         0.1443        nan        nan        nan         nan         nan
# nan_delay                        1.2911        nan        nan        nan         nan         nan
# departure_delay_float_new       -0.0317        nan        nan        nan         nan         nan
# time_span_afternoon              1.3321        nan        nan        nan         nan         nan
# time_span_early morning          0.6143        nan        nan        nan         nan         nan
# time_span_evening                0.6536        nan        nan        nan         nan         nan
# time_span_evening rush           0.9691        nan        nan        nan         nan         nan
# time_span_lunch                  1.0400        nan        nan        nan         nan         nan
# time_span_morning rush           0.8430        nan        nan        nan         nan         nan
# time_span_until midday           0.9521        nan        nan        nan         nan         nan
# weekday_Monday                  -0.2430        nan        nan        nan         nan         nan
# weekday_Saturday                 0.0750        nan        nan        nan         nan         nan
# weekday_Sunday                   0.0023        nan        nan        nan         nan         nan
# weekday_Thursday                -0.1434        nan        nan        nan         nan         nan
# weekday_Tuesday                 -0.2188        nan        nan        nan         nan         nan
# weekday_Wednesday               -0.1077        nan        nan        nan         nan         nan
# delay_span_0-5                   1.9588        nan        nan        nan         nan         nan
# delay_span_10-15                -0.3204        nan        nan        nan         nan         nan
# delay_span_15-20                 0.4743        nan        nan        nan         nan         nan
# delay_span_20-30                -0.0534        nan        nan        nan         nan         nan
# delay_span_30-45                 0.5655        nan        nan        nan         nan         nan
# delay_span_45-60                 0.7975        nan        nan        nan         nan         nan
# delay_span_5-10                  0.7911        nan        nan        nan         nan         nan
# alpha                           79.9817        nan        nan        nan         nan         nan
# ================================================================================================

# %%
# Define the independent variables (X) and the dependent variable (y)
X = time_span_dummy
y = data[y_string]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Create the zero-inflated negative binomial regression model
model = sm.ZeroInflatedNegativeBinomialP(y, X.astype(float))

# Fit the model
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/scipy/optimize/_optimize.py:1292: OptimizeWarning: Maximum number of iterations has been exceeded.
#   res = _minimize_bfgs(f, x0, args, fprime, callback=callback, **opts)
#          Current function value: 0.188706
#          Iterations: 35
#          Function evaluations: 39
#          Gradient evaluations: 39
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                      ZeroInflatedNegativeBinomialP Regression Results
# =========================================================================================
# Dep. Variable:              nextbike_trips_count   No. Observations:              2564861
# Model:             ZeroInflatedNegativeBinomialP   Df Residuals:                  2564853
# Method:                                      MLE   Df Model:                            7
# Date:                           Fri, 13 Sep 2024   Pseudo R-squ.:                0.003435
# Time:                                   20:34:42   Log-Likelihood:            -4.8401e+05
# converged:                                 False   LL-Null:                   -4.8567e+05
# Covariance Type:                       nonrobust   LLR p-value:                     0.000
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# inflate_const              -2.6491      0.194    -13.634      0.000      -3.030      -2.268
# const                      -3.0229      0.014   -218.743      0.000      -3.050      -2.996
# time_span_afternoon         0.5391      0.012     44.044      0.000       0.515       0.563
# time_span_early morning    -0.3552      0.029    -12.124      0.000      -0.413      -0.298
# time_span_evening          -0.2168      0.017    -12.645      0.000      -0.250      -0.183
# time_span_evening rush      0.1487      0.011     13.156      0.000       0.127       0.171
# time_span_lunch             0.2280      0.011     20.446      0.000       0.206       0.250
# time_span_morning rush     -0.1480      0.012    -12.545      0.000      -0.171      -0.125
# time_span_until midday      0.0863      0.014      6.042      0.000       0.058       0.114
# alpha                       8.3435      0.139     60.040      0.000       8.071       8.616
# ===========================================================================================

# %%
# Define the independent variables (X) and the dependent variable (y)
X = delay_span_dummy
y = data[y_string]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Create the zero-inflated negative binomial regression model
model = sm.ZeroInflatedNegativeBinomialP(y, X.astype(float))

# Fit the model
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.188759
#          Iterations: 30
#          Function evaluations: 33
#          Gradient evaluations: 33
#                      ZeroInflatedNegativeBinomialP Regression Results
# =========================================================================================
# Dep. Variable:              nextbike_trips_count   No. Observations:              2564861
# Model:             ZeroInflatedNegativeBinomialP   Df Residuals:                  2564853
# Method:                                      MLE   Df Model:                            7
# Date:                           Fri, 13 Sep 2024   Pseudo R-squ.:                0.003157
# Time:                                   20:45:02   Log-Likelihood:            -4.8414e+05
# converged:                                  True   LL-Null:                   -4.8567e+05
# Covariance Type:                       nonrobust   LLR p-value:                     0.000
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# inflate_const       -2.7305      0.608     -4.491      0.000      -3.922      -1.539
# const               -2.8314      0.037    -75.615      0.000      -2.905      -2.758
# delay_span_0-5      -0.3878      0.007    -52.535      0.000      -0.402      -0.373
# delay_span_10-15    -3.8458      1.061     -3.624      0.000      -5.926      -1.766
# delay_span_15-20    -1.5756      0.235     -6.713      0.000      -2.036      -1.116
# delay_span_20-30    -1.0995      0.170     -6.457      0.000      -1.433      -0.766
# delay_span_30-45    -1.9905      0.314     -6.348      0.000      -2.605      -1.376
# delay_span_45-60     0.7648      0.161      4.764      0.000       0.450       1.079
# delay_span_5-10     -1.1804      0.210     -5.616      0.000      -1.592      -0.768
# alpha                8.4117      0.359     23.443      0.000       7.708       9.115
# ====================================================================================

# %%
# Define the independent variables (X) and the dependent variable (y)
X = weekday_dummy
y = data[y_string]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Create the zero-inflated negative binomial regression model
model = sm.ZeroInflatedNegativeBinomialP(y, X.astype(float))

# Fit the model
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/scipy/optimize/_optimize.py:1292: OptimizeWarning: Maximum number of iterations has been exceeded.
#   res = _minimize_bfgs(f, x0, args, fprime, callback=callback, **opts)
#          Current function value: 0.189042
#          Iterations: 35
#          Function evaluations: 39
#          Gradient evaluations: 39
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                      ZeroInflatedNegativeBinomialP Regression Results
# =========================================================================================
# Dep. Variable:              nextbike_trips_count   No. Observations:              2564861
# Model:             ZeroInflatedNegativeBinomialP   Df Residuals:                  2564854
# Method:                                      MLE   Df Model:                            6
# Date:                           Fri, 13 Sep 2024   Pseudo R-squ.:                0.001663
# Time:                                   20:54:01   Log-Likelihood:            -4.8487e+05
# converged:                                 False   LL-Null:                   -4.8567e+05
# Covariance Type:                       nonrobust   LLR p-value:                     0.000
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# inflate_const        -2.7008      0.211    -12.776      0.000      -3.115      -2.286
# const                -2.8499      0.016   -179.520      0.000      -2.881      -2.819
# weekday_Monday       -0.1507      0.012    -12.691      0.000      -0.174      -0.127
# weekday_Saturday     -0.2250      0.012    -18.153      0.000      -0.249      -0.201
# weekday_Sunday       -0.5616      0.017    -33.449      0.000      -0.595      -0.529
# weekday_Thursday     -0.0632      0.012     -5.107      0.000      -0.087      -0.039
# weekday_Tuesday      -0.0246      0.012     -2.001      0.045      -0.049      -0.000
# weekday_Wednesday    -0.0016      0.012     -0.134      0.894      -0.026       0.022
# alpha                 8.6109      0.148     58.322      0.000       8.322       8.900
# =====================================================================================

# %%
# Define the independent variables (X) and the dependent variable (y)
X = selected_features
y = data[y_string]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Create the zero-inflated negative binomial regression model
model = sm.ZeroInflatedNegativeBinomialP(y, X.astype(float))

# Fit the model
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/base/model.py:595: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:4329: RuntimeWarning: overflow encountered in exp
#   return np.exp(linpred)
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3937: RuntimeWarning: invalid value encountered in multiply
#   a1 * np.log(a1) + y * np.log(mu) -
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3936: RuntimeWarning: invalid value encountered in subtract
#   llf = (gammaln(y + a1) - gammaln(y + 1) - gammaln(a1) +
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3974: RuntimeWarning: divide by zero encountered in log
#   dgterm = dgpart + np.log(a1 / a2) + 1 - a3 / a2
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3977: RuntimeWarning: invalid value encountered in multiply
#   dparams = (a4 * dgterm -
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3980: RuntimeWarning: overflow encountered in multiply
#   dparams = (self.exog.T * mu * dparams).T
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3980: RuntimeWarning: invalid value encountered in multiply
#   dparams = (self.exog.T * mu * dparams).T
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3937: RuntimeWarning: invalid value encountered in log
#   a1 * np.log(a1) + y * np.log(mu) -
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:4329: RuntimeWarning: overflow encountered in exp
#   return np.exp(linpred)
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3937: RuntimeWarning: invalid value encountered in multiply
#   a1 * np.log(a1) + y * np.log(mu) -
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3936: RuntimeWarning: invalid value encountered in subtract
#   llf = (gammaln(y + a1) - gammaln(y + 1) - gammaln(a1) +
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3974: RuntimeWarning: divide by zero encountered in log
#   dgterm = dgpart + np.log(a1 / a2) + 1 - a3 / a2
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3977: RuntimeWarning: invalid value encountered in multiply
#   dparams = (a4 * dgterm -
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3980: RuntimeWarning: overflow encountered in multiply
#   dparams = (self.exog.T * mu * dparams).T
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3980: RuntimeWarning: invalid value encountered in multiply
#   dparams = (self.exog.T * mu * dparams).T
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:4329: RuntimeWarning: overflow encountered in exp
#   return np.exp(linpred)
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3974: RuntimeWarning: divide by zero encountered in log
#   dgterm = dgpart + np.log(a1 / a2) + 1 - a3 / a2
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3977: RuntimeWarning: invalid value encountered in multiply
#   dparams = (a4 * dgterm -
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3980: RuntimeWarning: invalid value encountered in multiply
#   dparams = (self.exog.T * mu * dparams).T
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3937: RuntimeWarning: invalid value encountered in multiply
#   a1 * np.log(a1) + y * np.log(mu) -
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3936: RuntimeWarning: invalid value encountered in subtract
#   llf = (gammaln(y + a1) - gammaln(y + 1) - gammaln(a1) +
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/scipy/optimize/_optimize.py:1292: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(f, x0, args, fprime, callback=callback, **opts)
#          Current function value: nan
#          Iterations: 1
#          Function evaluations: 112
#          Gradient evaluations: 112
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/base/model.py:595: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                      ZeroInflatedNegativeBinomialP Regression Results
# =========================================================================================
# Dep. Variable:              nextbike_trips_count   No. Observations:              2564861
# Model:             ZeroInflatedNegativeBinomialP   Df Residuals:                  2564850
# Method:                                      MLE   Df Model:                           10
# Date:                           Fri, 13 Sep 2024   Pseudo R-squ.:                     nan
# Time:                                   21:08:01   Log-Likelihood:                    nan
# converged:                                 False   LL-Null:                   -4.8567e+05
# Covariance Type:                       nonrobust   LLR p-value:                       nan
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# inflate_const          -0.8432        nan        nan        nan         nan         nan
# const                  -3.0249        nan        nan        nan         nan         nan
# stop_id              1034.2141        nan        nan        nan         nan         nan
# no_delay                0.2903        nan        nan        nan         nan         nan
# delay                  -2.1507        nan        nan        nan         nan         nan
# current_temp            7.2496        nan        nan        nan         nan         nan
# transfer_stop           0.5491        nan        nan        nan         nan         nan
# delay_span_0-5          2.0704        nan        nan        nan         nan         nan
# time_span_afternoon     0.4937        nan        nan        nan         nan         nan
# weekend                 0.1191        nan        nan        nan         nan         nan
# weekday_Sunday         -0.2319        nan        nan        nan         nan         nan
# weather_int            -0.1153        nan        nan        nan         nan         nan
# alpha                  53.4987        nan        nan        nan         nan         nan
# =======================================================================================

# %%
# Zero inflated in thesis erklären

# %% [markdown]
# # Multilinear Regression

# %% [markdown]
# ### Best Model

# %%
# ALL

# Create a copy of the delay dataframe with the selected columns
delay_regression = data[['nextbike_trips_count', 'departure_delay_float', 'current_temp', 'current_precipitation_volume', 'service', 'weekday', 'delay_span', 'time_span', 'weekend', 'delay_category', 'cancelled_trip', 'delay', 'no_delay', 'nan_delay']].copy()

# Fit the multiple linear regression model
model = smf.ols(formula='nextbike_trips_count ~ departure_delay_float + current_temp + current_precipitation_volume + service + weekday + delay_span + time_span + weekend + delay_category + cancelled_trip + delay + no_delay + nan_delay', data=delay_regression).fit()

# Print the summary of the model
print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   R-squared:                       0.016
# Model:                              OLS   Adj. R-squared:                  0.016
# Method:                   Least Squares   F-statistic:                     927.0
# Date:                  Fri, 13 Sep 2024   Prob (F-statistic):               0.00
# Time:                          22:33:12   Log-Likelihood:            -1.4380e+05
# No. Observations:               1522668   AIC:                         2.877e+05
# Df Residuals:                   1522641   BIC:                         2.880e+05
# Df Model:                            26
# Covariance Type:              nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                       -0.1097      0.002    -47.216      0.000      -0.114      -0.105
# weekday[T.Monday]               -0.0218      0.001    -29.907      0.000      -0.023      -0.020
# weekday[T.Saturday]              0.0046      0.001      5.210      0.000       0.003       0.006
# weekday[T.Sunday]                0.0097      0.001      9.325      0.000       0.008       0.012
# weekday[T.Thursday]             -0.0169      0.001    -21.888      0.000      -0.018      -0.015
# weekday[T.Tuesday]              -0.0181      0.001    -23.822      0.000      -0.020      -0.017
# weekday[T.Wednesday]            -0.0132      0.001    -17.113      0.000      -0.015      -0.012
# delay_span[T.0-5]                0.4127      0.004    103.492      0.000       0.405       0.420
# delay_span[T.10-15]              0.3752      0.010     35.826      0.000       0.355       0.396
# delay_span[T.15-20]              0.3733      0.008     49.145      0.000       0.358       0.388
# delay_span[T.20-30]              0.3727      0.008     45.623      0.000       0.357       0.389
# delay_span[T.30-45]              0.3735      0.009     43.472      0.000       0.357       0.390
# delay_span[T.45-60]              0.3745      0.019     19.675      0.000       0.337       0.412
# delay_span[T.5-10]               0.3760      0.008     47.877      0.000       0.361       0.391
# time_span[T.afternoon]           0.0558      0.001     54.771      0.000       0.054       0.058
# time_span[T.early morning]       0.0190      0.001     13.571      0.000       0.016       0.022
# time_span[T.evening]             0.0162      0.001     15.882      0.000       0.014       0.018
# time_span[T.evening rush]        0.0303      0.001     32.801      0.000       0.029       0.032
# time_span[T.lunch]               0.0345      0.001     37.369      0.000       0.033       0.036
# time_span[T.morning rush]        0.0215      0.001     25.371      0.000       0.020       0.023
# time_span[T.until midday]        0.0292      0.001     29.878      0.000       0.027       0.031
# departure_delay_float            0.0011   8.77e-05     12.031      0.000       0.001       0.001
# current_temp                     0.0010   6.22e-05     16.104      0.000       0.001       0.001
# current_precipitation_volume    -0.0065      0.001     -9.718      0.000      -0.008      -0.005
# service                         -0.0176      0.003     -5.682      0.000      -0.024      -0.011
# weekend                         -0.0158      0.000    -52.869      0.000      -0.016      -0.015
# delay_category                  -0.0036      0.000     -8.207      0.000      -0.004      -0.003
# cancelled_trip                -1.95e-33   2.69e-34     -7.245      0.000   -2.48e-33   -1.42e-33
# delay                           -0.2758      0.003   -101.323      0.000      -0.281      -0.270
# no_delay                         0.1662      0.002     94.490      0.000       0.163       0.170
# nan_delay                             0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                  2076560.832   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        627241354.850
# Skew:                           7.889   Prob(JB):                         0.00
# Kurtosis:                     101.171   Cond. No.                     1.03e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.81e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### Other

# %%
# DELAY FEATURES ONLY

# Create a copy of the delay dataframe with the selected columns
delay_regression = data[[y_string, 'departure_delay_float_new', 'delay', 'no_delay', 'nan_delay', 'delay_span', 'cancelled_trip']].copy()

# Fit the multiple linear regression model
model = smf.ols(formula='nextbike_trips_count ~ departure_delay_float_new + delay + no_delay + nan_delay + delay_span + cancelled_trip', data=delay_regression).fit()

# Print the summary of the model
print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   R-squared:                       0.005
# Model:                              OLS   Adj. R-squared:                  0.005
# Method:                   Least Squares   F-statistic:                     1258.
# Date:                  Fri, 13 Sep 2024   Prob (F-statistic):               0.00
# Time:                          21:08:12   Log-Likelihood:            -2.8343e+05
# No. Observations:               2564861   AIC:                         5.669e+05
# Df Residuals:                   2564849   BIC:                         5.670e+05
# Df Model:                            11
# Covariance Type:              nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                 -2.671e+10   2.08e+10     -1.286      0.198   -6.74e+10     1.4e+10
# delay_span[T.0-5]             0.2905      0.003     84.445      0.000       0.284       0.297
# delay_span[T.10-15]           0.2403      0.010     23.125      0.000       0.220       0.261
# delay_span[T.15-20]           0.2425      0.007     33.009      0.000       0.228       0.257
# delay_span[T.20-30]           0.1489      0.006     23.429      0.000       0.136       0.161
# delay_span[T.30-45]           0.2131      0.008     25.630      0.000       0.197       0.229
# delay_span[T.45-60]           0.1310      0.011     12.429      0.000       0.110       0.152
# delay_span[T.5-10]            0.2635      0.008     34.343      0.000       0.248       0.279
# departure_delay_float_new     0.0012    8.7e-05     14.132      0.000       0.001       0.001
# delay                      2.671e+10   2.08e+10      1.286      0.198    -1.4e+10    6.74e+10
# no_delay                   2.671e+10   2.08e+10      1.286      0.198    -1.4e+10    6.74e+10
# nan_delay                  2.671e+10   2.08e+10      1.286      0.198    -1.4e+10    6.74e+10
# cancelled_trip               -0.0216      0.001    -14.825      0.000      -0.025      -0.019
# ==============================================================================
# Omnibus:                  3547432.901   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1166460056.548
# Skew:                           8.075   Prob(JB):                         0.00
# Kurtosis:                     106.218   Cond. No.                     5.97e+14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.23e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# DELAY FEATURES ONLY

# Create a copy of the delay dataframe with the selected columns
delay_regression = data[[y_string, 'departure_delay_float', 'delay', 'no_delay', 'nan_delay', 'delay_span', 'cancelled_trip']].copy()

# Fit the multiple linear regression model
model = smf.ols(formula='nextbike_trips_count ~ departure_delay_float + delay + no_delay + nan_delay + delay_span + cancelled_trip', data=delay_regression).fit()

# Print the summary of the model
print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   R-squared:                       0.011
# Model:                              OLS   Adj. R-squared:                  0.011
# Method:                   Least Squares   F-statistic:                     1892.
# Date:                  Fri, 13 Sep 2024   Prob (F-statistic):               0.00
# Time:                          21:28:19   Log-Likelihood:            -1.4729e+05
# No. Observations:               1522668   AIC:                         2.946e+05
# Df Residuals:                   1522658   BIC:                         2.947e+05
# Df Model:                             9
# Covariance Type:              nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -0.1032      0.001    -77.506      0.000      -0.106      -0.101
# delay_span[T.0-5]         0.4120      0.004    104.506      0.000       0.404       0.420
# delay_span[T.10-15]       0.3646      0.010     34.812      0.000       0.344       0.385
# delay_span[T.15-20]       0.3679      0.008     48.512      0.000       0.353       0.383
# delay_span[T.20-30]       0.3649      0.008     44.683      0.000       0.349       0.381
# delay_span[T.30-45]       0.3435      0.009     40.031      0.000       0.327       0.360
# delay_span[T.45-60]       0.3438      0.019     18.032      0.000       0.306       0.381
# delay_span[T.5-10]        0.3863      0.008     49.210      0.000       0.371       0.402
# departure_delay_float     0.0011   8.77e-05     12.157      0.000       0.001       0.001
# delay                    -0.2736      0.003   -104.035      0.000      -0.279      -0.268
# no_delay                  0.1704      0.001    128.922      0.000       0.168       0.173
# nan_delay                      0          0        nan        nan           0           0
# cancelled_trip                 0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                  2081694.228   Durbin-Watson:                   1.957
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        632019641.401
# Skew:                           7.926   Prob(JB):                         0.00
# Kurtosis:                     101.542   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# /home/students/miniconda3/envs/Andrej/lib/python3.12/site-packages/statsmodels/regression/linear_model.py:1967: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])

# %%
# TIME FEATURES

# Create a copy of the delay dataframe with the selected columns
delay_regression = data[['nextbike_trips_count', 'departure_delay_float_new', 'departure_delay_float', 'delay', 'no_delay', 'nan_delay', 'weekday', 'weekend', 'time_span']].copy()

# Fit the multiple linear regression model
model = smf.ols(formula='nextbike_trips_count ~ departure_delay_float_new + delay + no_delay + nan_delay + time_span + weekday + weekend', data=delay_regression).fit()

# Print the summary of the model
print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   R-squared:                       0.005
# Model:                              OLS   Adj. R-squared:                  0.005
# Method:                   Least Squares   F-statistic:                     804.7
# Date:                  Fri, 13 Sep 2024   Prob (F-statistic):               0.00
# Time:                          21:28:36   Log-Likelihood:            -2.8391e+05
# No. Observations:               2564861   AIC:                         5.679e+05
# Df Residuals:                   2564844   BIC:                         5.681e+05
# Df Model:                            16
# Covariance Type:              nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                  -5.933e+08   7.29e+09     -0.081      0.935   -1.49e+10    1.37e+10
# time_span[T.afternoon]         0.0617      0.001     65.317      0.000       0.060       0.064
# time_span[T.early morning]     0.0125      0.001      8.884      0.000       0.010       0.015
# time_span[T.evening]           0.0188      0.001     18.019      0.000       0.017       0.021
# time_span[T.evening rush]      0.0355      0.001     41.168      0.000       0.034       0.037
# time_span[T.lunch]             0.0397      0.001     45.811      0.000       0.038       0.041
# time_span[T.morning rush]      0.0210      0.001     24.714      0.000       0.019       0.023
# time_span[T.until midday]      0.0324      0.001     32.349      0.000       0.030       0.034
# weekday[T.Monday]          -1.236e+09   1.52e+10     -0.081      0.935    -3.1e+10    2.85e+10
# weekday[T.Saturday]         1.236e+09   1.52e+10      0.081      0.935   -2.85e+10     3.1e+10
# weekday[T.Sunday]           2.471e+09   3.04e+10      0.081      0.935   -5.71e+10     6.2e+10
# weekday[T.Thursday]        -1.236e+09   1.52e+10     -0.081      0.935    -3.1e+10    2.85e+10
# weekday[T.Tuesday]         -1.236e+09   1.52e+10     -0.081      0.935    -3.1e+10    2.85e+10
# weekday[T.Wednesday]       -1.236e+09   1.52e+10     -0.081      0.935    -3.1e+10    2.85e+10
# departure_delay_float_new  -7.302e-05   7.44e-05     -0.981      0.327      -0.000    7.28e-05
# delay                       1.829e+09   2.25e+10      0.081      0.935   -4.22e+10    4.59e+10
# no_delay                    1.829e+09   2.25e+10      0.081      0.935   -4.22e+10    4.59e+10
# nan_delay                   1.829e+09   2.25e+10      0.081      0.935   -4.22e+10    4.59e+10
# weekend                    -1.236e+09   1.52e+10     -0.081      0.935    -3.1e+10    2.85e+10
# ==============================================================================
# Omnibus:                  3548222.129   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1167538619.364
# Skew:                           8.079   Prob(JB):                         0.00
# Kurtosis:                     106.266   Cond. No.                     1.53e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.43e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# TIME FEATURES

# Create a copy of the delay dataframe with the selected columns
delay_regression = data[['nextbike_trips_count', 'departure_delay_float_new', 'departure_delay_float', 'delay', 'no_delay', 'nan_delay', 'weekday', 'weekend', 'time_span']].copy()

# Fit the multiple linear regression model
model = smf.ols(formula='nextbike_trips_count ~ departure_delay_float_new + delay + no_delay + nan_delay + time_span + weekday + weekend', data=delay_regression).fit()

# Print the summary of the model
print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   R-squared:                       0.005
# Model:                              OLS   Adj. R-squared:                  0.005
# Method:                   Least Squares   F-statistic:                     804.7
# Date:                  Fri, 13 Sep 2024   Prob (F-statistic):               0.00
# Time:                          21:28:53   Log-Likelihood:            -2.8391e+05
# No. Observations:               2564861   AIC:                         5.679e+05
# Df Residuals:                   2564844   BIC:                         5.681e+05
# Df Model:                            16
# Covariance Type:              nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                  -5.933e+08   7.29e+09     -0.081      0.935   -1.49e+10    1.37e+10
# time_span[T.afternoon]         0.0617      0.001     65.317      0.000       0.060       0.064
# time_span[T.early morning]     0.0125      0.001      8.884      0.000       0.010       0.015
# time_span[T.evening]           0.0188      0.001     18.019      0.000       0.017       0.021
# time_span[T.evening rush]      0.0355      0.001     41.168      0.000       0.034       0.037
# time_span[T.lunch]             0.0397      0.001     45.811      0.000       0.038       0.041
# time_span[T.morning rush]      0.0210      0.001     24.714      0.000       0.019       0.023
# time_span[T.until midday]      0.0324      0.001     32.349      0.000       0.030       0.034
# weekday[T.Monday]          -1.236e+09   1.52e+10     -0.081      0.935    -3.1e+10    2.85e+10
# weekday[T.Saturday]         1.236e+09   1.52e+10      0.081      0.935   -2.85e+10     3.1e+10
# weekday[T.Sunday]           2.471e+09   3.04e+10      0.081      0.935   -5.71e+10     6.2e+10
# weekday[T.Thursday]        -1.236e+09   1.52e+10     -0.081      0.935    -3.1e+10    2.85e+10
# weekday[T.Tuesday]         -1.236e+09   1.52e+10     -0.081      0.935    -3.1e+10    2.85e+10
# weekday[T.Wednesday]       -1.236e+09   1.52e+10     -0.081      0.935    -3.1e+10    2.85e+10
# departure_delay_float_new  -7.302e-05   7.44e-05     -0.981      0.327      -0.000    7.28e-05
# delay                       1.829e+09   2.25e+10      0.081      0.935   -4.22e+10    4.59e+10
# no_delay                    1.829e+09   2.25e+10      0.081      0.935   -4.22e+10    4.59e+10
# nan_delay                   1.829e+09   2.25e+10      0.081      0.935   -4.22e+10    4.59e+10
# weekend                    -1.236e+09   1.52e+10     -0.081      0.935    -3.1e+10    2.85e+10
# ==============================================================================
# Omnibus:                  3548222.129   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1167538619.364
# Skew:                           8.079   Prob(JB):                         0.00
# Kurtosis:                     106.266   Cond. No.                     1.53e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.43e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# ALL

# Create a copy of the delay dataframe with the selected columns
delay_regression = data[['nextbike_trips_count', 'departure_delay_float_new', 'current_temp', 'current_precipitation_volume', 'service', 'weekday', 'delay_span', 'time_span', 'weekend', 'delay_category', 'cancelled_trip', 'delay', 'no_delay', 'nan_delay']].copy()

# Fit the multiple linear regression model
model = smf.ols(formula='nextbike_trips_count ~ departure_delay_float_new + current_temp + current_precipitation_volume + service + weekday + delay_span + time_span + weekend + delay_category + cancelled_trip + delay + no_delay + nan_delay', data=delay_regression).fit()

# Print the summary of the model
print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     nextbike_trips_count   R-squared:                       0.009
# Model:                              OLS   Adj. R-squared:                  0.009
# Method:                   Least Squares   F-statistic:                     801.1
# Date:                  Fri, 13 Sep 2024   Prob (F-statistic):               0.00
# Time:                          22:32:51   Log-Likelihood:            -2.7917e+05
# No. Observations:               2564861   AIC:                         5.584e+05
# Df Residuals:                   2564832   BIC:                         5.588e+05
# Df Model:                            28
# Covariance Type:              nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                       -0.0561      0.002    -27.167      0.000      -0.060      -0.052
# weekday[T.Monday]               -0.0148      0.001    -25.947      0.000      -0.016      -0.014
# weekday[T.Saturday]              0.0001      0.001      0.174      0.862      -0.001       0.001
# weekday[T.Sunday]                0.0009      0.001      1.007      0.314      -0.001       0.003
# weekday[T.Thursday]             -0.0095      0.001    -15.842      0.000      -0.011      -0.008
# weekday[T.Tuesday]              -0.0121      0.001    -20.089      0.000      -0.013      -0.011
# weekday[T.Wednesday]            -0.0070      0.001    -11.744      0.000      -0.008      -0.006
# delay_span[T.0-5]                0.2879      0.003     83.257      0.000       0.281       0.295
# delay_span[T.10-15]              0.2477      0.010     23.831      0.000       0.227       0.268
# delay_span[T.15-20]              0.2445      0.007     33.230      0.000       0.230       0.259
# delay_span[T.20-30]              0.1528      0.006     24.005      0.000       0.140       0.165
# delay_span[T.30-45]              0.2409      0.008     28.918      0.000       0.225       0.257
# delay_span[T.45-60]              0.1491      0.011     14.149      0.000       0.128       0.170
# delay_span[T.5-10]               0.2500      0.008     32.580      0.000       0.235       0.265
# time_span[T.afternoon]           0.0503      0.001     50.663      0.000       0.048       0.052
# time_span[T.early morning]       0.0193      0.001     13.691      0.000       0.017       0.022
# time_span[T.evening]             0.0133      0.001     12.982      0.000       0.011       0.015
# time_span[T.evening rush]        0.0254      0.001     28.154      0.000       0.024       0.027
# time_span[T.lunch]               0.0297      0.001     32.883      0.000       0.028       0.031
# time_span[T.morning rush]        0.0208      0.001     24.366      0.000       0.019       0.023
# time_span[T.until midday]        0.0260      0.001     26.598      0.000       0.024       0.028
# departure_delay_float_new        0.0012   8.67e-05     14.175      0.000       0.001       0.001
# current_temp                     0.0018   4.53e-05     38.783      0.000       0.002       0.002
# current_precipitation_volume    -0.0056      0.001    -11.013      0.000      -0.007      -0.005
# service                         -0.0014      0.003     -0.521      0.602      -0.006       0.004
# weekend                         -0.0108      0.000    -42.637      0.000      -0.011      -0.010
# delay_category                  -0.0032      0.000     -7.227      0.000      -0.004      -0.002
# cancelled_trip                  -0.0248      0.002    -16.271      0.000      -0.028      -0.022
# delay                           -0.2402      0.003    -92.638      0.000      -0.245      -0.235
# no_delay                         0.0783      0.001     63.667      0.000       0.076       0.081
# nan_delay                        0.1058      0.002     68.265      0.000       0.103       0.109
# ==============================================================================
# Omnibus:                  3541499.883   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1161539191.036
# Skew:                           8.049   Prob(JB):                         0.00
# Kurtosis:                     106.003   Cond. No.                     9.47e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.34e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
