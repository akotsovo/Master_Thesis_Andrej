# %% [markdown]
# # 04: Merge first VRS "planned" data with stations in Bonn

# %% [markdown]
# Data that will be aggreagated, cleaned and merged in this notebook:
# - Bonn Stations (Notebook 1)
# - Agency
# - Routes
# - Stops
# - Stop Times

# %% [markdown]
# ### Note: this notebooks was executed on local machine

# %%
# import libraries
import pandas as pd
import numpy as np
import sklearn
from datetime import datetime
import os
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
import shapely
from shapely.geometry import Point
import hashlib

# %%
# Set month
data_month_single = '7'
data_month_double = '07'
data_month_int = 7

# %%
# load agency data
agency = pd.DataFrame(pd.read_csv("../Data/2023"+ data_month_double+"01-000000-UTC_gtfs-scraper_agency-vrs.csv"))

# %%
#calendar_dates = pd.DataFrame(pd.read_csv("/Volumes/T7/Master/Raw Data/"+ data_month_double+"/VRS Planned Data/2023"+ data_month_double+"01-000000-UTC_gtfs-scraper_calendar_dates-vrs.csv"))

# %%
#calendar = pd.DataFrame(pd.read_csv("/Volumes/T7/Master/Raw Data/"+ data_month_double+"/VRS Planned Data/2023"+ data_month_double+"01-000000-UTC_gtfs-scraper_calendar-vrs.csv"))

# %% [markdown]
# ## Routes

# %%
# load routes data
routes = pd.DataFrame(pd.read_csv("../Data/2023"+ data_month_double+"01-000000-UTC_gtfs-scraper_routes-vrs.csv"))
routes
# Out:
#      route_id  agency_id route_short_name route_long_name  route_type  \
# 0      100001          1                1             NaN           0
# 1      100002          1                E             NaN           0
# 2      100003          1                3             NaN           0
# 3      100004          1                4             NaN           0
# 4      100005          1                5             NaN           0
# ..        ...        ...              ...             ...         ...
# 607  19901298        199              SEV             NaN           3
# 608  19911310        199                A             NaN           3
# 609  19911789        199                B             NaN           3
# 610  19911790        139             RB48             NaN           3
# 611  19911791          5               S6             NaN           3
#
#     route_color route_text_color
# 0        E0071C           FFFFFF
# 1        000000           FFFFFF
# 2        F29DC2           FFFFFF
# 3        EA71A5           FFFFFF
# 4        A69CC8           FFFFFF
# ..          ...              ...
# 607      000000           FFFFFF
# 608      000000           FFFFFF
# 609      000000           FFFFFF
# 610      FFC82E           FFFFFF
# 611      000000           FFFFFF
#
# [612 rows x 7 columns]

# %%
# if short name is missing, fill with long name
routes['route_short_name'] = routes['route_short_name'].fillna(routes['route_long_name'])

# %%
# drop columns
routes.drop(columns=['route_long_name', 'route_color', 'route_text_color'], inplace=True)

# %%
routes
# Out:
#      route_id  agency_id route_short_name  route_type
# 0      100001          1                1           0
# 1      100002          1                E           0
# 2      100003          1                3           0
# 3      100004          1                4           0
# 4      100005          1                5           0
# ..        ...        ...              ...         ...
# 607  19901298        199              SEV           3
# 608  19911310        199                A           3
# 609  19911789        199                B           3
# 610  19911790        139             RB48           3
# 611  19911791          5               S6           3
#
# [612 rows x 4 columns]

# %%
# create column with route type name for better understanding
routes['route_type_name'] = routes['route_type'].apply(lambda x: 'Tram' if x == 0 else 'Rail' if x == 2 else 'Bus')

# %% [markdown]
# ## Merge Agency with Routes

# %%
routes = routes.merge(agency[['agency_id', 'agency_name']], on='agency_id', how='left')
routes
# Out:
#      route_id  agency_id route_short_name  route_type route_type_name  \
# 0      100001          1                1           0            Tram
# 1      100002          1                E           0            Tram
# 2      100003          1                3           0            Tram
# 3      100004          1                4           0            Tram
# 4      100005          1                5           0            Tram
# ..        ...        ...              ...         ...             ...
# 607  19901298        199              SEV           3             Bus
# 608  19911310        199                A           3             Bus
# 609  19911789        199                B           3             Bus
# 610  19911790        139             RB48           3             Bus
# 611  19911791          5               S6           3             Bus
#
#                                     agency_name
# 0               KVB Kölner Verkehrs-Betriebe AG
# 1               KVB Kölner Verkehrs-Betriebe AG
# 2               KVB Kölner Verkehrs-Betriebe AG
# 3               KVB Kölner Verkehrs-Betriebe AG
# 4               KVB Kölner Verkehrs-Betriebe AG
# ..                                          ...
# 607  SEV Schienenersatzverkehr Deutsche Bahn AG
# 608  SEV Schienenersatzverkehr Deutsche Bahn AG
# 609  SEV Schienenersatzverkehr Deutsche Bahn AG
# 610               NX National Express Rail GmbH
# 611                DB DB - Regio AG, Region NRW
#
# [612 rows x 6 columns]

# %%
# export to csv
routes.to_csv('../Data/04_routes_merged.csv', index=False)

# %% [markdown]
# Now, agency dataframe can be ignored

# %% [markdown]
# ## Stops

# %%
# load stops data
stops = pd.DataFrame(pd.read_csv("../Data/2023"+data_month_double+"01-000000-UTC_gtfs-scraper_stops-vrs.csv"))
stops
# Out:
#       stop_id                   stop_name   stop_lat  stop_lon  location_type
# 0           1               Köln Heumarkt  50.935705  6.959995              0
# 1           2               Köln Neumarkt  50.935770  6.947677              0
# 2           3               Köln Poststr.  50.931238  6.950060              0
# 3           4        Köln Mauritiuskirche  50.934173  6.945069              0
# 4           6                Köln Rathaus  50.938467  6.959697              0
# ...       ...                         ...        ...       ...            ...
# 6956    64728          Dormagen Dantestr.  51.112985  6.757370              0
# 6957    66006  Remscheid Kräwinklerbrücke  51.184089  7.305355              0
# 6958    74228      Wuppertal Kurvenstraße  51.248001  7.287557              0
# 6959    77620      Wuppertal In Der Hardt  51.220275  7.287913              0
# 6960    77621   Wuppertal Mesenholler Weg  51.219068  7.296253              0
#
# [6961 rows x 5 columns]

# %%
#drop location_type
stops.drop(columns=['location_type'], inplace=True)

# %% [markdown]
# Now we need to narrow stops down with the stops that are only in Bonn

# %%
#load bonn stops
bonn_stops = gpd.read_parquet('../Data/01_bonn_stop_buffer.parquet')
bonn_stops = gpd.GeoDataFrame(bonn_stops)
# Out:
# /var/folders/_m/71fq0nk106s02qxvct5s2sv80000gn/T/ipykernel_2915/120213552.py:2: UserWarning: Multiple non-primary geometry columns read from Parquet/Feather file. The first column read was promoted to the primary geometry.
#   bonn_stops = gpd.read_parquet('/Volumes/T7/Master/Processed Data/01_bonn_stop_buffer.parquet')

# %%
# only keep stops in Bonn
stops = stops[stops['stop_name'].str.split().str[0] == 'Bonn']

# %%
stops
# Out:
#       stop_id                                stop_name   stop_lat  stop_lon
# 39         43                      Bonn Propsthof Nord  50.739096  7.073507
# 156       161                    Bonn Bad Godesberg Bf  50.683920  7.159553
# 357       371            Bonn Bad Godesberg Stadthalle  50.680336  7.158347
# 653       683                       Bonn Museum Koenig  50.721748  7.114519
# 654       684  Bonn Bundesrechnungshof/Auswärtiges Amt  50.725560  7.111579
# ...       ...                                      ...        ...       ...
# 6655     9716              Bonn Gerhart-Hauptmann-Str.  50.735969  7.060630
# 6688     9777                         Bonn Kleine Str.  50.741163  7.047926
# 6689     9778                      Bonn Magdalenenstr.  50.727103  7.072652
# 6690     9779                     Bonn Am Dickobskreuz  50.737108  7.072725
# 6691     9780                     Bonn Georg-Elser-Weg  50.756198  7.052400
#
# [543 rows x 4 columns]

# %%
# rename columns to prepare for merge
stops.rename(columns={'stop_lon': 'long'}, inplace=True)
stops.rename(columns={'stop_lat': 'lat'}, inplace=True)
# Out:
# /var/folders/_m/71fq0nk106s02qxvct5s2sv80000gn/T/ipykernel_2915/4187973222.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stops.rename(columns={'stop_lon': 'long'}, inplace=True)
# /var/folders/_m/71fq0nk106s02qxvct5s2sv80000gn/T/ipykernel_2915/4187973222.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stops.rename(columns={'stop_lat': 'lat'}, inplace=True)

# %%
stops
# Out:
#       stop_id                                stop_name        lat      long
# 39         43                      Bonn Propsthof Nord  50.739096  7.073507
# 156       161                    Bonn Bad Godesberg Bf  50.683920  7.159553
# 357       371            Bonn Bad Godesberg Stadthalle  50.680336  7.158347
# 653       683                       Bonn Museum Koenig  50.721748  7.114519
# 654       684  Bonn Bundesrechnungshof/Auswärtiges Amt  50.725560  7.111579
# ...       ...                                      ...        ...       ...
# 6655     9716              Bonn Gerhart-Hauptmann-Str.  50.735969  7.060630
# 6688     9777                         Bonn Kleine Str.  50.741163  7.047926
# 6689     9778                      Bonn Magdalenenstr.  50.727103  7.072652
# 6690     9779                     Bonn Am Dickobskreuz  50.737108  7.072725
# 6691     9780                     Bonn Georg-Elser-Weg  50.756198  7.052400
#
# [543 rows x 4 columns]

# %%
# Create a new column "geometry" with Point objects
stops['geometry'] = stops.apply(lambda row: Point(row['long'], row['lat']), axis=1)
# Out:
# /var/folders/_m/71fq0nk106s02qxvct5s2sv80000gn/T/ipykernel_2915/1411703467.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stops['geometry'] = stops.apply(lambda row: Point(row['long'], row['lat']), axis=1)

# %%
stops
# Out:
#       stop_id                                stop_name        lat      long  \
# 39         43                      Bonn Propsthof Nord  50.739096  7.073507
# 156       161                    Bonn Bad Godesberg Bf  50.683920  7.159553
# 357       371            Bonn Bad Godesberg Stadthalle  50.680336  7.158347
# 653       683                       Bonn Museum Koenig  50.721748  7.114519
# 654       684  Bonn Bundesrechnungshof/Auswärtiges Amt  50.725560  7.111579
# ...       ...                                      ...        ...       ...
# 6655     9716              Bonn Gerhart-Hauptmann-Str.  50.735969  7.060630
# 6688     9777                         Bonn Kleine Str.  50.741163  7.047926
# 6689     9778                      Bonn Magdalenenstr.  50.727103  7.072652
# 6690     9779                     Bonn Am Dickobskreuz  50.737108  7.072725
# 6691     9780                     Bonn Georg-Elser-Weg  50.756198  7.052400
#
#                         geometry
# 39    POINT (7.073507 50.739096)
# 156    POINT (7.159553 50.68392)
# 357   POINT (7.158347 50.680336)
# 653   POINT (7.114519 50.721748)
# 654    POINT (7.111579 50.72556)
# ...                          ...
# 6655   POINT (7.06063 50.735969)
# 6688  POINT (7.047926 50.741163)
# 6689  POINT (7.072652 50.727103)
# 6690  POINT (7.072725 50.737108)
# 6691    POINT (7.0524 50.756198)
#
# [543 rows x 5 columns]

# %%
# iterate over all stops and check if they are in buffer_zone
for index, stop_row in bonn_stops.iterrows():

    for index, stop in stops.iterrows():

        point = stop['geometry']

        if stop_row['buffer_zone'].contains(point):
           bonn_stops['stop_id'] = stops['stop_id']
           bonn_stops['stop_name'] = stops['stop_name']

# %%
bonn_stops
# Out:
#                  station_point  \
# 39    POINT (7.07351 50.73910)
# 156   POINT (7.15955 50.68392)
# 357   POINT (7.15835 50.68034)
# 600   POINT (7.00271 50.75686)
# 643   POINT (7.00758 50.75425)
# ...                        ...
# 6689  POINT (7.07265 50.72710)
# 6690  POINT (7.07273 50.73711)
# 6691  POINT (7.05240 50.75620)
# 6716  POINT (7.01639 50.71882)
# 6721  POINT (7.00717 50.80467)
#
#                                             buffer_zone        lat      long  \
# 39    POLYGON ((7.07626 50.73943, 7.07630 50.73926, ...  50.739096  7.073507
# 156   POLYGON ((7.16230 50.68425, 7.16234 50.68408, ...  50.683920  7.159553
# 357   POLYGON ((7.16110 50.68067, 7.16113 50.68050, ...  50.680336  7.158347
# 600   POLYGON ((7.00547 50.75720, 7.00550 50.75703, ...  50.756861  7.002714
# 643   POLYGON ((7.01033 50.75458, 7.01037 50.75441, ...  50.754248  7.007576
# ...                                                 ...        ...       ...
# 6689  POLYGON ((7.07540 50.72744, 7.07544 50.72727, ...  50.727103  7.072652
# 6690  POLYGON ((7.07548 50.73744, 7.07551 50.73727, ...  50.737108  7.072725
# 6691  POLYGON ((7.05515 50.75653, 7.05519 50.75636, ...  50.756198  7.052400
# 6716  POLYGON ((7.01914 50.71915, 7.01918 50.71898, ...  50.718815  7.016388
# 6721  POLYGON ((7.00993 50.80501, 7.00996 50.80484, ...  50.804674  7.007171
#
#       stop_id                      stop_name
# 39       43.0            Bonn Propsthof Nord
# 156     161.0          Bonn Bad Godesberg Bf
# 357     371.0  Bonn Bad Godesberg Stadthalle
# 600       NaN                            NaN
# 643       NaN                            NaN
# ...       ...                            ...
# 6689   9778.0            Bonn Magdalenenstr.
# 6690   9779.0           Bonn Am Dickobskreuz
# 6691   9780.0           Bonn Georg-Elser-Weg
# 6716      NaN                            NaN
# 6721      NaN                            NaN
#
# [845 rows x 6 columns]

# %%
# drop rows with missing values - those are not in Bonn
bonn_stops.dropna(subset=['stop_id', 'stop_name'], inplace=True)

# %%
bonn_stops
# Out:
#                  station_point  \
# 39    POINT (7.07351 50.73910)
# 156   POINT (7.15955 50.68392)
# 357   POINT (7.15835 50.68034)
# 653   POINT (7.11452 50.72175)
# 654   POINT (7.11158 50.72556)
# ...                        ...
# 6655  POINT (7.06063 50.73597)
# 6688  POINT (7.04793 50.74116)
# 6689  POINT (7.07265 50.72710)
# 6690  POINT (7.07273 50.73711)
# 6691  POINT (7.05240 50.75620)
#
#                                             buffer_zone        lat      long  \
# 39    POLYGON ((7.07626 50.73943, 7.07630 50.73926, ...  50.739096  7.073507
# 156   POLYGON ((7.16230 50.68425, 7.16234 50.68408, ...  50.683920  7.159553
# 357   POLYGON ((7.16110 50.68067, 7.16113 50.68050, ...  50.680336  7.158347
# 653   POLYGON ((7.11727 50.72208, 7.11731 50.72191, ...  50.721748  7.114519
# 654   POLYGON ((7.11433 50.72589, 7.11437 50.72572, ...  50.725560  7.111579
# ...                                                 ...        ...       ...
# 6655  POLYGON ((7.06338 50.73630, 7.06342 50.73613, ...  50.735969  7.060630
# 6688  POLYGON ((7.05068 50.74150, 7.05072 50.74133, ...  50.741163  7.047926
# 6689  POLYGON ((7.07540 50.72744, 7.07544 50.72727, ...  50.727103  7.072652
# 6690  POLYGON ((7.07548 50.73744, 7.07551 50.73727, ...  50.737108  7.072725
# 6691  POLYGON ((7.05515 50.75653, 7.05519 50.75636, ...  50.756198  7.052400
#
#       stop_id                                stop_name
# 39       43.0                      Bonn Propsthof Nord
# 156     161.0                    Bonn Bad Godesberg Bf
# 357     371.0            Bonn Bad Godesberg Stadthalle
# 653     683.0                       Bonn Museum Koenig
# 654     684.0  Bonn Bundesrechnungshof/Auswärtiges Amt
# ...       ...                                      ...
# 6655   9716.0              Bonn Gerhart-Hauptmann-Str.
# 6688   9777.0                         Bonn Kleine Str.
# 6689   9778.0                      Bonn Magdalenenstr.
# 6690   9779.0                     Bonn Am Dickobskreuz
# 6691   9780.0                     Bonn Georg-Elser-Weg
#
# [527 rows x 6 columns]

# %%
# convert to int
bonn_stops['stop_id'] = bonn_stops['stop_id'].astype(int)

# %%
bonn_stops
# Out:
#                  station_point  \
# 39    POINT (7.07351 50.73910)
# 156   POINT (7.15955 50.68392)
# 357   POINT (7.15835 50.68034)
# 653   POINT (7.11452 50.72175)
# 654   POINT (7.11158 50.72556)
# ...                        ...
# 6655  POINT (7.06063 50.73597)
# 6688  POINT (7.04793 50.74116)
# 6689  POINT (7.07265 50.72710)
# 6690  POINT (7.07273 50.73711)
# 6691  POINT (7.05240 50.75620)
#
#                                             buffer_zone        lat      long  \
# 39    POLYGON ((7.07626 50.73943, 7.07630 50.73926, ...  50.739096  7.073507
# 156   POLYGON ((7.16230 50.68425, 7.16234 50.68408, ...  50.683920  7.159553
# 357   POLYGON ((7.16110 50.68067, 7.16113 50.68050, ...  50.680336  7.158347
# 653   POLYGON ((7.11727 50.72208, 7.11731 50.72191, ...  50.721748  7.114519
# 654   POLYGON ((7.11433 50.72589, 7.11437 50.72572, ...  50.725560  7.111579
# ...                                                 ...        ...       ...
# 6655  POLYGON ((7.06338 50.73630, 7.06342 50.73613, ...  50.735969  7.060630
# 6688  POLYGON ((7.05068 50.74150, 7.05072 50.74133, ...  50.741163  7.047926
# 6689  POLYGON ((7.07540 50.72744, 7.07544 50.72727, ...  50.727103  7.072652
# 6690  POLYGON ((7.07548 50.73744, 7.07551 50.73727, ...  50.737108  7.072725
# 6691  POLYGON ((7.05515 50.75653, 7.05519 50.75636, ...  50.756198  7.052400
#
#       stop_id                                stop_name
# 39         43                      Bonn Propsthof Nord
# 156       161                    Bonn Bad Godesberg Bf
# 357       371            Bonn Bad Godesberg Stadthalle
# 653       683                       Bonn Museum Koenig
# 654       684  Bonn Bundesrechnungshof/Auswärtiges Amt
# ...       ...                                      ...
# 6655     9716              Bonn Gerhart-Hauptmann-Str.
# 6688     9777                         Bonn Kleine Str.
# 6689     9778                      Bonn Magdalenenstr.
# 6690     9779                     Bonn Am Dickobskreuz
# 6691     9780                     Bonn Georg-Elser-Weg
#
# [527 rows x 6 columns]

# %%
# export to parquet
bonn_stops.to_parquet('../Data/04_bonn_stations.parquet')

# %% [markdown]
# ## Cut "Stop Times" and megre with stop data from above

# %% [markdown]
# Trim Stop Times to stops only in Bonn

# %%
# load stop times data
stop_times =pd.DataFrame(pd.read_csv("../Data/2023"+ data_month_double+"01-000000-UTC_gtfs-scraper_stop_times-vrs.csv"))
stop_times
# Out:
# /var/folders/_m/71fq0nk106s02qxvct5s2sv80000gn/T/ipykernel_2915/705314464.py:2: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   stop_times =pd.DataFrame(pd.read_csv("/Volumes/T7/Master/Raw Data/"+ data_month_double+"/VRS Planned data/2023"+ data_month_double+"01-000000-UTC_gtfs-scraper_stop_times-vrs.csv"))
#                                                    trip_id arrival_time  \
# 0        9-398-011-8279.2.21:121500-23-1_93B3E758-D5F5-...     12:15:00
# 1        9-398-011-8279.2.21:121500-23-1_93B3E758-D5F5-...     12:17:00
# 2        9-398-011-8279.2.21:121500-23-1_93B3E758-D5F5-...     12:19:00
# 3        9-398-011-8279.2.21:121500-23-1_93B3E758-D5F5-...     12:21:00
# 4        9-398-011-8279.2.21:121500-23-1_93B3E758-D5F5-...     12:22:00
# ...                                                    ...          ...
# 2444727  7-288-016-3432.2.21:272100-35-1_335F78EC-5757-...     28:00:00
# 2444728  7-288-016-3432.2.21:272100-35-1_335F78EC-5757-...     28:02:00
# 2444729  7-288-016-3432.2.21:272100-35-1_335F78EC-5757-...     28:03:00
# 2444730  7-288-016-3432.2.21:272100-35-1_335F78EC-5757-...     28:04:00
# 2444731  7-288-016-3432.2.21:272100-35-1_335F78EC-5757-...     28:06:00
#
#         departure_time  stop_id  stop_sequence stop_headsign  pickup_type  \
# 0             12:15:00     8279              1           NaN            0
# 1             12:17:00     4145              2           NaN            0
# 2             12:19:00     3642              3           NaN            0
# 3             12:21:00     3911              4           NaN            0
# 4             12:22:00     3817              5           NaN            0
# ...                ...      ...            ...           ...          ...
# 2444727       28:00:00     1956             31           NaN            0
# 2444728       28:02:00     3100             32           NaN            0
# 2444729       28:03:00     5258             33           NaN            0
# 2444730       28:04:00     3433             34           NaN            0
# 2444731       28:06:00     3432             35           NaN            0
#
#          drop_off_type
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 2444727              0
# 2444728              0
# 2444729              0
# 2444730              0
# 2444731              0
#
# [2444732 rows x 8 columns]

# %%
# drop columns
stop_times.drop(columns=['pickup_type', 'drop_off_type'], inplace=True)

# %%
stop_times
# Out:
#                                                    trip_id arrival_time  \
# 0        9-398-011-8279.2.21:121500-23-1_93B3E758-D5F5-...     12:15:00
# 1        9-398-011-8279.2.21:121500-23-1_93B3E758-D5F5-...     12:17:00
# 2        9-398-011-8279.2.21:121500-23-1_93B3E758-D5F5-...     12:19:00
# 3        9-398-011-8279.2.21:121500-23-1_93B3E758-D5F5-...     12:21:00
# 4        9-398-011-8279.2.21:121500-23-1_93B3E758-D5F5-...     12:22:00
# ...                                                    ...          ...
# 2444727  7-288-016-3432.2.21:272100-35-1_335F78EC-5757-...     28:00:00
# 2444728  7-288-016-3432.2.21:272100-35-1_335F78EC-5757-...     28:02:00
# 2444729  7-288-016-3432.2.21:272100-35-1_335F78EC-5757-...     28:03:00
# 2444730  7-288-016-3432.2.21:272100-35-1_335F78EC-5757-...     28:04:00
# 2444731  7-288-016-3432.2.21:272100-35-1_335F78EC-5757-...     28:06:00
#
#         departure_time  stop_id  stop_sequence stop_headsign
# 0             12:15:00     8279              1           NaN
# 1             12:17:00     4145              2           NaN
# 2             12:19:00     3642              3           NaN
# 3             12:21:00     3911              4           NaN
# 4             12:22:00     3817              5           NaN
# ...                ...      ...            ...           ...
# 2444727       28:00:00     1956             31           NaN
# 2444728       28:02:00     3100             32           NaN
# 2444729       28:03:00     5258             33           NaN
# 2444730       28:04:00     3433             34           NaN
# 2444731       28:06:00     3432             35           NaN
#
# [2444732 rows x 6 columns]

# %%
# Merge the stop_times and merged_stops DataFrames based on the stop_id column
merged_data = pd.merge(stop_times, bonn_stops, on='stop_id', how='inner')

# The merged_data DataFrame will now contain only the rows where the stop_id matches in both DataFrames

# %%
merged_data
# Out:
#                                                   trip_id arrival_time  \
# 0       6330006-633-006-1584.2.24:202100-11-1_A90CDB5F...     20:21:00
# 1       6330006-633-006-1584.2.24:202100-11-1_A90CDB5F...     20:22:00
# 2       6330006-633-006-1584.2.24:202100-11-1_A90CDB5F...     20:24:00
# 3       6330006-633-006-1584.2.24:202100-11-1_A90CDB5F...     20:25:00
# 4       6330006-633-006-1584.2.24:202100-11-1_A90CDB5F...     20:26:00
# ...                                                   ...          ...
# 354971  6350145-635-006-1584.2.23:200800-19-1_BB9DD49C...     20:20:00
# 354972  6350145-635-006-1584.2.23:200800-19-1_BB9DD49C...     20:21:00
# 354973  6350145-635-006-1584.2.23:200800-19-1_BB9DD49C...     20:23:00
# 354974  6350145-635-006-1584.2.23:200800-19-1_BB9DD49C...     20:24:00
# 354975  6350145-635-006-1584.2.23:200800-19-1_BB9DD49C...     20:25:00
#
#        departure_time  stop_id  stop_sequence stop_headsign  \
# 0            20:21:00     1584              1           NaN
# 1            20:22:00     1583              2           NaN
# 2            20:24:00     1582              3           NaN
# 3            20:25:00     1581              4           NaN
# 4            20:26:00     1580              5           NaN
# ...               ...      ...            ...           ...
# 354971       20:20:00     1568             12           NaN
# 354972       20:21:00     1566             13           NaN
# 354973       20:23:00     1562             14           NaN
# 354974       20:24:00     2313             15           NaN
# 354975       20:25:00     2312             16           NaN
#
#                    station_point  \
# 0       POINT (7.15513 50.72238)
# 1       POINT (7.15079 50.72595)
# 2       POINT (7.14873 50.73034)
# 3       POINT (7.14563 50.73330)
# 4       POINT (7.14250 50.73497)
# ...                          ...
# 354971  POINT (7.16736 50.74520)
# 354972  POINT (7.17369 50.74516)
# 354973  POINT (7.17490 50.75007)
# 354974  POINT (7.16800 50.75066)
# 354975  POINT (7.16218 50.75075)
#
#                                               buffer_zone        lat  \
# 0       POLYGON ((7.15789 50.72271, 7.15792 50.72254, ...  50.722377
# 1       POLYGON ((7.15354 50.72629, 7.15358 50.72611, ...  50.725953
# 2       POLYGON ((7.15148 50.73068, 7.15152 50.73050, ...  50.730342
# 3       POLYGON ((7.14838 50.73364, 7.14842 50.73346, ...  50.733303
# 4       POLYGON ((7.14525 50.73530, 7.14529 50.73513, ...  50.734970
# ...                                                   ...        ...
# 354971  POLYGON ((7.17011 50.74553, 7.17015 50.74536, ...  50.745197
# 354972  POLYGON ((7.17644 50.74549, 7.17648 50.74532, ...  50.745160
# 354973  POLYGON ((7.17766 50.75041, 7.17769 50.75023, ...  50.750074
# 354974  POLYGON ((7.17076 50.75099, 7.17079 50.75082, ...  50.750656
# 354975  POLYGON ((7.16493 50.75108, 7.16497 50.75091, ...  50.750750
#
#             long                stop_name
# 0       7.155135          Bonn Ramersdorf
# 1       7.150790          Bonn Samansstr.
# 2       7.148731  Bonn Küdinghoven Kirche
# 3       7.145630            Bonn Forstweg
# 4       7.142498          Bonn Broichstr.
# ...          ...                      ...
# 354971  7.167358        Bonn Am Rehsprung
# 354972  7.173690    Bonn Paul-Langen-Str.
# 354973  7.174904    Bonn Kohlkauler Platz
# 354974  7.168004          Bonn Ennertstr.
# 354975  7.162182         Bonn Kautex-Werk
#
# [354976 rows x 11 columns]

# %%
# create a GeoDataFrame
merged_data = gpd.GeoDataFrame(merged_data)

# %%
merged_data.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 354976 entries, 0 to 354975
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   trip_id         354976 non-null  object
#  1   arrival_time    354976 non-null  object
#  2   departure_time  354976 non-null  object
#  3   stop_id         354976 non-null  int64
#  4   stop_sequence   354976 non-null  int64
#  5   stop_headsign   216 non-null     object
#  6   station_point   354976 non-null  geometry
#  7   buffer_zone     354976 non-null  geometry
#  8   lat             354976 non-null  float64
#  9   long            354976 non-null  float64
#  10  stop_name       354976 non-null  object
# dtypes: float64(2), geometry(2), int64(2), object(5)
# memory usage: 29.8+ MB

# %%
# export the merged data to parquet
merged_data.to_parquet('../Data/04_merged_stop_times_buffer_zones.parquet')
